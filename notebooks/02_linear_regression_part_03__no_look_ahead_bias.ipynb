# %% [markdown]
# The objetive of this notebook is to avoid the look ahead bias introduced on the previous
# notebook

# %%
import logging
import imp
from dateutil.relativedelta import relativedelta

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
from helpers.dataset import read_quote_dataset, preprocess_quotes
from helpers.backtest import train_model_and_backtest_regressor, get_backtest_performance_metrics

# %%
# Configir logging module for jypter notebook
imp.reload(logging)
logging_format = '%(asctime)s - %(levelname)s - %(process)s - %(message)s'
logging.basicConfig(level=logging.DEBUG, format=logging_format)

# %%
PARAM_DATASET = '../data/SPY_postprocess_adj.csv.gz'

# %%
df = read_quote_dataset(PARAM_DATASET)

# %%
df.head()
# Out:
#         date        open        high         low     close   close_adj  \
# 0 2000-01-03  148.250000  148.250000  143.875000  145.4375  101.425385
# 1 2000-01-04  143.531204  144.062500  139.640594  139.7500   97.459068
# 2 2000-01-05  139.937500  141.531204  137.250000  140.0000   97.633377
# 3 2000-01-06  139.625000  141.500000  137.750000  137.7500   96.064301
# 4 2000-01-07  140.312500  145.750000  140.062500  145.7500  101.643333
#
#      volume    open_adj     low_adj    high_adj  ...  \
# 0   8164300  103.386770  100.335727  103.386770  ...
# 1   8089800  100.096010   97.382770  100.466526  ...
# 2  12177900   97.589791   95.715579   98.701210  ...
# 3   6227200   97.371891   96.064301   98.679482  ...
# 4   8066500   97.851322   97.676977  101.643333  ...
#
#    ratio_close_adj_000_close_adj_005_norm  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ratio_close_adj_000_close_adj_020_norm  ratio_close_adj_000_ema_005_norm  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                          0.486630
# 4                                     NaN                          0.815422
#
#    ratio_close_adj_000_ema_010_norm  ratio_close_adj_000_ema_020_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ratio_close_adj_000_ema_050_norm  ratio_close_adj_000_sma_005_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                          0.740588
#
#    ratio_close_adj_000_sma_010_norm  ratio_close_adj_000_sma_020_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ratio_close_adj_000_sma_050_norm
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 173 columns]

# %%
vars_to_shift = ['close_adj', 'close_adj_norm', 'close_adj_std']
shift_periods = [1, 5, 10, 20]
vars_for_return = ['close_adj']
return_periods = [1, 5, 10, 20]

# %%
df = preprocess_quotes(
    df, vars_to_shift=vars_to_shift, shift_periods=shift_periods,
    vars_for_return=vars_for_return, return_periods=return_periods,
    shift_date=True
)

# %%
df[['date', 'close_adj', 'date_shift_1', 'close_adj_shift_1', 'close_adj_ret_1', 
    'date_shift_5', 'close_adj_shift_5', 'close_adj_ret_5']].head(10)
# Out:
#         date   close_adj date_shift_1  close_adj_shift_1  close_adj_ret_1  \
# 0 2000-01-03  101.425385   2000-01-04          97.459068        -0.039106
# 1 2000-01-04   97.459068   2000-01-05          97.633377         0.001789
# 2 2000-01-05   97.633377   2000-01-06          96.064301        -0.016071
# 3 2000-01-06   96.064301   2000-01-07         101.643333         0.058076
# 4 2000-01-07  101.643333   2000-01-10         101.992004         0.003430
# 5 2000-01-10  101.992004   2000-01-11         100.771645        -0.011965
# 6 2000-01-11  100.771645   2000-01-12          99.769150        -0.009948
# 7 2000-01-12   99.769150   2000-01-13         101.120308         0.013543
# 8 2000-01-13  101.120308   2000-01-14         102.493233         0.013577
# 9 2000-01-14  102.493233   2000-01-18         101.686958        -0.007867
#
#   date_shift_5  close_adj_shift_5  close_adj_ret_5
# 0   2000-01-10         101.992004         0.005587
# 1   2000-01-11         100.771645         0.033989
# 2   2000-01-12          99.769150         0.021875
# 3   2000-01-13         101.120308         0.052631
# 4   2000-01-14         102.493233         0.008362
# 5   2000-01-18         101.686958        -0.002991
# 6   2000-01-19         102.515060         0.017301
# 7   2000-01-20         100.945953         0.011795
# 8   2000-01-21         100.727989        -0.003880
# 9   2000-01-24          97.873047        -0.045078

# %% [markdown]
# Check we have the same CAGR than on part 02

# %%
x_vars = ['open_adj', 'low_adj', 'high_adj']
y_var = 'close_adj_shift_20'
buy_price_col = 'close_adj'
sell_price_col = 'close_adj_shift_1'
model_class = LinearRegression
model_params = {'fit_intercept': True}

# %%
df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
    buy_price_col=buy_price_col, sell_price_col=sell_price_col,
    model_class=model_class, model_params=model_params, 
    backtest_start='2000-02-01', backtest_end='2018-12-31', 
    model_update_frequency='M', train_history_period=relativedelta(months=1),
)
# Out:
# 2019-05-05 16:12:18,672 - DEBUG - 22988 - 228 periods to backtest: ['2000-02-01', '2000-02-29', '2000-03-31', '2000-04-30', '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31', '2000-09-30', '2000-10-31', '2000-11-30', '2000-12-31', '2001-01-31', '2001-02-28', '2001-03-31', '2001-04-30', '2001-05-31', '2001-06-30', '2001-07-31', '2001-08-31', '2001-09-30', '2001-10-31', '2001-11-30', '2001-12-31', '2002-01-31', '2002-02-28', '2002-03-31', '2002-04-30', '2002-05-31', '2002-06-30', '2002-07-31', '2002-08-31', '2002-09-30', '2002-10-31', '2002-11-30', '2002-12-31', '2003-01-31', '2003-02-28', '2003-03-31', '2003-04-30', '2003-05-31', '2003-06-30', '2003-07-31', '2003-08-31', '2003-09-30', '2003-10-31', '2003-11-30', '2003-12-31', '2004-01-31', '2004-02-29', '2004-03-31', '2004-04-30', '2004-05-31', '2004-06-30', '2004-07-31', '2004-08-31', '2004-09-30', '2004-10-31', '2004-11-30', '2004-12-31', '2005-01-31', '2005-02-28', '2005-03-31', '2005-04-30', '2005-05-31', '2005-06-30', '2005-07-31', '2005-08-31', '2005-09-30', '2005-10-31', '2005-11-30', '2005-12-31', '2006-01-31', '2006-02-28', '2006-03-31', '2006-04-30', '2006-05-31', '2006-06-30', '2006-07-31', '2006-08-31', '2006-09-30', '2006-10-31', '2006-11-30', '2006-12-31', '2007-01-31', '2007-02-28', '2007-03-31', '2007-04-30', '2007-05-31', '2007-06-30', '2007-07-31', '2007-08-31', '2007-09-30', '2007-10-31', '2007-11-30', '2007-12-31', '2008-01-31', '2008-02-29', '2008-03-31', '2008-04-30', '2008-05-31', '2008-06-30', '2008-07-31', '2008-08-31', '2008-09-30', '2008-10-31', '2008-11-30', '2008-12-31', '2009-01-31', '2009-02-28', '2009-03-31', '2009-04-30', '2009-05-31', '2009-06-30', '2009-07-31', '2009-08-31', '2009-09-30', '2009-10-31', '2009-11-30', '2009-12-31', '2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30', '2010-05-31', '2010-06-30', '2010-07-31', '2010-08-31', '2010-09-30', '2010-10-31', '2010-11-30', '2010-12-31', '2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30', '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31', '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31', '2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30', '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31', '2012-09-30', '2012-10-31', '2012-11-30', '2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31'].
# 2019-05-05 16:12:18,673 - INFO - 22988 - Training a model to be tested between 2000-02-01 and 2000-02-29.
# 2019-05-05 16:12:18,675 - INFO - 22988 - Training dataset is between 2000-01-03 and 2000-01-31.
# 2019-05-05 16:12:18,685 - INFO - 22988 - Training a model to be tested between 2000-02-29 and 2000-03-31.
# 2019-05-05 16:12:18,688 - INFO - 22988 - Training dataset is between 2000-01-31 and 2000-02-28.
# 2019-05-05 16:12:18,697 - INFO - 22988 - Training a model to be tested between 2000-03-31 and 2000-04-30.
# 2019-05-05 16:12:18,699 - INFO - 22988 - Training dataset is between 2000-02-29 and 2000-03-30.
# 2019-05-05 16:12:18,710 - INFO - 22988 - Training a model to be tested between 2000-04-30 and 2000-05-31.
# 2019-05-05 16:12:18,712 - INFO - 22988 - Training dataset is between 2000-03-30 and 2000-04-28.
# 2019-05-05 16:12:18,721 - INFO - 22988 - Training a model to be tested between 2000-05-31 and 2000-06-30.
# 2019-05-05 16:12:18,724 - INFO - 22988 - Training dataset is between 2000-05-01 and 2000-05-30.
# 2019-05-05 16:12:18,760 - INFO - 22988 - Training a model to be tested between 2000-06-30 and 2000-07-31.
# 2019-05-05 16:12:18,762 - INFO - 22988 - Training dataset is between 2000-05-30 and 2000-06-29.
# 2019-05-05 16:12:18,770 - INFO - 22988 - Training a model to be tested between 2000-07-31 and 2000-08-31.
# 2019-05-05 16:12:18,773 - INFO - 22988 - Training dataset is between 2000-06-30 and 2000-07-28.
# 2019-05-05 16:12:18,782 - INFO - 22988 - Training a model to be tested between 2000-08-31 and 2000-09-30.
# 2019-05-05 16:12:18,784 - INFO - 22988 - Training dataset is between 2000-07-31 and 2000-08-30.
# 2019-05-05 16:12:18,795 - INFO - 22988 - Training a model to be tested between 2000-09-30 and 2000-10-31.
# 2019-05-05 16:12:18,797 - INFO - 22988 - Training dataset is between 2000-08-30 and 2000-09-29.
# 2019-05-05 16:12:18,807 - INFO - 22988 - Training a model to be tested between 2000-10-31 and 2000-11-30.
# 2019-05-05 16:12:18,808 - INFO - 22988 - Training dataset is between 2000-10-02 and 2000-10-30.
# 2019-05-05 16:12:18,816 - INFO - 22988 - Training a model to be tested between 2000-11-30 and 2000-12-31.
# 2019-05-05 16:12:18,819 - INFO - 22988 - Training dataset is between 2000-10-30 and 2000-11-29.
# 2019-05-05 16:12:18,832 - INFO - 22988 - Training a model to be tested between 2000-12-31 and 2001-01-31.
# 2019-05-05 16:12:18,835 - INFO - 22988 - Training dataset is between 2000-11-30 and 2000-12-29.
# 2019-05-05 16:12:18,849 - INFO - 22988 - Training a model to be tested between 2001-01-31 and 2001-02-28.
# 2019-05-05 16:12:18,851 - INFO - 22988 - Training dataset is between 2001-01-02 and 2001-01-30.
# 2019-05-05 16:12:18,863 - INFO - 22988 - Training a model to be tested between 2001-02-28 and 2001-03-31.
# 2019-05-05 16:12:18,866 - INFO - 22988 - Training dataset is between 2001-01-29 and 2001-02-27.
# 2019-05-05 16:12:18,879 - INFO - 22988 - Training a model to be tested between 2001-03-31 and 2001-04-30.
# 2019-05-05 16:12:18,884 - INFO - 22988 - Training dataset is between 2001-02-28 and 2001-03-30.
# 2019-05-05 16:12:18,898 - INFO - 22988 - Training a model to be tested between 2001-04-30 and 2001-05-31.
# 2019-05-05 16:12:18,900 - INFO - 22988 - Training dataset is between 2001-03-30 and 2001-04-27.
# 2019-05-05 16:12:18,909 - INFO - 22988 - Training a model to be tested between 2001-05-31 and 2001-06-30.
# 2019-05-05 16:12:18,912 - INFO - 22988 - Training dataset is between 2001-04-30 and 2001-05-30.
# 2019-05-05 16:12:18,920 - INFO - 22988 - Training a model to be tested between 2001-06-30 and 2001-07-31.
# 2019-05-05 16:12:18,923 - INFO - 22988 - Training dataset is between 2001-05-30 and 2001-06-29.
# 2019-05-05 16:12:18,933 - INFO - 22988 - Training a model to be tested between 2001-07-31 and 2001-08-31.
# 2019-05-05 16:12:18,935 - INFO - 22988 - Training dataset is between 2001-07-02 and 2001-07-30.
# 2019-05-05 16:12:18,943 - INFO - 22988 - Training a model to be tested between 2001-08-31 and 2001-09-30.
# 2019-05-05 16:12:18,945 - INFO - 22988 - Training dataset is between 2001-07-31 and 2001-08-30.
# 2019-05-05 16:12:18,955 - INFO - 22988 - Training a model to be tested between 2001-09-30 and 2001-10-31.
# 2019-05-05 16:12:18,957 - INFO - 22988 - Training dataset is between 2001-08-30 and 2001-09-28.
# 2019-05-05 16:12:18,966 - INFO - 22988 - Training a model to be tested between 2001-10-31 and 2001-11-30.
# 2019-05-05 16:12:18,969 - INFO - 22988 - Training dataset is between 2001-10-01 and 2001-10-30.
# 2019-05-05 16:12:18,978 - INFO - 22988 - Training a model to be tested between 2001-11-30 and 2001-12-31.
# 2019-05-05 16:12:18,980 - INFO - 22988 - Training dataset is between 2001-10-30 and 2001-11-29.
# 2019-05-05 16:12:18,990 - INFO - 22988 - Training a model to be tested between 2001-12-31 and 2002-01-31.
# 2019-05-05 16:12:18,992 - INFO - 22988 - Training dataset is between 2001-11-30 and 2001-12-28.
# 2019-05-05 16:12:19,003 - INFO - 22988 - Training a model to be tested between 2002-01-31 and 2002-02-28.
# 2019-05-05 16:12:19,004 - INFO - 22988 - Training dataset is between 2001-12-31 and 2002-01-30.
# 2019-05-05 16:12:19,013 - INFO - 22988 - Training a model to be tested between 2002-02-28 and 2002-03-31.
# 2019-05-05 16:12:19,016 - INFO - 22988 - Training dataset is between 2002-01-28 and 2002-02-27.
# 2019-05-05 16:12:19,027 - INFO - 22988 - Training a model to be tested between 2002-03-31 and 2002-04-30.
# 2019-05-05 16:12:19,029 - INFO - 22988 - Training dataset is between 2002-02-28 and 2002-03-28.
# 2019-05-05 16:12:19,039 - INFO - 22988 - Training a model to be tested between 2002-04-30 and 2002-05-31.
# 2019-05-05 16:12:19,041 - INFO - 22988 - Training dataset is between 2002-04-01 and 2002-04-29.
# 2019-05-05 16:12:19,051 - INFO - 22988 - Training a model to be tested between 2002-05-31 and 2002-06-30.
# 2019-05-05 16:12:19,054 - INFO - 22988 - Training dataset is between 2002-04-30 and 2002-05-30.
# 2019-05-05 16:12:19,063 - INFO - 22988 - Training a model to be tested between 2002-06-30 and 2002-07-31.
# 2019-05-05 16:12:19,066 - INFO - 22988 - Training dataset is between 2002-05-30 and 2002-06-28.
# 2019-05-05 16:12:19,074 - INFO - 22988 - Training a model to be tested between 2002-07-31 and 2002-08-31.
# 2019-05-05 16:12:19,077 - INFO - 22988 - Training dataset is between 2002-07-01 and 2002-07-30.
# 2019-05-05 16:12:19,087 - INFO - 22988 - Training a model to be tested between 2002-08-31 and 2002-09-30.
# 2019-05-05 16:12:19,089 - INFO - 22988 - Training dataset is between 2002-07-31 and 2002-08-30.
# 2019-05-05 16:12:19,099 - INFO - 22988 - Training a model to be tested between 2002-09-30 and 2002-10-31.
# 2019-05-05 16:12:19,102 - INFO - 22988 - Training dataset is between 2002-08-30 and 2002-09-27.
# 2019-05-05 16:12:19,111 - INFO - 22988 - Training a model to be tested between 2002-10-31 and 2002-11-30.
# 2019-05-05 16:12:19,114 - INFO - 22988 - Training dataset is between 2002-09-30 and 2002-10-30.
# 2019-05-05 16:12:19,123 - INFO - 22988 - Training a model to be tested between 2002-11-30 and 2002-12-31.
# 2019-05-05 16:12:19,126 - INFO - 22988 - Training dataset is between 2002-10-30 and 2002-11-29.
# 2019-05-05 16:12:19,136 - INFO - 22988 - Training a model to be tested between 2002-12-31 and 2003-01-31.
# 2019-05-05 16:12:19,138 - INFO - 22988 - Training dataset is between 2002-12-02 and 2002-12-30.
# 2019-05-05 16:12:19,146 - INFO - 22988 - Training a model to be tested between 2003-01-31 and 2003-02-28.
# 2019-05-05 16:12:19,150 - INFO - 22988 - Training dataset is between 2002-12-31 and 2003-01-30.
# 2019-05-05 16:12:19,159 - INFO - 22988 - Training a model to be tested between 2003-02-28 and 2003-03-31.
# 2019-05-05 16:12:19,161 - INFO - 22988 - Training dataset is between 2003-01-28 and 2003-02-27.
# 2019-05-05 16:12:19,170 - INFO - 22988 - Training a model to be tested between 2003-03-31 and 2003-04-30.
# 2019-05-05 16:12:19,172 - INFO - 22988 - Training dataset is between 2003-02-28 and 2003-03-28.
# 2019-05-05 16:12:19,180 - INFO - 22988 - Training a model to be tested between 2003-04-30 and 2003-05-31.
# 2019-05-05 16:12:19,183 - INFO - 22988 - Training dataset is between 2003-03-31 and 2003-04-29.
# 2019-05-05 16:12:19,192 - INFO - 22988 - Training a model to be tested between 2003-05-31 and 2003-06-30.
# 2019-05-05 16:12:19,194 - INFO - 22988 - Training dataset is between 2003-04-30 and 2003-05-30.
# 2019-05-05 16:12:19,203 - INFO - 22988 - Training a model to be tested between 2003-06-30 and 2003-07-31.
# 2019-05-05 16:12:19,205 - INFO - 22988 - Training dataset is between 2003-05-30 and 2003-06-27.
# 2019-05-05 16:12:19,214 - INFO - 22988 - Training a model to be tested between 2003-07-31 and 2003-08-31.
# 2019-05-05 16:12:19,217 - INFO - 22988 - Training dataset is between 2003-06-30 and 2003-07-30.
# 2019-05-05 16:12:19,225 - INFO - 22988 - Training a model to be tested between 2003-08-31 and 2003-09-30.
# 2019-05-05 16:12:19,227 - INFO - 22988 - Training dataset is between 2003-07-31 and 2003-08-29.
# 2019-05-05 16:12:19,235 - INFO - 22988 - Training a model to be tested between 2003-09-30 and 2003-10-31.
# 2019-05-05 16:12:19,236 - INFO - 22988 - Training dataset is between 2003-09-02 and 2003-09-29.
# 2019-05-05 16:12:19,245 - INFO - 22988 - Training a model to be tested between 2003-10-31 and 2003-11-30.
# 2019-05-05 16:12:19,247 - INFO - 22988 - Training dataset is between 2003-09-30 and 2003-10-30.
# 2019-05-05 16:12:19,254 - INFO - 22988 - Training a model to be tested between 2003-11-30 and 2003-12-31.
# 2019-05-05 16:12:19,257 - INFO - 22988 - Training dataset is between 2003-10-30 and 2003-11-28.
# 2019-05-05 16:12:19,265 - INFO - 22988 - Training a model to be tested between 2003-12-31 and 2004-01-31.
# 2019-05-05 16:12:19,267 - INFO - 22988 - Training dataset is between 2003-12-01 and 2003-12-30.
# 2019-05-05 16:12:19,274 - INFO - 22988 - Training a model to be tested between 2004-01-31 and 2004-02-29.
# 2019-05-05 16:12:19,276 - INFO - 22988 - Training dataset is between 2003-12-31 and 2004-01-30.
# 2019-05-05 16:12:19,285 - INFO - 22988 - Training a model to be tested between 2004-02-29 and 2004-03-31.
# 2019-05-05 16:12:19,287 - INFO - 22988 - Training dataset is between 2004-01-29 and 2004-02-27.
# 2019-05-05 16:12:19,295 - INFO - 22988 - Training a model to be tested between 2004-03-31 and 2004-04-30.
# 2019-05-05 16:12:19,298 - INFO - 22988 - Training dataset is between 2004-03-01 and 2004-03-30.
# 2019-05-05 16:12:19,306 - INFO - 22988 - Training a model to be tested between 2004-04-30 and 2004-05-31.
# 2019-05-05 16:12:19,308 - INFO - 22988 - Training dataset is between 2004-03-30 and 2004-04-29.
# 2019-05-05 16:12:19,315 - INFO - 22988 - Training a model to be tested between 2004-05-31 and 2004-06-30.
# 2019-05-05 16:12:19,317 - INFO - 22988 - Training dataset is between 2004-04-30 and 2004-05-28.
# 2019-05-05 16:12:19,325 - INFO - 22988 - Training a model to be tested between 2004-06-30 and 2004-07-31.
# 2019-05-05 16:12:19,327 - INFO - 22988 - Training dataset is between 2004-06-01 and 2004-06-29.
# 2019-05-05 16:12:19,335 - INFO - 22988 - Training a model to be tested between 2004-07-31 and 2004-08-31.
# 2019-05-05 16:12:19,338 - INFO - 22988 - Training dataset is between 2004-06-30 and 2004-07-30.
# 2019-05-05 16:12:19,347 - INFO - 22988 - Training a model to be tested between 2004-08-31 and 2004-09-30.
# 2019-05-05 16:12:19,348 - INFO - 22988 - Training dataset is between 2004-08-02 and 2004-08-30.
# 2019-05-05 16:12:19,357 - INFO - 22988 - Training a model to be tested between 2004-09-30 and 2004-10-31.
# 2019-05-05 16:12:19,360 - INFO - 22988 - Training dataset is between 2004-08-30 and 2004-09-29.
# 2019-05-05 16:12:19,368 - INFO - 22988 - Training a model to be tested between 2004-10-31 and 2004-11-30.
# 2019-05-05 16:12:19,370 - INFO - 22988 - Training dataset is between 2004-09-30 and 2004-10-29.
# 2019-05-05 16:12:19,378 - INFO - 22988 - Training a model to be tested between 2004-11-30 and 2004-12-31.
# 2019-05-05 16:12:19,381 - INFO - 22988 - Training dataset is between 2004-11-01 and 2004-11-29.
# 2019-05-05 16:12:19,389 - INFO - 22988 - Training a model to be tested between 2004-12-31 and 2005-01-31.
# 2019-05-05 16:12:19,390 - INFO - 22988 - Training dataset is between 2004-11-30 and 2004-12-30.
# 2019-05-05 16:12:19,399 - INFO - 22988 - Training a model to be tested between 2005-01-31 and 2005-02-28.
# 2019-05-05 16:12:19,401 - INFO - 22988 - Training dataset is between 2004-12-31 and 2005-01-28.
# 2019-05-05 16:12:19,409 - INFO - 22988 - Training a model to be tested between 2005-02-28 and 2005-03-31.
# 2019-05-05 16:12:19,411 - INFO - 22988 - Training dataset is between 2005-01-28 and 2005-02-25.
# 2019-05-05 16:12:19,419 - INFO - 22988 - Training a model to be tested between 2005-03-31 and 2005-04-30.
# 2019-05-05 16:12:19,421 - INFO - 22988 - Training dataset is between 2005-02-28 and 2005-03-30.
# 2019-05-05 16:12:19,429 - INFO - 22988 - Training a model to be tested between 2005-04-30 and 2005-05-31.
# 2019-05-05 16:12:19,431 - INFO - 22988 - Training dataset is between 2005-03-30 and 2005-04-29.
# 2019-05-05 16:12:19,440 - INFO - 22988 - Training a model to be tested between 2005-05-31 and 2005-06-30.
# 2019-05-05 16:12:19,441 - INFO - 22988 - Training dataset is between 2005-05-02 and 2005-05-27.
# 2019-05-05 16:12:19,449 - INFO - 22988 - Training a model to be tested between 2005-06-30 and 2005-07-31.
# 2019-05-05 16:12:19,451 - INFO - 22988 - Training dataset is between 2005-05-31 and 2005-06-29.
# 2019-05-05 16:12:19,459 - INFO - 22988 - Training a model to be tested between 2005-07-31 and 2005-08-31.
# 2019-05-05 16:12:19,462 - INFO - 22988 - Training dataset is between 2005-06-30 and 2005-07-29.
# 2019-05-05 16:12:19,470 - INFO - 22988 - Training a model to be tested between 2005-08-31 and 2005-09-30.
# 2019-05-05 16:12:19,472 - INFO - 22988 - Training dataset is between 2005-08-01 and 2005-08-30.
# 2019-05-05 16:12:19,481 - INFO - 22988 - Training a model to be tested between 2005-09-30 and 2005-10-31.
# 2019-05-05 16:12:19,483 - INFO - 22988 - Training dataset is between 2005-08-30 and 2005-09-29.
# 2019-05-05 16:12:19,491 - INFO - 22988 - Training a model to be tested between 2005-10-31 and 2005-11-30.
# 2019-05-05 16:12:19,493 - INFO - 22988 - Training dataset is between 2005-09-30 and 2005-10-28.
# 2019-05-05 16:12:19,503 - INFO - 22988 - Training a model to be tested between 2005-11-30 and 2005-12-31.
# 2019-05-05 16:12:19,505 - INFO - 22988 - Training dataset is between 2005-10-31 and 2005-11-29.
# 2019-05-05 16:12:19,514 - INFO - 22988 - Training a model to be tested between 2005-12-31 and 2006-01-31.
# 2019-05-05 16:12:19,516 - INFO - 22988 - Training dataset is between 2005-11-30 and 2005-12-30.
# 2019-05-05 16:12:19,524 - INFO - 22988 - Training a model to be tested between 2006-01-31 and 2006-02-28.
# 2019-05-05 16:12:19,526 - INFO - 22988 - Training dataset is between 2006-01-03 and 2006-01-30.
# 2019-05-05 16:12:19,534 - INFO - 22988 - Training a model to be tested between 2006-02-28 and 2006-03-31.
# 2019-05-05 16:12:19,536 - INFO - 22988 - Training dataset is between 2006-01-30 and 2006-02-27.
# 2019-05-05 16:12:19,544 - INFO - 22988 - Training a model to be tested between 2006-03-31 and 2006-04-30.
# 2019-05-05 16:12:19,546 - INFO - 22988 - Training dataset is between 2006-02-28 and 2006-03-30.
# 2019-05-05 16:12:19,554 - INFO - 22988 - Training a model to be tested between 2006-04-30 and 2006-05-31.
# 2019-05-05 16:12:19,557 - INFO - 22988 - Training dataset is between 2006-03-30 and 2006-04-28.
# 2019-05-05 16:12:19,566 - INFO - 22988 - Training a model to be tested between 2006-05-31 and 2006-06-30.
# 2019-05-05 16:12:19,568 - INFO - 22988 - Training dataset is between 2006-05-01 and 2006-05-30.
# 2019-05-05 16:12:19,576 - INFO - 22988 - Training a model to be tested between 2006-06-30 and 2006-07-31.
# 2019-05-05 16:12:19,578 - INFO - 22988 - Training dataset is between 2006-05-30 and 2006-06-29.
# 2019-05-05 16:12:19,586 - INFO - 22988 - Training a model to be tested between 2006-07-31 and 2006-08-31.
# 2019-05-05 16:12:19,588 - INFO - 22988 - Training dataset is between 2006-06-30 and 2006-07-28.
# 2019-05-05 16:12:19,599 - INFO - 22988 - Training a model to be tested between 2006-08-31 and 2006-09-30.
# 2019-05-05 16:12:19,601 - INFO - 22988 - Training dataset is between 2006-07-31 and 2006-08-30.
# 2019-05-05 16:12:19,609 - INFO - 22988 - Training a model to be tested between 2006-09-30 and 2006-10-31.
# 2019-05-05 16:12:19,612 - INFO - 22988 - Training dataset is between 2006-08-30 and 2006-09-29.
# 2019-05-05 16:12:19,622 - INFO - 22988 - Training a model to be tested between 2006-10-31 and 2006-11-30.
# 2019-05-05 16:12:19,625 - INFO - 22988 - Training dataset is between 2006-10-02 and 2006-10-30.
# 2019-05-05 16:12:19,635 - INFO - 22988 - Training a model to be tested between 2006-11-30 and 2006-12-31.
# 2019-05-05 16:12:19,637 - INFO - 22988 - Training dataset is between 2006-10-30 and 2006-11-29.
# 2019-05-05 16:12:19,645 - INFO - 22988 - Training a model to be tested between 2006-12-31 and 2007-01-31.
# 2019-05-05 16:12:19,648 - INFO - 22988 - Training dataset is between 2006-11-30 and 2006-12-29.
# 2019-05-05 16:12:19,657 - INFO - 22988 - Training a model to be tested between 2007-01-31 and 2007-02-28.
# 2019-05-05 16:12:19,660 - INFO - 22988 - Training dataset is between 2007-01-03 and 2007-01-30.
# 2019-05-05 16:12:19,669 - INFO - 22988 - Training a model to be tested between 2007-02-28 and 2007-03-31.
# 2019-05-05 16:12:19,673 - INFO - 22988 - Training dataset is between 2007-01-29 and 2007-02-27.
# 2019-05-05 16:12:19,683 - INFO - 22988 - Training a model to be tested between 2007-03-31 and 2007-04-30.
# 2019-05-05 16:12:19,686 - INFO - 22988 - Training dataset is between 2007-02-28 and 2007-03-30.
# 2019-05-05 16:12:19,696 - INFO - 22988 - Training a model to be tested between 2007-04-30 and 2007-05-31.
# 2019-05-05 16:12:19,699 - INFO - 22988 - Training dataset is between 2007-03-30 and 2007-04-27.
# 2019-05-05 16:12:19,709 - INFO - 22988 - Training a model to be tested between 2007-05-31 and 2007-06-30.
# 2019-05-05 16:12:19,712 - INFO - 22988 - Training dataset is between 2007-04-30 and 2007-05-30.
# 2019-05-05 16:12:19,722 - INFO - 22988 - Training a model to be tested between 2007-06-30 and 2007-07-31.
# 2019-05-05 16:12:19,726 - INFO - 22988 - Training dataset is between 2007-05-30 and 2007-06-29.
# 2019-05-05 16:12:19,735 - INFO - 22988 - Training a model to be tested between 2007-07-31 and 2007-08-31.
# 2019-05-05 16:12:19,737 - INFO - 22988 - Training dataset is between 2007-07-02 and 2007-07-30.
# 2019-05-05 16:12:19,745 - INFO - 22988 - Training a model to be tested between 2007-08-31 and 2007-09-30.
# 2019-05-05 16:12:19,747 - INFO - 22988 - Training dataset is between 2007-07-31 and 2007-08-30.
# 2019-05-05 16:12:19,756 - INFO - 22988 - Training a model to be tested between 2007-09-30 and 2007-10-31.
# 2019-05-05 16:12:19,758 - INFO - 22988 - Training dataset is between 2007-08-30 and 2007-09-28.
# 2019-05-05 16:12:19,766 - INFO - 22988 - Training a model to be tested between 2007-10-31 and 2007-11-30.
# 2019-05-05 16:12:19,769 - INFO - 22988 - Training dataset is between 2007-10-01 and 2007-10-30.
# 2019-05-05 16:12:19,779 - INFO - 22988 - Training a model to be tested between 2007-11-30 and 2007-12-31.
# 2019-05-05 16:12:19,781 - INFO - 22988 - Training dataset is between 2007-10-30 and 2007-11-29.
# 2019-05-05 16:12:19,792 - INFO - 22988 - Training a model to be tested between 2007-12-31 and 2008-01-31.
# 2019-05-05 16:12:19,795 - INFO - 22988 - Training dataset is between 2007-11-30 and 2007-12-28.
# 2019-05-05 16:12:19,806 - INFO - 22988 - Training a model to be tested between 2008-01-31 and 2008-02-29.
# 2019-05-05 16:12:19,808 - INFO - 22988 - Training dataset is between 2007-12-31 and 2008-01-30.
# 2019-05-05 16:12:19,819 - INFO - 22988 - Training a model to be tested between 2008-02-29 and 2008-03-31.
# 2019-05-05 16:12:19,821 - INFO - 22988 - Training dataset is between 2008-01-29 and 2008-02-28.
# 2019-05-05 16:12:19,830 - INFO - 22988 - Training a model to be tested between 2008-03-31 and 2008-04-30.
# 2019-05-05 16:12:19,832 - INFO - 22988 - Training dataset is between 2008-02-29 and 2008-03-28.
# 2019-05-05 16:12:19,842 - INFO - 22988 - Training a model to be tested between 2008-04-30 and 2008-05-31.
# 2019-05-05 16:12:19,845 - INFO - 22988 - Training dataset is between 2008-03-31 and 2008-04-29.
# 2019-05-05 16:12:19,853 - INFO - 22988 - Training a model to be tested between 2008-05-31 and 2008-06-30.
# 2019-05-05 16:12:19,856 - INFO - 22988 - Training dataset is between 2008-04-30 and 2008-05-30.
# 2019-05-05 16:12:19,865 - INFO - 22988 - Training a model to be tested between 2008-06-30 and 2008-07-31.
# 2019-05-05 16:12:19,868 - INFO - 22988 - Training dataset is between 2008-05-30 and 2008-06-27.
# 2019-05-05 16:12:19,876 - INFO - 22988 - Training a model to be tested between 2008-07-31 and 2008-08-31.
# 2019-05-05 16:12:19,879 - INFO - 22988 - Training dataset is between 2008-06-30 and 2008-07-30.
# 2019-05-05 16:12:19,887 - INFO - 22988 - Training a model to be tested between 2008-08-31 and 2008-09-30.
# 2019-05-05 16:12:19,889 - INFO - 22988 - Training dataset is between 2008-07-31 and 2008-08-29.
# 2019-05-05 16:12:19,897 - INFO - 22988 - Training a model to be tested between 2008-09-30 and 2008-10-31.
# 2019-05-05 16:12:19,900 - INFO - 22988 - Training dataset is between 2008-09-02 and 2008-09-29.
# 2019-05-05 16:12:19,910 - INFO - 22988 - Training a model to be tested between 2008-10-31 and 2008-11-30.
# 2019-05-05 16:12:19,912 - INFO - 22988 - Training dataset is between 2008-09-30 and 2008-10-30.
# 2019-05-05 16:12:19,920 - INFO - 22988 - Training a model to be tested between 2008-11-30 and 2008-12-31.
# 2019-05-05 16:12:19,922 - INFO - 22988 - Training dataset is between 2008-10-30 and 2008-11-28.
# 2019-05-05 16:12:19,930 - INFO - 22988 - Training a model to be tested between 2008-12-31 and 2009-01-31.
# 2019-05-05 16:12:19,933 - INFO - 22988 - Training dataset is between 2008-12-01 and 2008-12-30.
# 2019-05-05 16:12:19,941 - INFO - 22988 - Training a model to be tested between 2009-01-31 and 2009-02-28.
# 2019-05-05 16:12:19,943 - INFO - 22988 - Training dataset is between 2008-12-31 and 2009-01-30.
# 2019-05-05 16:12:19,951 - INFO - 22988 - Training a model to be tested between 2009-02-28 and 2009-03-31.
# 2019-05-05 16:12:19,953 - INFO - 22988 - Training dataset is between 2009-01-28 and 2009-02-27.
# 2019-05-05 16:12:19,961 - INFO - 22988 - Training a model to be tested between 2009-03-31 and 2009-04-30.
# 2019-05-05 16:12:19,963 - INFO - 22988 - Training dataset is between 2009-03-02 and 2009-03-30.
# 2019-05-05 16:12:19,971 - INFO - 22988 - Training a model to be tested between 2009-04-30 and 2009-05-31.
# 2019-05-05 16:12:19,974 - INFO - 22988 - Training dataset is between 2009-03-30 and 2009-04-29.
# 2019-05-05 16:12:19,982 - INFO - 22988 - Training a model to be tested between 2009-05-31 and 2009-06-30.
# 2019-05-05 16:12:19,984 - INFO - 22988 - Training dataset is between 2009-04-30 and 2009-05-29.
# 2019-05-05 16:12:19,993 - INFO - 22988 - Training a model to be tested between 2009-06-30 and 2009-07-31.
# 2019-05-05 16:12:19,995 - INFO - 22988 - Training dataset is between 2009-06-01 and 2009-06-29.
# 2019-05-05 16:12:20,002 - INFO - 22988 - Training a model to be tested between 2009-07-31 and 2009-08-31.
# 2019-05-05 16:12:20,004 - INFO - 22988 - Training dataset is between 2009-06-30 and 2009-07-30.
# 2019-05-05 16:12:20,013 - INFO - 22988 - Training a model to be tested between 2009-08-31 and 2009-09-30.
# 2019-05-05 16:12:20,015 - INFO - 22988 - Training dataset is between 2009-07-31 and 2009-08-28.
# 2019-05-05 16:12:20,023 - INFO - 22988 - Training a model to be tested between 2009-09-30 and 2009-10-31.
# 2019-05-05 16:12:20,024 - INFO - 22988 - Training dataset is between 2009-08-31 and 2009-09-29.
# 2019-05-05 16:12:20,034 - INFO - 22988 - Training a model to be tested between 2009-10-31 and 2009-11-30.
# 2019-05-05 16:12:20,036 - INFO - 22988 - Training dataset is between 2009-09-30 and 2009-10-30.
# 2019-05-05 16:12:20,044 - INFO - 22988 - Training a model to be tested between 2009-11-30 and 2009-12-31.
# 2019-05-05 16:12:20,046 - INFO - 22988 - Training dataset is between 2009-10-30 and 2009-11-27.
# 2019-05-05 16:12:20,055 - INFO - 22988 - Training a model to be tested between 2009-12-31 and 2010-01-31.
# 2019-05-05 16:12:20,057 - INFO - 22988 - Training dataset is between 2009-11-30 and 2009-12-30.
# 2019-05-05 16:12:20,065 - INFO - 22988 - Training a model to be tested between 2010-01-31 and 2010-02-28.
# 2019-05-05 16:12:20,067 - INFO - 22988 - Training dataset is between 2009-12-31 and 2010-01-29.
# 2019-05-05 16:12:20,076 - INFO - 22988 - Training a model to be tested between 2010-02-28 and 2010-03-31.
# 2019-05-05 16:12:20,078 - INFO - 22988 - Training dataset is between 2010-01-28 and 2010-02-26.
# 2019-05-05 16:12:20,086 - INFO - 22988 - Training a model to be tested between 2010-03-31 and 2010-04-30.
# 2019-05-05 16:12:20,088 - INFO - 22988 - Training dataset is between 2010-03-01 and 2010-03-30.
# 2019-05-05 16:12:20,097 - INFO - 22988 - Training a model to be tested between 2010-04-30 and 2010-05-31.
# 2019-05-05 16:12:20,099 - INFO - 22988 - Training dataset is between 2010-03-30 and 2010-04-29.
# 2019-05-05 16:12:20,108 - INFO - 22988 - Training a model to be tested between 2010-05-31 and 2010-06-30.
# 2019-05-05 16:12:20,109 - INFO - 22988 - Training dataset is between 2010-04-30 and 2010-05-28.
# 2019-05-05 16:12:20,118 - INFO - 22988 - Training a model to be tested between 2010-06-30 and 2010-07-31.
# 2019-05-05 16:12:20,119 - INFO - 22988 - Training dataset is between 2010-06-01 and 2010-06-29.
# 2019-05-05 16:12:20,128 - INFO - 22988 - Training a model to be tested between 2010-07-31 and 2010-08-31.
# 2019-05-05 16:12:20,131 - INFO - 22988 - Training dataset is between 2010-06-30 and 2010-07-30.
# 2019-05-05 16:12:20,139 - INFO - 22988 - Training a model to be tested between 2010-08-31 and 2010-09-30.
# 2019-05-05 16:12:20,141 - INFO - 22988 - Training dataset is between 2010-08-02 and 2010-08-30.
# 2019-05-05 16:12:20,149 - INFO - 22988 - Training a model to be tested between 2010-09-30 and 2010-10-31.
# 2019-05-05 16:12:20,151 - INFO - 22988 - Training dataset is between 2010-08-30 and 2010-09-29.
# 2019-05-05 16:12:20,160 - INFO - 22988 - Training a model to be tested between 2010-10-31 and 2010-11-30.
# 2019-05-05 16:12:20,161 - INFO - 22988 - Training dataset is between 2010-09-30 and 2010-10-29.
# 2019-05-05 16:12:20,170 - INFO - 22988 - Training a model to be tested between 2010-11-30 and 2010-12-31.
# 2019-05-05 16:12:20,172 - INFO - 22988 - Training dataset is between 2010-11-01 and 2010-11-29.
# 2019-05-05 16:12:20,180 - INFO - 22988 - Training a model to be tested between 2010-12-31 and 2011-01-31.
# 2019-05-05 16:12:20,182 - INFO - 22988 - Training dataset is between 2010-11-30 and 2010-12-30.
# 2019-05-05 16:12:20,191 - INFO - 22988 - Training a model to be tested between 2011-01-31 and 2011-02-28.
# 2019-05-05 16:12:20,193 - INFO - 22988 - Training dataset is between 2010-12-31 and 2011-01-28.
# 2019-05-05 16:12:20,202 - INFO - 22988 - Training a model to be tested between 2011-02-28 and 2011-03-31.
# 2019-05-05 16:12:20,204 - INFO - 22988 - Training dataset is between 2011-01-28 and 2011-02-25.
# 2019-05-05 16:12:20,213 - INFO - 22988 - Training a model to be tested between 2011-03-31 and 2011-04-30.
# 2019-05-05 16:12:20,215 - INFO - 22988 - Training dataset is between 2011-02-28 and 2011-03-30.
# 2019-05-05 16:12:20,223 - INFO - 22988 - Training a model to be tested between 2011-04-30 and 2011-05-31.
# 2019-05-05 16:12:20,226 - INFO - 22988 - Training dataset is between 2011-03-30 and 2011-04-29.
# 2019-05-05 16:12:20,236 - INFO - 22988 - Training a model to be tested between 2011-05-31 and 2011-06-30.
# 2019-05-05 16:12:20,238 - INFO - 22988 - Training dataset is between 2011-05-02 and 2011-05-27.
# 2019-05-05 16:12:20,246 - INFO - 22988 - Training a model to be tested between 2011-06-30 and 2011-07-31.
# 2019-05-05 16:12:20,249 - INFO - 22988 - Training dataset is between 2011-05-31 and 2011-06-29.
# 2019-05-05 16:12:20,257 - INFO - 22988 - Training a model to be tested between 2011-07-31 and 2011-08-31.
# 2019-05-05 16:12:20,259 - INFO - 22988 - Training dataset is between 2011-06-30 and 2011-07-29.
# 2019-05-05 16:12:20,268 - INFO - 22988 - Training a model to be tested between 2011-08-31 and 2011-09-30.
# 2019-05-05 16:12:20,270 - INFO - 22988 - Training dataset is between 2011-08-01 and 2011-08-30.
# 2019-05-05 16:12:20,278 - INFO - 22988 - Training a model to be tested between 2011-09-30 and 2011-10-31.
# 2019-05-05 16:12:20,280 - INFO - 22988 - Training dataset is between 2011-08-30 and 2011-09-29.
# 2019-05-05 16:12:20,288 - INFO - 22988 - Training a model to be tested between 2011-10-31 and 2011-11-30.
# 2019-05-05 16:12:20,290 - INFO - 22988 - Training dataset is between 2011-09-30 and 2011-10-28.
# 2019-05-05 16:12:20,299 - INFO - 22988 - Training a model to be tested between 2011-11-30 and 2011-12-31.
# 2019-05-05 16:12:20,302 - INFO - 22988 - Training dataset is between 2011-10-31 and 2011-11-29.
# 2019-05-05 16:12:20,310 - INFO - 22988 - Training a model to be tested between 2011-12-31 and 2012-01-31.
# 2019-05-05 16:12:20,313 - INFO - 22988 - Training dataset is between 2011-11-30 and 2011-12-30.
# 2019-05-05 16:12:20,321 - INFO - 22988 - Training a model to be tested between 2012-01-31 and 2012-02-29.
# 2019-05-05 16:12:20,324 - INFO - 22988 - Training dataset is between 2012-01-03 and 2012-01-30.
# 2019-05-05 16:12:20,333 - INFO - 22988 - Training a model to be tested between 2012-02-29 and 2012-03-31.
# 2019-05-05 16:12:20,335 - INFO - 22988 - Training dataset is between 2012-01-30 and 2012-02-28.
# 2019-05-05 16:12:20,343 - INFO - 22988 - Training a model to be tested between 2012-03-31 and 2012-04-30.
# 2019-05-05 16:12:20,345 - INFO - 22988 - Training dataset is between 2012-02-29 and 2012-03-30.
# 2019-05-05 16:12:20,354 - INFO - 22988 - Training a model to be tested between 2012-04-30 and 2012-05-31.
# 2019-05-05 16:12:20,356 - INFO - 22988 - Training dataset is between 2012-03-30 and 2012-04-27.
# 2019-05-05 16:12:20,364 - INFO - 22988 - Training a model to be tested between 2012-05-31 and 2012-06-30.
# 2019-05-05 16:12:20,366 - INFO - 22988 - Training dataset is between 2012-04-30 and 2012-05-30.
# 2019-05-05 16:12:20,374 - INFO - 22988 - Training a model to be tested between 2012-06-30 and 2012-07-31.
# 2019-05-05 16:12:20,376 - INFO - 22988 - Training dataset is between 2012-05-30 and 2012-06-29.
# 2019-05-05 16:12:20,384 - INFO - 22988 - Training a model to be tested between 2012-07-31 and 2012-08-31.
# 2019-05-05 16:12:20,385 - INFO - 22988 - Training dataset is between 2012-07-02 and 2012-07-30.
# 2019-05-05 16:12:20,394 - INFO - 22988 - Training a model to be tested between 2012-08-31 and 2012-09-30.
# 2019-05-05 16:12:20,396 - INFO - 22988 - Training dataset is between 2012-07-31 and 2012-08-30.
# 2019-05-05 16:12:20,404 - INFO - 22988 - Training a model to be tested between 2012-09-30 and 2012-10-31.
# 2019-05-05 16:12:20,406 - INFO - 22988 - Training dataset is between 2012-08-30 and 2012-09-28.
# 2019-05-05 16:12:20,415 - INFO - 22988 - Training a model to be tested between 2012-10-31 and 2012-11-30.
# 2019-05-05 16:12:20,417 - INFO - 22988 - Training dataset is between 2012-10-01 and 2012-10-26.
# 2019-05-05 16:12:20,425 - INFO - 22988 - Training a model to be tested between 2012-11-30 and 2012-12-31.
# 2019-05-05 16:12:20,428 - INFO - 22988 - Training dataset is between 2012-10-31 and 2012-11-29.
# 2019-05-05 16:12:20,436 - INFO - 22988 - Training a model to be tested between 2012-12-31 and 2013-01-31.
# 2019-05-05 16:12:20,439 - INFO - 22988 - Training dataset is between 2012-11-30 and 2012-12-28.
# 2019-05-05 16:12:20,447 - INFO - 22988 - Training a model to be tested between 2013-01-31 and 2013-02-28.
# 2019-05-05 16:12:20,449 - INFO - 22988 - Training dataset is between 2012-12-31 and 2013-01-30.
# 2019-05-05 16:12:20,458 - INFO - 22988 - Training a model to be tested between 2013-02-28 and 2013-03-31.
# 2019-05-05 16:12:20,460 - INFO - 22988 - Training dataset is between 2013-01-28 and 2013-02-27.
# 2019-05-05 16:12:20,467 - INFO - 22988 - Training a model to be tested between 2013-03-31 and 2013-04-30.
# 2019-05-05 16:12:20,469 - INFO - 22988 - Training dataset is between 2013-02-28 and 2013-03-28.
# 2019-05-05 16:12:20,477 - INFO - 22988 - Training a model to be tested between 2013-04-30 and 2013-05-31.
# 2019-05-05 16:12:20,480 - INFO - 22988 - Training dataset is between 2013-04-01 and 2013-04-29.
# 2019-05-05 16:12:20,488 - INFO - 22988 - Training a model to be tested between 2013-05-31 and 2013-06-30.
# 2019-05-05 16:12:20,490 - INFO - 22988 - Training dataset is between 2013-04-30 and 2013-05-30.
# 2019-05-05 16:12:20,499 - INFO - 22988 - Training a model to be tested between 2013-06-30 and 2013-07-31.
# 2019-05-05 16:12:20,501 - INFO - 22988 - Training dataset is between 2013-05-30 and 2013-06-28.
# 2019-05-05 16:12:20,509 - INFO - 22988 - Training a model to be tested between 2013-07-31 and 2013-08-31.
# 2019-05-05 16:12:20,512 - INFO - 22988 - Training dataset is between 2013-07-01 and 2013-07-30.
# 2019-05-05 16:12:20,521 - INFO - 22988 - Training a model to be tested between 2013-08-31 and 2013-09-30.
# 2019-05-05 16:12:20,523 - INFO - 22988 - Training dataset is between 2013-07-31 and 2013-08-30.
# 2019-05-05 16:12:20,531 - INFO - 22988 - Training a model to be tested between 2013-09-30 and 2013-10-31.
# 2019-05-05 16:12:20,533 - INFO - 22988 - Training dataset is between 2013-08-30 and 2013-09-27.
# 2019-05-05 16:12:20,541 - INFO - 22988 - Training a model to be tested between 2013-10-31 and 2013-11-30.
# 2019-05-05 16:12:20,543 - INFO - 22988 - Training dataset is between 2013-09-30 and 2013-10-30.
# 2019-05-05 16:12:20,551 - INFO - 22988 - Training a model to be tested between 2013-11-30 and 2013-12-31.
# 2019-05-05 16:12:20,553 - INFO - 22988 - Training dataset is between 2013-10-30 and 2013-11-29.
# 2019-05-05 16:12:20,561 - INFO - 22988 - Training a model to be tested between 2013-12-31 and 2014-01-31.
# 2019-05-05 16:12:20,563 - INFO - 22988 - Training dataset is between 2013-12-02 and 2013-12-30.
# 2019-05-05 16:12:20,573 - INFO - 22988 - Training a model to be tested between 2014-01-31 and 2014-02-28.
# 2019-05-05 16:12:20,575 - INFO - 22988 - Training dataset is between 2013-12-31 and 2014-01-30.
# 2019-05-05 16:12:20,583 - INFO - 22988 - Training a model to be tested between 2014-02-28 and 2014-03-31.
# 2019-05-05 16:12:20,585 - INFO - 22988 - Training dataset is between 2014-01-28 and 2014-02-27.
# 2019-05-05 16:12:20,594 - INFO - 22988 - Training a model to be tested between 2014-03-31 and 2014-04-30.
# 2019-05-05 16:12:20,596 - INFO - 22988 - Training dataset is between 2014-02-28 and 2014-03-28.
# 2019-05-05 16:12:20,604 - INFO - 22988 - Training a model to be tested between 2014-04-30 and 2014-05-31.
# 2019-05-05 16:12:20,606 - INFO - 22988 - Training dataset is between 2014-03-31 and 2014-04-29.
# 2019-05-05 16:12:20,616 - INFO - 22988 - Training a model to be tested between 2014-05-31 and 2014-06-30.
# 2019-05-05 16:12:20,618 - INFO - 22988 - Training dataset is between 2014-04-30 and 2014-05-30.
# 2019-05-05 16:12:20,626 - INFO - 22988 - Training a model to be tested between 2014-06-30 and 2014-07-31.
# 2019-05-05 16:12:20,628 - INFO - 22988 - Training dataset is between 2014-05-30 and 2014-06-27.
# 2019-05-05 16:12:20,636 - INFO - 22988 - Training a model to be tested between 2014-07-31 and 2014-08-31.
# 2019-05-05 16:12:20,638 - INFO - 22988 - Training dataset is between 2014-06-30 and 2014-07-30.
# 2019-05-05 16:12:20,646 - INFO - 22988 - Training a model to be tested between 2014-08-31 and 2014-09-30.
# 2019-05-05 16:12:20,648 - INFO - 22988 - Training dataset is between 2014-07-31 and 2014-08-29.
# 2019-05-05 16:12:20,657 - INFO - 22988 - Training a model to be tested between 2014-09-30 and 2014-10-31.
# 2019-05-05 16:12:20,658 - INFO - 22988 - Training dataset is between 2014-09-02 and 2014-09-29.
# 2019-05-05 16:12:20,667 - INFO - 22988 - Training a model to be tested between 2014-10-31 and 2014-11-30.
# 2019-05-05 16:12:20,669 - INFO - 22988 - Training dataset is between 2014-09-30 and 2014-10-30.
# 2019-05-05 16:12:20,677 - INFO - 22988 - Training a model to be tested between 2014-11-30 and 2014-12-31.
# 2019-05-05 16:12:20,679 - INFO - 22988 - Training dataset is between 2014-10-30 and 2014-11-28.
# 2019-05-05 16:12:20,687 - INFO - 22988 - Training a model to be tested between 2014-12-31 and 2015-01-31.
# 2019-05-05 16:12:20,689 - INFO - 22988 - Training dataset is between 2014-12-01 and 2014-12-30.
# 2019-05-05 16:12:20,698 - INFO - 22988 - Training a model to be tested between 2015-01-31 and 2015-02-28.
# 2019-05-05 16:12:20,700 - INFO - 22988 - Training dataset is between 2014-12-31 and 2015-01-30.
# 2019-05-05 16:12:20,708 - INFO - 22988 - Training a model to be tested between 2015-02-28 and 2015-03-31.
# 2019-05-05 16:12:20,710 - INFO - 22988 - Training dataset is between 2015-01-28 and 2015-02-27.
# 2019-05-05 16:12:20,719 - INFO - 22988 - Training a model to be tested between 2015-03-31 and 2015-04-30.
# 2019-05-05 16:12:20,722 - INFO - 22988 - Training dataset is between 2015-03-02 and 2015-03-30.
# 2019-05-05 16:12:20,730 - INFO - 22988 - Training a model to be tested between 2015-04-30 and 2015-05-31.
# 2019-05-05 16:12:20,732 - INFO - 22988 - Training dataset is between 2015-03-30 and 2015-04-29.
# 2019-05-05 16:12:20,741 - INFO - 22988 - Training a model to be tested between 2015-05-31 and 2015-06-30.
# 2019-05-05 16:12:20,743 - INFO - 22988 - Training dataset is between 2015-04-30 and 2015-05-29.
# 2019-05-05 16:12:20,751 - INFO - 22988 - Training a model to be tested between 2015-06-30 and 2015-07-31.
# 2019-05-05 16:12:20,754 - INFO - 22988 - Training dataset is between 2015-06-01 and 2015-06-29.
# 2019-05-05 16:12:20,763 - INFO - 22988 - Training a model to be tested between 2015-07-31 and 2015-08-31.
# 2019-05-05 16:12:20,765 - INFO - 22988 - Training dataset is between 2015-06-30 and 2015-07-30.
# 2019-05-05 16:12:20,773 - INFO - 22988 - Training a model to be tested between 2015-08-31 and 2015-09-30.
# 2019-05-05 16:12:20,775 - INFO - 22988 - Training dataset is between 2015-07-31 and 2015-08-28.
# 2019-05-05 16:12:20,783 - INFO - 22988 - Training a model to be tested between 2015-09-30 and 2015-10-31.
# 2019-05-05 16:12:20,785 - INFO - 22988 - Training dataset is between 2015-08-31 and 2015-09-29.
# 2019-05-05 16:12:20,794 - INFO - 22988 - Training a model to be tested between 2015-10-31 and 2015-11-30.
# 2019-05-05 16:12:20,796 - INFO - 22988 - Training dataset is between 2015-09-30 and 2015-10-30.
# 2019-05-05 16:12:20,806 - INFO - 22988 - Training a model to be tested between 2015-11-30 and 2015-12-31.
# 2019-05-05 16:12:20,808 - INFO - 22988 - Training dataset is between 2015-10-30 and 2015-11-27.
# 2019-05-05 16:12:20,818 - INFO - 22988 - Training a model to be tested between 2015-12-31 and 2016-01-31.
# 2019-05-05 16:12:20,820 - INFO - 22988 - Training dataset is between 2015-11-30 and 2015-12-30.
# 2019-05-05 16:12:20,828 - INFO - 22988 - Training a model to be tested between 2016-01-31 and 2016-02-29.
# 2019-05-05 16:12:20,830 - INFO - 22988 - Training dataset is between 2015-12-31 and 2016-01-29.
# 2019-05-05 16:12:20,840 - INFO - 22988 - Training a model to be tested between 2016-02-29 and 2016-03-31.
# 2019-05-05 16:12:20,843 - INFO - 22988 - Training dataset is between 2016-01-29 and 2016-02-26.
# 2019-05-05 16:12:20,850 - INFO - 22988 - Training a model to be tested between 2016-03-31 and 2016-04-30.
# 2019-05-05 16:12:20,852 - INFO - 22988 - Training dataset is between 2016-02-29 and 2016-03-30.
# 2019-05-05 16:12:20,861 - INFO - 22988 - Training a model to be tested between 2016-04-30 and 2016-05-31.
# 2019-05-05 16:12:20,863 - INFO - 22988 - Training dataset is between 2016-03-30 and 2016-04-29.
# 2019-05-05 16:12:20,872 - INFO - 22988 - Training a model to be tested between 2016-05-31 and 2016-06-30.
# 2019-05-05 16:12:20,874 - INFO - 22988 - Training dataset is between 2016-05-02 and 2016-05-27.
# 2019-05-05 16:12:20,883 - INFO - 22988 - Training a model to be tested between 2016-06-30 and 2016-07-31.
# 2019-05-05 16:12:20,886 - INFO - 22988 - Training dataset is between 2016-05-31 and 2016-06-29.
# 2019-05-05 16:12:20,894 - INFO - 22988 - Training a model to be tested between 2016-07-31 and 2016-08-31.
# 2019-05-05 16:12:20,896 - INFO - 22988 - Training dataset is between 2016-06-30 and 2016-07-29.
# 2019-05-05 16:12:20,905 - INFO - 22988 - Training a model to be tested between 2016-08-31 and 2016-09-30.
# 2019-05-05 16:12:20,907 - INFO - 22988 - Training dataset is between 2016-08-01 and 2016-08-30.
# 2019-05-05 16:12:20,915 - INFO - 22988 - Training a model to be tested between 2016-09-30 and 2016-10-31.
# 2019-05-05 16:12:20,917 - INFO - 22988 - Training dataset is between 2016-08-30 and 2016-09-29.
# 2019-05-05 16:12:20,925 - INFO - 22988 - Training a model to be tested between 2016-10-31 and 2016-11-30.
# 2019-05-05 16:12:20,927 - INFO - 22988 - Training dataset is between 2016-09-30 and 2016-10-28.
# 2019-05-05 16:12:20,936 - INFO - 22988 - Training a model to be tested between 2016-11-30 and 2016-12-31.
# 2019-05-05 16:12:20,939 - INFO - 22988 - Training dataset is between 2016-10-31 and 2016-11-29.
# 2019-05-05 16:12:20,948 - INFO - 22988 - Training a model to be tested between 2016-12-31 and 2017-01-31.
# 2019-05-05 16:12:20,950 - INFO - 22988 - Training dataset is between 2016-11-30 and 2016-12-30.
# 2019-05-05 16:12:20,959 - INFO - 22988 - Training a model to be tested between 2017-01-31 and 2017-02-28.
# 2019-05-05 16:12:20,961 - INFO - 22988 - Training dataset is between 2017-01-03 and 2017-01-30.
# 2019-05-05 16:12:20,970 - INFO - 22988 - Training a model to be tested between 2017-02-28 and 2017-03-31.
# 2019-05-05 16:12:20,974 - INFO - 22988 - Training dataset is between 2017-01-30 and 2017-02-27.
# 2019-05-05 16:12:20,983 - INFO - 22988 - Training a model to be tested between 2017-03-31 and 2017-04-30.
# 2019-05-05 16:12:20,985 - INFO - 22988 - Training dataset is between 2017-02-28 and 2017-03-30.
# 2019-05-05 16:12:20,994 - INFO - 22988 - Training a model to be tested between 2017-04-30 and 2017-05-31.
# 2019-05-05 16:12:20,996 - INFO - 22988 - Training dataset is between 2017-03-30 and 2017-04-28.
# 2019-05-05 16:12:21,005 - INFO - 22988 - Training a model to be tested between 2017-05-31 and 2017-06-30.
# 2019-05-05 16:12:21,007 - INFO - 22988 - Training dataset is between 2017-05-01 and 2017-05-30.
# 2019-05-05 16:12:21,017 - INFO - 22988 - Training a model to be tested between 2017-06-30 and 2017-07-31.
# 2019-05-05 16:12:21,019 - INFO - 22988 - Training dataset is between 2017-05-30 and 2017-06-29.
# 2019-05-05 16:12:21,027 - INFO - 22988 - Training a model to be tested between 2017-07-31 and 2017-08-31.
# 2019-05-05 16:12:21,029 - INFO - 22988 - Training dataset is between 2017-06-30 and 2017-07-28.
# 2019-05-05 16:12:21,039 - INFO - 22988 - Training a model to be tested between 2017-08-31 and 2017-09-30.
# 2019-05-05 16:12:21,041 - INFO - 22988 - Training dataset is between 2017-07-31 and 2017-08-30.
# 2019-05-05 16:12:21,050 - INFO - 22988 - Training a model to be tested between 2017-09-30 and 2017-10-31.
# 2019-05-05 16:12:21,052 - INFO - 22988 - Training dataset is between 2017-08-30 and 2017-09-29.
# 2019-05-05 16:12:21,060 - INFO - 22988 - Training a model to be tested between 2017-10-31 and 2017-11-30.
# 2019-05-05 16:12:21,063 - INFO - 22988 - Training dataset is between 2017-10-02 and 2017-10-30.
# 2019-05-05 16:12:21,071 - INFO - 22988 - Training a model to be tested between 2017-11-30 and 2017-12-31.
# 2019-05-05 16:12:21,074 - INFO - 22988 - Training dataset is between 2017-10-30 and 2017-11-29.
# 2019-05-05 16:12:21,083 - INFO - 22988 - Training a model to be tested between 2017-12-31 and 2018-01-31.
# 2019-05-05 16:12:21,085 - INFO - 22988 - Training dataset is between 2017-11-30 and 2017-12-29.
# 2019-05-05 16:12:21,094 - INFO - 22988 - Training a model to be tested between 2018-01-31 and 2018-02-28.
# 2019-05-05 16:12:21,096 - INFO - 22988 - Training dataset is between 2018-01-02 and 2018-01-30.
# 2019-05-05 16:12:21,105 - INFO - 22988 - Training a model to be tested between 2018-02-28 and 2018-03-31.
# 2019-05-05 16:12:21,107 - INFO - 22988 - Training dataset is between 2018-01-29 and 2018-02-27.
# 2019-05-05 16:12:21,117 - INFO - 22988 - Training a model to be tested between 2018-03-31 and 2018-04-30.
# 2019-05-05 16:12:21,120 - INFO - 22988 - Training dataset is between 2018-02-28 and 2018-03-29.
# 2019-05-05 16:12:21,130 - INFO - 22988 - Training a model to be tested between 2018-04-30 and 2018-05-31.
# 2019-05-05 16:12:21,132 - INFO - 22988 - Training dataset is between 2018-04-02 and 2018-04-27.
# 2019-05-05 16:12:21,141 - INFO - 22988 - Training a model to be tested between 2018-05-31 and 2018-06-30.
# 2019-05-05 16:12:21,144 - INFO - 22988 - Training dataset is between 2018-04-30 and 2018-05-30.
# 2019-05-05 16:12:21,152 - INFO - 22988 - Training a model to be tested between 2018-06-30 and 2018-07-31.
# 2019-05-05 16:12:21,154 - INFO - 22988 - Training dataset is between 2018-05-30 and 2018-06-29.
# 2019-05-05 16:12:21,163 - INFO - 22988 - Training a model to be tested between 2018-07-31 and 2018-08-31.
# 2019-05-05 16:12:21,165 - INFO - 22988 - Training dataset is between 2018-07-02 and 2018-07-30.
# 2019-05-05 16:12:21,174 - INFO - 22988 - Training a model to be tested between 2018-08-31 and 2018-09-30.
# 2019-05-05 16:12:21,177 - INFO - 22988 - Training dataset is between 2018-07-31 and 2018-08-30.
# 2019-05-05 16:12:21,185 - INFO - 22988 - Training a model to be tested between 2018-09-30 and 2018-10-31.
# 2019-05-05 16:12:21,187 - INFO - 22988 - Training dataset is between 2018-08-30 and 2018-09-28.
# 2019-05-05 16:12:21,196 - INFO - 22988 - Training a model to be tested between 2018-10-31 and 2018-11-30.
# 2019-05-05 16:12:21,197 - INFO - 22988 - Training dataset is between 2018-10-01 and 2018-10-30.
# 2019-05-05 16:12:21,205 - INFO - 22988 - Training a model to be tested between 2018-11-30 and 2018-12-31.
# 2019-05-05 16:12:21,209 - INFO - 22988 - Training dataset is between 2018-10-30 and 2018-11-29.

# %%
get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, with_benchmark=True, with_delta=True)
# Out:
#                       main     benchmark         delta
# alpha             0.549535 -3.322314e-16           NaN
# beta             -0.055703  1.000000e+00           NaN
# cagr              0.694489  5.047234e-02      0.644017
# max_drawdown     -0.194069 -5.518942e-01      0.357825
# return        21152.394548  1.534235e+00  21150.860313
# sharpe            2.885469  3.527034e-01      2.532765
# var              -0.014543 -1.925716e-02      0.004714
# volatility        0.189144  1.916436e-01     -0.002499

# %% [markdown]
# Yes, it is a 69.44% CAGR. We are on the same page.
# For future comparison, lets do exactly the same, but starting the backtest on march and take 2 month of history
# to train the model.

# %%
x_vars = ['open_adj', 'low_adj', 'high_adj']
y_var = 'close_adj_shift_20'
buy_price_col = 'close_adj'
sell_price_col = 'close_adj_shift_1'
model_class = LinearRegression
model_params = {'fit_intercept': True}

df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
    buy_price_col=buy_price_col, sell_price_col=sell_price_col,
    model_class=model_class, model_params=model_params, 
    backtest_start='2000-03-01', backtest_end='2018-12-31', 
    model_update_frequency='M', train_history_period=relativedelta(months=2),
)
# Out:
# 2019-05-06 10:58:38,038 - DEBUG - 22988 - 227 periods to backtest: ['2000-03-01', '2000-03-31', '2000-04-30', '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31', '2000-09-30', '2000-10-31', '2000-11-30', '2000-12-31', '2001-01-31', '2001-02-28', '2001-03-31', '2001-04-30', '2001-05-31', '2001-06-30', '2001-07-31', '2001-08-31', '2001-09-30', '2001-10-31', '2001-11-30', '2001-12-31', '2002-01-31', '2002-02-28', '2002-03-31', '2002-04-30', '2002-05-31', '2002-06-30', '2002-07-31', '2002-08-31', '2002-09-30', '2002-10-31', '2002-11-30', '2002-12-31', '2003-01-31', '2003-02-28', '2003-03-31', '2003-04-30', '2003-05-31', '2003-06-30', '2003-07-31', '2003-08-31', '2003-09-30', '2003-10-31', '2003-11-30', '2003-12-31', '2004-01-31', '2004-02-29', '2004-03-31', '2004-04-30', '2004-05-31', '2004-06-30', '2004-07-31', '2004-08-31', '2004-09-30', '2004-10-31', '2004-11-30', '2004-12-31', '2005-01-31', '2005-02-28', '2005-03-31', '2005-04-30', '2005-05-31', '2005-06-30', '2005-07-31', '2005-08-31', '2005-09-30', '2005-10-31', '2005-11-30', '2005-12-31', '2006-01-31', '2006-02-28', '2006-03-31', '2006-04-30', '2006-05-31', '2006-06-30', '2006-07-31', '2006-08-31', '2006-09-30', '2006-10-31', '2006-11-30', '2006-12-31', '2007-01-31', '2007-02-28', '2007-03-31', '2007-04-30', '2007-05-31', '2007-06-30', '2007-07-31', '2007-08-31', '2007-09-30', '2007-10-31', '2007-11-30', '2007-12-31', '2008-01-31', '2008-02-29', '2008-03-31', '2008-04-30', '2008-05-31', '2008-06-30', '2008-07-31', '2008-08-31', '2008-09-30', '2008-10-31', '2008-11-30', '2008-12-31', '2009-01-31', '2009-02-28', '2009-03-31', '2009-04-30', '2009-05-31', '2009-06-30', '2009-07-31', '2009-08-31', '2009-09-30', '2009-10-31', '2009-11-30', '2009-12-31', '2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30', '2010-05-31', '2010-06-30', '2010-07-31', '2010-08-31', '2010-09-30', '2010-10-31', '2010-11-30', '2010-12-31', '2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30', '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31', '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31', '2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30', '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31', '2012-09-30', '2012-10-31', '2012-11-30', '2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31'].
# 2019-05-06 10:58:38,038 - INFO - 22988 - Training a model to be tested between 2000-03-01 and 2000-03-31.
# 2019-05-06 10:58:38,040 - INFO - 22988 - Training dataset is between 2000-01-03 and 2000-02-29.
# 2019-05-06 10:58:38,048 - INFO - 22988 - Training a model to be tested between 2000-03-31 and 2000-04-30.
# 2019-05-06 10:58:38,050 - INFO - 22988 - Training dataset is between 2000-01-31 and 2000-03-30.
# 2019-05-06 10:58:38,058 - INFO - 22988 - Training a model to be tested between 2000-04-30 and 2000-05-31.
# 2019-05-06 10:58:38,059 - INFO - 22988 - Training dataset is between 2000-02-29 and 2000-04-28.
# 2019-05-06 10:58:38,068 - INFO - 22988 - Training a model to be tested between 2000-05-31 and 2000-06-30.
# 2019-05-06 10:58:38,070 - INFO - 22988 - Training dataset is between 2000-03-31 and 2000-05-30.
# 2019-05-06 10:58:38,078 - INFO - 22988 - Training a model to be tested between 2000-06-30 and 2000-07-31.
# 2019-05-06 10:58:38,081 - INFO - 22988 - Training dataset is between 2000-05-01 and 2000-06-29.
# 2019-05-06 10:58:38,091 - INFO - 22988 - Training a model to be tested between 2000-07-31 and 2000-08-31.
# 2019-05-06 10:58:38,093 - INFO - 22988 - Training dataset is between 2000-05-31 and 2000-07-28.
# 2019-05-06 10:58:38,102 - INFO - 22988 - Training a model to be tested between 2000-08-31 and 2000-09-30.
# 2019-05-06 10:58:38,105 - INFO - 22988 - Training dataset is between 2000-06-30 and 2000-08-30.
# 2019-05-06 10:58:38,114 - INFO - 22988 - Training a model to be tested between 2000-09-30 and 2000-10-31.
# 2019-05-06 10:58:38,117 - INFO - 22988 - Training dataset is between 2000-07-31 and 2000-09-29.
# 2019-05-06 10:58:38,127 - INFO - 22988 - Training a model to be tested between 2000-10-31 and 2000-11-30.
# 2019-05-06 10:58:38,129 - INFO - 22988 - Training dataset is between 2000-08-31 and 2000-10-30.
# 2019-05-06 10:58:38,139 - INFO - 22988 - Training a model to be tested between 2000-11-30 and 2000-12-31.
# 2019-05-06 10:58:38,142 - INFO - 22988 - Training dataset is between 2000-10-02 and 2000-11-29.
# 2019-05-06 10:58:38,152 - INFO - 22988 - Training a model to be tested between 2000-12-31 and 2001-01-31.
# 2019-05-06 10:58:38,154 - INFO - 22988 - Training dataset is between 2000-10-31 and 2000-12-29.
# 2019-05-06 10:58:38,164 - INFO - 22988 - Training a model to be tested between 2001-01-31 and 2001-02-28.
# 2019-05-06 10:58:38,166 - INFO - 22988 - Training dataset is between 2000-11-30 and 2001-01-30.
# 2019-05-06 10:58:38,174 - INFO - 22988 - Training a model to be tested between 2001-02-28 and 2001-03-31.
# 2019-05-06 10:58:38,177 - INFO - 22988 - Training dataset is between 2000-12-28 and 2001-02-27.
# 2019-05-06 10:58:38,187 - INFO - 22988 - Training a model to be tested between 2001-03-31 and 2001-04-30.
# 2019-05-06 10:58:38,190 - INFO - 22988 - Training dataset is between 2001-01-31 and 2001-03-30.
# 2019-05-06 10:58:38,199 - INFO - 22988 - Training a model to be tested between 2001-04-30 and 2001-05-31.
# 2019-05-06 10:58:38,201 - INFO - 22988 - Training dataset is between 2001-02-28 and 2001-04-27.
# 2019-05-06 10:58:38,211 - INFO - 22988 - Training a model to be tested between 2001-05-31 and 2001-06-30.
# 2019-05-06 10:58:38,214 - INFO - 22988 - Training dataset is between 2001-04-02 and 2001-05-30.
# 2019-05-06 10:58:38,223 - INFO - 22988 - Training a model to be tested between 2001-06-30 and 2001-07-31.
# 2019-05-06 10:58:38,225 - INFO - 22988 - Training dataset is between 2001-04-30 and 2001-06-29.
# 2019-05-06 10:58:38,234 - INFO - 22988 - Training a model to be tested between 2001-07-31 and 2001-08-31.
# 2019-05-06 10:58:38,237 - INFO - 22988 - Training dataset is between 2001-05-31 and 2001-07-30.
# 2019-05-06 10:58:38,246 - INFO - 22988 - Training a model to be tested between 2001-08-31 and 2001-09-30.
# 2019-05-06 10:58:38,248 - INFO - 22988 - Training dataset is between 2001-07-02 and 2001-08-30.
# 2019-05-06 10:58:38,258 - INFO - 22988 - Training a model to be tested between 2001-09-30 and 2001-10-31.
# 2019-05-06 10:58:38,261 - INFO - 22988 - Training dataset is between 2001-07-30 and 2001-09-28.
# 2019-05-06 10:58:38,270 - INFO - 22988 - Training a model to be tested between 2001-10-31 and 2001-11-30.
# 2019-05-06 10:58:38,272 - INFO - 22988 - Training dataset is between 2001-08-31 and 2001-10-30.
# 2019-05-06 10:58:38,281 - INFO - 22988 - Training a model to be tested between 2001-11-30 and 2001-12-31.
# 2019-05-06 10:58:38,284 - INFO - 22988 - Training dataset is between 2001-10-01 and 2001-11-29.
# 2019-05-06 10:58:38,292 - INFO - 22988 - Training a model to be tested between 2001-12-31 and 2002-01-31.
# 2019-05-06 10:58:38,294 - INFO - 22988 - Training dataset is between 2001-10-31 and 2001-12-28.
# 2019-05-06 10:58:38,305 - INFO - 22988 - Training a model to be tested between 2002-01-31 and 2002-02-28.
# 2019-05-06 10:58:38,306 - INFO - 22988 - Training dataset is between 2001-11-30 and 2002-01-30.
# 2019-05-06 10:58:38,316 - INFO - 22988 - Training a model to be tested between 2002-02-28 and 2002-03-31.
# 2019-05-06 10:58:38,318 - INFO - 22988 - Training dataset is between 2001-12-28 and 2002-02-27.
# 2019-05-06 10:58:38,329 - INFO - 22988 - Training a model to be tested between 2002-03-31 and 2002-04-30.
# 2019-05-06 10:58:38,331 - INFO - 22988 - Training dataset is between 2002-01-31 and 2002-03-28.
# 2019-05-06 10:58:38,341 - INFO - 22988 - Training a model to be tested between 2002-04-30 and 2002-05-31.
# 2019-05-06 10:58:38,344 - INFO - 22988 - Training dataset is between 2002-02-28 and 2002-04-29.
# 2019-05-06 10:58:38,353 - INFO - 22988 - Training a model to be tested between 2002-05-31 and 2002-06-30.
# 2019-05-06 10:58:38,355 - INFO - 22988 - Training dataset is between 2002-04-01 and 2002-05-30.
# 2019-05-06 10:58:38,365 - INFO - 22988 - Training a model to be tested between 2002-06-30 and 2002-07-31.
# 2019-05-06 10:58:38,368 - INFO - 22988 - Training dataset is between 2002-04-30 and 2002-06-28.
# 2019-05-06 10:58:38,376 - INFO - 22988 - Training a model to be tested between 2002-07-31 and 2002-08-31.
# 2019-05-06 10:58:38,379 - INFO - 22988 - Training dataset is between 2002-05-31 and 2002-07-30.
# 2019-05-06 10:58:38,388 - INFO - 22988 - Training a model to be tested between 2002-08-31 and 2002-09-30.
# 2019-05-06 10:58:38,391 - INFO - 22988 - Training dataset is between 2002-07-01 and 2002-08-30.
# 2019-05-06 10:58:38,400 - INFO - 22988 - Training a model to be tested between 2002-09-30 and 2002-10-31.
# 2019-05-06 10:58:38,404 - INFO - 22988 - Training dataset is between 2002-07-30 and 2002-09-27.
# 2019-05-06 10:58:38,412 - INFO - 22988 - Training a model to be tested between 2002-10-31 and 2002-11-30.
# 2019-05-06 10:58:38,414 - INFO - 22988 - Training dataset is between 2002-09-03 and 2002-10-30.
# 2019-05-06 10:58:38,424 - INFO - 22988 - Training a model to be tested between 2002-11-30 and 2002-12-31.
# 2019-05-06 10:58:38,426 - INFO - 22988 - Training dataset is between 2002-09-30 and 2002-11-29.
# 2019-05-06 10:58:38,436 - INFO - 22988 - Training a model to be tested between 2002-12-31 and 2003-01-31.
# 2019-05-06 10:58:38,438 - INFO - 22988 - Training dataset is between 2002-10-31 and 2002-12-30.
# 2019-05-06 10:58:38,448 - INFO - 22988 - Training a model to be tested between 2003-01-31 and 2003-02-28.
# 2019-05-06 10:58:38,451 - INFO - 22988 - Training dataset is between 2002-12-02 and 2003-01-30.
# 2019-05-06 10:58:38,462 - INFO - 22988 - Training a model to be tested between 2003-02-28 and 2003-03-31.
# 2019-05-06 10:58:38,464 - INFO - 22988 - Training dataset is between 2002-12-30 and 2003-02-27.
# 2019-05-06 10:58:38,474 - INFO - 22988 - Training a model to be tested between 2003-03-31 and 2003-04-30.
# 2019-05-06 10:58:38,476 - INFO - 22988 - Training dataset is between 2003-01-31 and 2003-03-28.
# 2019-05-06 10:58:38,486 - INFO - 22988 - Training a model to be tested between 2003-04-30 and 2003-05-31.
# 2019-05-06 10:58:38,489 - INFO - 22988 - Training dataset is between 2003-02-28 and 2003-04-29.
# 2019-05-06 10:58:38,497 - INFO - 22988 - Training a model to be tested between 2003-05-31 and 2003-06-30.
# 2019-05-06 10:58:38,499 - INFO - 22988 - Training dataset is between 2003-03-31 and 2003-05-30.
# 2019-05-06 10:58:38,509 - INFO - 22988 - Training a model to be tested between 2003-06-30 and 2003-07-31.
# 2019-05-06 10:58:38,512 - INFO - 22988 - Training dataset is between 2003-04-30 and 2003-06-27.
# 2019-05-06 10:58:38,521 - INFO - 22988 - Training a model to be tested between 2003-07-31 and 2003-08-31.
# 2019-05-06 10:58:38,523 - INFO - 22988 - Training dataset is between 2003-06-02 and 2003-07-30.
# 2019-05-06 10:58:38,531 - INFO - 22988 - Training a model to be tested between 2003-08-31 and 2003-09-30.
# 2019-05-06 10:58:38,534 - INFO - 22988 - Training dataset is between 2003-06-30 and 2003-08-29.
# 2019-05-06 10:58:38,542 - INFO - 22988 - Training a model to be tested between 2003-09-30 and 2003-10-31.
# 2019-05-06 10:58:38,544 - INFO - 22988 - Training dataset is between 2003-07-30 and 2003-09-29.
# 2019-05-06 10:58:38,553 - INFO - 22988 - Training a model to be tested between 2003-10-31 and 2003-11-30.
# 2019-05-06 10:58:38,555 - INFO - 22988 - Training dataset is between 2003-09-02 and 2003-10-30.
# 2019-05-06 10:58:38,564 - INFO - 22988 - Training a model to be tested between 2003-11-30 and 2003-12-31.
# 2019-05-06 10:58:38,566 - INFO - 22988 - Training dataset is between 2003-09-30 and 2003-11-28.
# 2019-05-06 10:58:38,574 - INFO - 22988 - Training a model to be tested between 2003-12-31 and 2004-01-31.
# 2019-05-06 10:58:38,576 - INFO - 22988 - Training dataset is between 2003-10-31 and 2003-12-30.
# 2019-05-06 10:58:38,585 - INFO - 22988 - Training a model to be tested between 2004-01-31 and 2004-02-29.
# 2019-05-06 10:58:38,587 - INFO - 22988 - Training dataset is between 2003-12-01 and 2004-01-30.
# 2019-05-06 10:58:38,594 - INFO - 22988 - Training a model to be tested between 2004-02-29 and 2004-03-31.
# 2019-05-06 10:58:38,597 - INFO - 22988 - Training dataset is between 2003-12-29 and 2004-02-27.
# 2019-05-06 10:58:38,606 - INFO - 22988 - Training a model to be tested between 2004-03-31 and 2004-04-30.
# 2019-05-06 10:58:38,609 - INFO - 22988 - Training dataset is between 2004-02-02 and 2004-03-30.
# 2019-05-06 10:58:38,617 - INFO - 22988 - Training a model to be tested between 2004-04-30 and 2004-05-31.
# 2019-05-06 10:58:38,620 - INFO - 22988 - Training dataset is between 2004-03-01 and 2004-04-29.
# 2019-05-06 10:58:38,628 - INFO - 22988 - Training a model to be tested between 2004-05-31 and 2004-06-30.
# 2019-05-06 10:58:38,631 - INFO - 22988 - Training dataset is between 2004-03-31 and 2004-05-28.
# 2019-05-06 10:58:38,639 - INFO - 22988 - Training a model to be tested between 2004-06-30 and 2004-07-31.
# 2019-05-06 10:58:38,641 - INFO - 22988 - Training dataset is between 2004-04-30 and 2004-06-29.
# 2019-05-06 10:58:38,651 - INFO - 22988 - Training a model to be tested between 2004-07-31 and 2004-08-31.
# 2019-05-06 10:58:38,654 - INFO - 22988 - Training dataset is between 2004-06-01 and 2004-07-30.
# 2019-05-06 10:58:38,662 - INFO - 22988 - Training a model to be tested between 2004-08-31 and 2004-09-30.
# 2019-05-06 10:58:38,664 - INFO - 22988 - Training dataset is between 2004-06-30 and 2004-08-30.
# 2019-05-06 10:58:38,674 - INFO - 22988 - Training a model to be tested between 2004-09-30 and 2004-10-31.
# 2019-05-06 10:58:38,676 - INFO - 22988 - Training dataset is between 2004-07-30 and 2004-09-29.
# 2019-05-06 10:58:38,685 - INFO - 22988 - Training a model to be tested between 2004-10-31 and 2004-11-30.
# 2019-05-06 10:58:38,687 - INFO - 22988 - Training dataset is between 2004-08-31 and 2004-10-29.
# 2019-05-06 10:58:38,695 - INFO - 22988 - Training a model to be tested between 2004-11-30 and 2004-12-31.
# 2019-05-06 10:58:38,698 - INFO - 22988 - Training dataset is between 2004-09-30 and 2004-11-29.
# 2019-05-06 10:58:38,706 - INFO - 22988 - Training a model to be tested between 2004-12-31 and 2005-01-31.
# 2019-05-06 10:58:38,708 - INFO - 22988 - Training dataset is between 2004-11-01 and 2004-12-30.
# 2019-05-06 10:58:38,716 - INFO - 22988 - Training a model to be tested between 2005-01-31 and 2005-02-28.
# 2019-05-06 10:58:38,718 - INFO - 22988 - Training dataset is between 2004-11-30 and 2005-01-28.
# 2019-05-06 10:58:38,726 - INFO - 22988 - Training a model to be tested between 2005-02-28 and 2005-03-31.
# 2019-05-06 10:58:38,728 - INFO - 22988 - Training dataset is between 2004-12-28 and 2005-02-25.
# 2019-05-06 10:58:38,737 - INFO - 22988 - Training a model to be tested between 2005-03-31 and 2005-04-30.
# 2019-05-06 10:58:38,740 - INFO - 22988 - Training dataset is between 2005-01-31 and 2005-03-30.
# 2019-05-06 10:58:38,747 - INFO - 22988 - Training a model to be tested between 2005-04-30 and 2005-05-31.
# 2019-05-06 10:58:38,749 - INFO - 22988 - Training dataset is between 2005-02-28 and 2005-04-29.
# 2019-05-06 10:58:38,758 - INFO - 22988 - Training a model to be tested between 2005-05-31 and 2005-06-30.
# 2019-05-06 10:58:38,760 - INFO - 22988 - Training dataset is between 2005-03-31 and 2005-05-27.
# 2019-05-06 10:58:38,768 - INFO - 22988 - Training a model to be tested between 2005-06-30 and 2005-07-31.
# 2019-05-06 10:58:38,770 - INFO - 22988 - Training dataset is between 2005-05-02 and 2005-06-29.
# 2019-05-06 10:58:38,779 - INFO - 22988 - Training a model to be tested between 2005-07-31 and 2005-08-31.
# 2019-05-06 10:58:38,781 - INFO - 22988 - Training dataset is between 2005-05-31 and 2005-07-29.
# 2019-05-06 10:58:38,790 - INFO - 22988 - Training a model to be tested between 2005-08-31 and 2005-09-30.
# 2019-05-06 10:58:38,792 - INFO - 22988 - Training dataset is between 2005-06-30 and 2005-08-30.
# 2019-05-06 10:58:38,802 - INFO - 22988 - Training a model to be tested between 2005-09-30 and 2005-10-31.
# 2019-05-06 10:58:38,804 - INFO - 22988 - Training dataset is between 2005-08-01 and 2005-09-29.
# 2019-05-06 10:58:38,812 - INFO - 22988 - Training a model to be tested between 2005-10-31 and 2005-11-30.
# 2019-05-06 10:58:38,814 - INFO - 22988 - Training dataset is between 2005-08-31 and 2005-10-28.
# 2019-05-06 10:58:38,822 - INFO - 22988 - Training a model to be tested between 2005-11-30 and 2005-12-31.
# 2019-05-06 10:58:38,824 - INFO - 22988 - Training dataset is between 2005-09-30 and 2005-11-29.
# 2019-05-06 10:58:38,833 - INFO - 22988 - Training a model to be tested between 2005-12-31 and 2006-01-31.
# 2019-05-06 10:58:38,834 - INFO - 22988 - Training dataset is between 2005-10-31 and 2005-12-30.
# 2019-05-06 10:58:38,843 - INFO - 22988 - Training a model to be tested between 2006-01-31 and 2006-02-28.
# 2019-05-06 10:58:38,845 - INFO - 22988 - Training dataset is between 2005-11-30 and 2006-01-30.
# 2019-05-06 10:58:38,854 - INFO - 22988 - Training a model to be tested between 2006-02-28 and 2006-03-31.
# 2019-05-06 10:58:38,856 - INFO - 22988 - Training dataset is between 2005-12-28 and 2006-02-27.
# 2019-05-06 10:58:38,864 - INFO - 22988 - Training a model to be tested between 2006-03-31 and 2006-04-30.
# 2019-05-06 10:58:38,866 - INFO - 22988 - Training dataset is between 2006-01-31 and 2006-03-30.
# 2019-05-06 10:58:38,874 - INFO - 22988 - Training a model to be tested between 2006-04-30 and 2006-05-31.
# 2019-05-06 10:58:38,876 - INFO - 22988 - Training dataset is between 2006-02-28 and 2006-04-28.
# 2019-05-06 10:58:38,884 - INFO - 22988 - Training a model to be tested between 2006-05-31 and 2006-06-30.
# 2019-05-06 10:58:38,886 - INFO - 22988 - Training dataset is between 2006-03-31 and 2006-05-30.
# 2019-05-06 10:58:38,895 - INFO - 22988 - Training a model to be tested between 2006-06-30 and 2006-07-31.
# 2019-05-06 10:58:38,897 - INFO - 22988 - Training dataset is between 2006-05-01 and 2006-06-29.
# 2019-05-06 10:58:38,905 - INFO - 22988 - Training a model to be tested between 2006-07-31 and 2006-08-31.
# 2019-05-06 10:58:38,907 - INFO - 22988 - Training dataset is between 2006-05-31 and 2006-07-28.
# 2019-05-06 10:58:38,916 - INFO - 22988 - Training a model to be tested between 2006-08-31 and 2006-09-30.
# 2019-05-06 10:58:38,918 - INFO - 22988 - Training dataset is between 2006-06-30 and 2006-08-30.
# 2019-05-06 10:58:38,926 - INFO - 22988 - Training a model to be tested between 2006-09-30 and 2006-10-31.
# 2019-05-06 10:58:38,928 - INFO - 22988 - Training dataset is between 2006-07-31 and 2006-09-29.
# 2019-05-06 10:58:38,937 - INFO - 22988 - Training a model to be tested between 2006-10-31 and 2006-11-30.
# 2019-05-06 10:58:38,939 - INFO - 22988 - Training dataset is between 2006-08-31 and 2006-10-30.
# 2019-05-06 10:58:38,948 - INFO - 22988 - Training a model to be tested between 2006-11-30 and 2006-12-31.
# 2019-05-06 10:58:38,949 - INFO - 22988 - Training dataset is between 2006-10-02 and 2006-11-29.
# 2019-05-06 10:58:38,959 - INFO - 22988 - Training a model to be tested between 2006-12-31 and 2007-01-31.
# 2019-05-06 10:58:38,961 - INFO - 22988 - Training dataset is between 2006-10-31 and 2006-12-29.
# 2019-05-06 10:58:38,971 - INFO - 22988 - Training a model to be tested between 2007-01-31 and 2007-02-28.
# 2019-05-06 10:58:38,973 - INFO - 22988 - Training dataset is between 2006-11-30 and 2007-01-30.
# 2019-05-06 10:58:38,981 - INFO - 22988 - Training a model to be tested between 2007-02-28 and 2007-03-31.
# 2019-05-06 10:58:38,983 - INFO - 22988 - Training dataset is between 2006-12-28 and 2007-02-27.
# 2019-05-06 10:58:38,991 - INFO - 22988 - Training a model to be tested between 2007-03-31 and 2007-04-30.
# 2019-05-06 10:58:38,993 - INFO - 22988 - Training dataset is between 2007-01-31 and 2007-03-30.
# 2019-05-06 10:58:39,001 - INFO - 22988 - Training a model to be tested between 2007-04-30 and 2007-05-31.
# 2019-05-06 10:58:39,003 - INFO - 22988 - Training dataset is between 2007-02-28 and 2007-04-27.
# 2019-05-06 10:58:39,013 - INFO - 22988 - Training a model to be tested between 2007-05-31 and 2007-06-30.
# 2019-05-06 10:58:39,015 - INFO - 22988 - Training dataset is between 2007-04-02 and 2007-05-30.
# 2019-05-06 10:58:39,024 - INFO - 22988 - Training a model to be tested between 2007-06-30 and 2007-07-31.
# 2019-05-06 10:58:39,026 - INFO - 22988 - Training dataset is between 2007-04-30 and 2007-06-29.
# 2019-05-06 10:58:39,036 - INFO - 22988 - Training a model to be tested between 2007-07-31 and 2007-08-31.
# 2019-05-06 10:58:39,038 - INFO - 22988 - Training dataset is between 2007-05-31 and 2007-07-30.
# 2019-05-06 10:58:39,046 - INFO - 22988 - Training a model to be tested between 2007-08-31 and 2007-09-30.
# 2019-05-06 10:58:39,049 - INFO - 22988 - Training dataset is between 2007-07-02 and 2007-08-30.
# 2019-05-06 10:58:39,058 - INFO - 22988 - Training a model to be tested between 2007-09-30 and 2007-10-31.
# 2019-05-06 10:58:39,060 - INFO - 22988 - Training dataset is between 2007-07-30 and 2007-09-28.
# 2019-05-06 10:58:39,068 - INFO - 22988 - Training a model to be tested between 2007-10-31 and 2007-11-30.
# 2019-05-06 10:58:39,071 - INFO - 22988 - Training dataset is between 2007-08-31 and 2007-10-30.
# 2019-05-06 10:58:39,080 - INFO - 22988 - Training a model to be tested between 2007-11-30 and 2007-12-31.
# 2019-05-06 10:58:39,082 - INFO - 22988 - Training dataset is between 2007-10-01 and 2007-11-29.
# 2019-05-06 10:58:39,093 - INFO - 22988 - Training a model to be tested between 2007-12-31 and 2008-01-31.
# 2019-05-06 10:58:39,096 - INFO - 22988 - Training dataset is between 2007-10-31 and 2007-12-28.
# 2019-05-06 10:58:39,104 - INFO - 22988 - Training a model to be tested between 2008-01-31 and 2008-02-29.
# 2019-05-06 10:58:39,107 - INFO - 22988 - Training dataset is between 2007-11-30 and 2008-01-30.
# 2019-05-06 10:58:39,116 - INFO - 22988 - Training a model to be tested between 2008-02-29 and 2008-03-31.
# 2019-05-06 10:58:39,117 - INFO - 22988 - Training dataset is between 2007-12-31 and 2008-02-28.
# 2019-05-06 10:58:39,126 - INFO - 22988 - Training a model to be tested between 2008-03-31 and 2008-04-30.
# 2019-05-06 10:58:39,129 - INFO - 22988 - Training dataset is between 2008-01-31 and 2008-03-28.
# 2019-05-06 10:58:39,137 - INFO - 22988 - Training a model to be tested between 2008-04-30 and 2008-05-31.
# 2019-05-06 10:58:39,140 - INFO - 22988 - Training dataset is between 2008-02-29 and 2008-04-29.
# 2019-05-06 10:58:39,148 - INFO - 22988 - Training a model to be tested between 2008-05-31 and 2008-06-30.
# 2019-05-06 10:58:39,150 - INFO - 22988 - Training dataset is between 2008-03-31 and 2008-05-30.
# 2019-05-06 10:58:39,159 - INFO - 22988 - Training a model to be tested between 2008-06-30 and 2008-07-31.
# 2019-05-06 10:58:39,161 - INFO - 22988 - Training dataset is between 2008-04-30 and 2008-06-27.
# 2019-05-06 10:58:39,169 - INFO - 22988 - Training a model to be tested between 2008-07-31 and 2008-08-31.
# 2019-05-06 10:58:39,172 - INFO - 22988 - Training dataset is between 2008-06-02 and 2008-07-30.
# 2019-05-06 10:58:39,180 - INFO - 22988 - Training a model to be tested between 2008-08-31 and 2008-09-30.
# 2019-05-06 10:58:39,182 - INFO - 22988 - Training dataset is between 2008-06-30 and 2008-08-29.
# 2019-05-06 10:58:39,191 - INFO - 22988 - Training a model to be tested between 2008-09-30 and 2008-10-31.
# 2019-05-06 10:58:39,193 - INFO - 22988 - Training dataset is between 2008-07-30 and 2008-09-29.
# 2019-05-06 10:58:39,202 - INFO - 22988 - Training a model to be tested between 2008-10-31 and 2008-11-30.
# 2019-05-06 10:58:39,203 - INFO - 22988 - Training dataset is between 2008-09-02 and 2008-10-30.
# 2019-05-06 10:58:39,212 - INFO - 22988 - Training a model to be tested between 2008-11-30 and 2008-12-31.
# 2019-05-06 10:58:39,214 - INFO - 22988 - Training dataset is between 2008-09-30 and 2008-11-28.
# 2019-05-06 10:58:39,222 - INFO - 22988 - Training a model to be tested between 2008-12-31 and 2009-01-31.
# 2019-05-06 10:58:39,224 - INFO - 22988 - Training dataset is between 2008-10-31 and 2008-12-30.
# 2019-05-06 10:58:39,233 - INFO - 22988 - Training a model to be tested between 2009-01-31 and 2009-02-28.
# 2019-05-06 10:58:39,235 - INFO - 22988 - Training dataset is between 2008-12-01 and 2009-01-30.
# 2019-05-06 10:58:39,243 - INFO - 22988 - Training a model to be tested between 2009-02-28 and 2009-03-31.
# 2019-05-06 10:58:39,245 - INFO - 22988 - Training dataset is between 2008-12-29 and 2009-02-27.
# 2019-05-06 10:58:39,255 - INFO - 22988 - Training a model to be tested between 2009-03-31 and 2009-04-30.
# 2019-05-06 10:58:39,257 - INFO - 22988 - Training dataset is between 2009-02-02 and 2009-03-30.
# 2019-05-06 10:58:39,265 - INFO - 22988 - Training a model to be tested between 2009-04-30 and 2009-05-31.
# 2019-05-06 10:58:39,267 - INFO - 22988 - Training dataset is between 2009-03-02 and 2009-04-29.
# 2019-05-06 10:58:39,275 - INFO - 22988 - Training a model to be tested between 2009-05-31 and 2009-06-30.
# 2019-05-06 10:58:39,277 - INFO - 22988 - Training dataset is between 2009-03-31 and 2009-05-29.
# 2019-05-06 10:58:39,285 - INFO - 22988 - Training a model to be tested between 2009-06-30 and 2009-07-31.
# 2019-05-06 10:58:39,287 - INFO - 22988 - Training dataset is between 2009-04-30 and 2009-06-29.
# 2019-05-06 10:58:39,296 - INFO - 22988 - Training a model to be tested between 2009-07-31 and 2009-08-31.
# 2019-05-06 10:58:39,298 - INFO - 22988 - Training dataset is between 2009-06-01 and 2009-07-30.
# 2019-05-06 10:58:39,306 - INFO - 22988 - Training a model to be tested between 2009-08-31 and 2009-09-30.
# 2019-05-06 10:58:39,309 - INFO - 22988 - Training dataset is between 2009-06-30 and 2009-08-28.
# 2019-05-06 10:58:39,317 - INFO - 22988 - Training a model to be tested between 2009-09-30 and 2009-10-31.
# 2019-05-06 10:58:39,318 - INFO - 22988 - Training dataset is between 2009-07-30 and 2009-09-29.
# 2019-05-06 10:58:39,327 - INFO - 22988 - Training a model to be tested between 2009-10-31 and 2009-11-30.
# 2019-05-06 10:58:39,329 - INFO - 22988 - Training dataset is between 2009-08-31 and 2009-10-30.
# 2019-05-06 10:58:39,337 - INFO - 22988 - Training a model to be tested between 2009-11-30 and 2009-12-31.
# 2019-05-06 10:58:39,339 - INFO - 22988 - Training dataset is between 2009-09-30 and 2009-11-27.
# 2019-05-06 10:58:39,347 - INFO - 22988 - Training a model to be tested between 2009-12-31 and 2010-01-31.
# 2019-05-06 10:58:39,349 - INFO - 22988 - Training dataset is between 2009-11-02 and 2009-12-30.
# 2019-05-06 10:58:39,357 - INFO - 22988 - Training a model to be tested between 2010-01-31 and 2010-02-28.
# 2019-05-06 10:58:39,359 - INFO - 22988 - Training dataset is between 2009-11-30 and 2010-01-29.
# 2019-05-06 10:58:39,368 - INFO - 22988 - Training a model to be tested between 2010-02-28 and 2010-03-31.
# 2019-05-06 10:58:39,371 - INFO - 22988 - Training dataset is between 2009-12-28 and 2010-02-26.
# 2019-05-06 10:58:39,379 - INFO - 22988 - Training a model to be tested between 2010-03-31 and 2010-04-30.
# 2019-05-06 10:58:39,381 - INFO - 22988 - Training dataset is between 2010-02-01 and 2010-03-30.
# 2019-05-06 10:58:39,389 - INFO - 22988 - Training a model to be tested between 2010-04-30 and 2010-05-31.
# 2019-05-06 10:58:39,391 - INFO - 22988 - Training dataset is between 2010-03-01 and 2010-04-29.
# 2019-05-06 10:58:39,400 - INFO - 22988 - Training a model to be tested between 2010-05-31 and 2010-06-30.
# 2019-05-06 10:58:39,402 - INFO - 22988 - Training dataset is between 2010-03-31 and 2010-05-28.
# 2019-05-06 10:58:39,411 - INFO - 22988 - Training a model to be tested between 2010-06-30 and 2010-07-31.
# 2019-05-06 10:58:39,412 - INFO - 22988 - Training dataset is between 2010-04-30 and 2010-06-29.
# 2019-05-06 10:58:39,421 - INFO - 22988 - Training a model to be tested between 2010-07-31 and 2010-08-31.
# 2019-05-06 10:58:39,423 - INFO - 22988 - Training dataset is between 2010-06-01 and 2010-07-30.
# 2019-05-06 10:58:39,431 - INFO - 22988 - Training a model to be tested between 2010-08-31 and 2010-09-30.
# 2019-05-06 10:58:39,433 - INFO - 22988 - Training dataset is between 2010-06-30 and 2010-08-30.
# 2019-05-06 10:58:39,441 - INFO - 22988 - Training a model to be tested between 2010-09-30 and 2010-10-31.
# 2019-05-06 10:58:39,443 - INFO - 22988 - Training dataset is between 2010-07-30 and 2010-09-29.
# 2019-05-06 10:58:39,451 - INFO - 22988 - Training a model to be tested between 2010-10-31 and 2010-11-30.
# 2019-05-06 10:58:39,453 - INFO - 22988 - Training dataset is between 2010-08-31 and 2010-10-29.
# 2019-05-06 10:58:39,462 - INFO - 22988 - Training a model to be tested between 2010-11-30 and 2010-12-31.
# 2019-05-06 10:58:39,464 - INFO - 22988 - Training dataset is between 2010-09-30 and 2010-11-29.
# 2019-05-06 10:58:39,472 - INFO - 22988 - Training a model to be tested between 2010-12-31 and 2011-01-31.
# 2019-05-06 10:58:39,474 - INFO - 22988 - Training dataset is between 2010-11-01 and 2010-12-30.
# 2019-05-06 10:58:39,482 - INFO - 22988 - Training a model to be tested between 2011-01-31 and 2011-02-28.
# 2019-05-06 10:58:39,484 - INFO - 22988 - Training dataset is between 2010-11-30 and 2011-01-28.
# 2019-05-06 10:58:39,493 - INFO - 22988 - Training a model to be tested between 2011-02-28 and 2011-03-31.
# 2019-05-06 10:58:39,494 - INFO - 22988 - Training dataset is between 2010-12-28 and 2011-02-25.
# 2019-05-06 10:58:39,503 - INFO - 22988 - Training a model to be tested between 2011-03-31 and 2011-04-30.
# 2019-05-06 10:58:39,505 - INFO - 22988 - Training dataset is between 2011-01-31 and 2011-03-30.
# 2019-05-06 10:58:39,513 - INFO - 22988 - Training a model to be tested between 2011-04-30 and 2011-05-31.
# 2019-05-06 10:58:39,516 - INFO - 22988 - Training dataset is between 2011-02-28 and 2011-04-29.
# 2019-05-06 10:58:39,525 - INFO - 22988 - Training a model to be tested between 2011-05-31 and 2011-06-30.
# 2019-05-06 10:58:39,527 - INFO - 22988 - Training dataset is between 2011-03-31 and 2011-05-27.
# 2019-05-06 10:58:39,535 - INFO - 22988 - Training a model to be tested between 2011-06-30 and 2011-07-31.
# 2019-05-06 10:58:39,538 - INFO - 22988 - Training dataset is between 2011-05-02 and 2011-06-29.
# 2019-05-06 10:58:39,547 - INFO - 22988 - Training a model to be tested between 2011-07-31 and 2011-08-31.
# 2019-05-06 10:58:39,549 - INFO - 22988 - Training dataset is between 2011-05-31 and 2011-07-29.
# 2019-05-06 10:58:39,558 - INFO - 22988 - Training a model to be tested between 2011-08-31 and 2011-09-30.
# 2019-05-06 10:58:39,560 - INFO - 22988 - Training dataset is between 2011-06-30 and 2011-08-30.
# 2019-05-06 10:58:39,569 - INFO - 22988 - Training a model to be tested between 2011-09-30 and 2011-10-31.
# 2019-05-06 10:58:39,571 - INFO - 22988 - Training dataset is between 2011-08-01 and 2011-09-29.
# 2019-05-06 10:58:39,580 - INFO - 22988 - Training a model to be tested between 2011-10-31 and 2011-11-30.
# 2019-05-06 10:58:39,583 - INFO - 22988 - Training dataset is between 2011-08-31 and 2011-10-28.
# 2019-05-06 10:58:39,591 - INFO - 22988 - Training a model to be tested between 2011-11-30 and 2011-12-31.
# 2019-05-06 10:58:39,593 - INFO - 22988 - Training dataset is between 2011-09-30 and 2011-11-29.
# 2019-05-06 10:58:39,600 - INFO - 22988 - Training a model to be tested between 2011-12-31 and 2012-01-31.
# 2019-05-06 10:58:39,604 - INFO - 22988 - Training dataset is between 2011-10-31 and 2011-12-30.
# 2019-05-06 10:58:39,612 - INFO - 22988 - Training a model to be tested between 2012-01-31 and 2012-02-29.
# 2019-05-06 10:58:39,614 - INFO - 22988 - Training dataset is between 2011-11-30 and 2012-01-30.
# 2019-05-06 10:58:39,624 - INFO - 22988 - Training a model to be tested between 2012-02-29 and 2012-03-31.
# 2019-05-06 10:58:39,627 - INFO - 22988 - Training dataset is between 2011-12-29 and 2012-02-28.
# 2019-05-06 10:58:39,635 - INFO - 22988 - Training a model to be tested between 2012-03-31 and 2012-04-30.
# 2019-05-06 10:58:39,638 - INFO - 22988 - Training dataset is between 2012-01-31 and 2012-03-30.
# 2019-05-06 10:58:39,646 - INFO - 22988 - Training a model to be tested between 2012-04-30 and 2012-05-31.
# 2019-05-06 10:58:39,649 - INFO - 22988 - Training dataset is between 2012-02-29 and 2012-04-27.
# 2019-05-06 10:58:39,657 - INFO - 22988 - Training a model to be tested between 2012-05-31 and 2012-06-30.
# 2019-05-06 10:58:39,659 - INFO - 22988 - Training dataset is between 2012-04-02 and 2012-05-30.
# 2019-05-06 10:58:39,669 - INFO - 22988 - Training a model to be tested between 2012-06-30 and 2012-07-31.
# 2019-05-06 10:58:39,671 - INFO - 22988 - Training dataset is between 2012-04-30 and 2012-06-29.
# 2019-05-06 10:58:39,679 - INFO - 22988 - Training a model to be tested between 2012-07-31 and 2012-08-31.
# 2019-05-06 10:58:39,682 - INFO - 22988 - Training dataset is between 2012-05-31 and 2012-07-30.
# 2019-05-06 10:58:39,690 - INFO - 22988 - Training a model to be tested between 2012-08-31 and 2012-09-30.
# 2019-05-06 10:58:39,692 - INFO - 22988 - Training dataset is between 2012-07-02 and 2012-08-30.
# 2019-05-06 10:58:39,701 - INFO - 22988 - Training a model to be tested between 2012-09-30 and 2012-10-31.
# 2019-05-06 10:58:39,703 - INFO - 22988 - Training dataset is between 2012-07-30 and 2012-09-28.
# 2019-05-06 10:58:39,711 - INFO - 22988 - Training a model to be tested between 2012-10-31 and 2012-11-30.
# 2019-05-06 10:58:39,714 - INFO - 22988 - Training dataset is between 2012-08-31 and 2012-10-26.
# 2019-05-06 10:58:39,722 - INFO - 22988 - Training a model to be tested between 2012-11-30 and 2012-12-31.
# 2019-05-06 10:58:39,724 - INFO - 22988 - Training dataset is between 2012-10-01 and 2012-11-29.
# 2019-05-06 10:58:39,733 - INFO - 22988 - Training a model to be tested between 2012-12-31 and 2013-01-31.
# 2019-05-06 10:58:39,734 - INFO - 22988 - Training dataset is between 2012-10-31 and 2012-12-28.
# 2019-05-06 10:58:39,744 - INFO - 22988 - Training a model to be tested between 2013-01-31 and 2013-02-28.
# 2019-05-06 10:58:39,746 - INFO - 22988 - Training dataset is between 2012-11-30 and 2013-01-30.
# 2019-05-06 10:58:39,754 - INFO - 22988 - Training a model to be tested between 2013-02-28 and 2013-03-31.
# 2019-05-06 10:58:39,755 - INFO - 22988 - Training dataset is between 2012-12-28 and 2013-02-27.
# 2019-05-06 10:58:39,764 - INFO - 22988 - Training a model to be tested between 2013-03-31 and 2013-04-30.
# 2019-05-06 10:58:39,766 - INFO - 22988 - Training dataset is between 2013-01-31 and 2013-03-28.
# 2019-05-06 10:58:39,774 - INFO - 22988 - Training a model to be tested between 2013-04-30 and 2013-05-31.
# 2019-05-06 10:58:39,777 - INFO - 22988 - Training dataset is between 2013-02-28 and 2013-04-29.
# 2019-05-06 10:58:39,786 - INFO - 22988 - Training a model to be tested between 2013-05-31 and 2013-06-30.
# 2019-05-06 10:58:39,787 - INFO - 22988 - Training dataset is between 2013-04-01 and 2013-05-30.
# 2019-05-06 10:58:39,795 - INFO - 22988 - Training a model to be tested between 2013-06-30 and 2013-07-31.
# 2019-05-06 10:58:39,798 - INFO - 22988 - Training dataset is between 2013-04-30 and 2013-06-28.
# 2019-05-06 10:58:39,807 - INFO - 22988 - Training a model to be tested between 2013-07-31 and 2013-08-31.
# 2019-05-06 10:58:39,809 - INFO - 22988 - Training dataset is between 2013-05-31 and 2013-07-30.
# 2019-05-06 10:58:39,817 - INFO - 22988 - Training a model to be tested between 2013-08-31 and 2013-09-30.
# 2019-05-06 10:58:39,819 - INFO - 22988 - Training dataset is between 2013-07-01 and 2013-08-30.
# 2019-05-06 10:58:39,827 - INFO - 22988 - Training a model to be tested between 2013-09-30 and 2013-10-31.
# 2019-05-06 10:58:39,829 - INFO - 22988 - Training dataset is between 2013-07-30 and 2013-09-27.
# 2019-05-06 10:58:39,838 - INFO - 22988 - Training a model to be tested between 2013-10-31 and 2013-11-30.
# 2019-05-06 10:58:39,840 - INFO - 22988 - Training dataset is between 2013-09-03 and 2013-10-30.
# 2019-05-06 10:58:39,848 - INFO - 22988 - Training a model to be tested between 2013-11-30 and 2013-12-31.
# 2019-05-06 10:58:39,850 - INFO - 22988 - Training dataset is between 2013-09-30 and 2013-11-29.
# 2019-05-06 10:58:39,858 - INFO - 22988 - Training a model to be tested between 2013-12-31 and 2014-01-31.
# 2019-05-06 10:58:39,861 - INFO - 22988 - Training dataset is between 2013-10-31 and 2013-12-30.
# 2019-05-06 10:58:39,869 - INFO - 22988 - Training a model to be tested between 2014-01-31 and 2014-02-28.
# 2019-05-06 10:58:39,871 - INFO - 22988 - Training dataset is between 2013-12-02 and 2014-01-30.
# 2019-05-06 10:58:39,880 - INFO - 22988 - Training a model to be tested between 2014-02-28 and 2014-03-31.
# 2019-05-06 10:58:39,882 - INFO - 22988 - Training dataset is between 2013-12-30 and 2014-02-27.
# 2019-05-06 10:58:39,892 - INFO - 22988 - Training a model to be tested between 2014-03-31 and 2014-04-30.
# 2019-05-06 10:58:39,894 - INFO - 22988 - Training dataset is between 2014-01-31 and 2014-03-28.
# 2019-05-06 10:58:39,904 - INFO - 22988 - Training a model to be tested between 2014-04-30 and 2014-05-31.
# 2019-05-06 10:58:39,906 - INFO - 22988 - Training dataset is between 2014-02-28 and 2014-04-29.
# 2019-05-06 10:58:39,915 - INFO - 22988 - Training a model to be tested between 2014-05-31 and 2014-06-30.
# 2019-05-06 10:58:39,917 - INFO - 22988 - Training dataset is between 2014-03-31 and 2014-05-30.
# 2019-05-06 10:58:39,925 - INFO - 22988 - Training a model to be tested between 2014-06-30 and 2014-07-31.
# 2019-05-06 10:58:39,927 - INFO - 22988 - Training dataset is between 2014-04-30 and 2014-06-27.
# 2019-05-06 10:58:39,935 - INFO - 22988 - Training a model to be tested between 2014-07-31 and 2014-08-31.
# 2019-05-06 10:58:39,938 - INFO - 22988 - Training dataset is between 2014-06-02 and 2014-07-30.
# 2019-05-06 10:58:39,947 - INFO - 22988 - Training a model to be tested between 2014-08-31 and 2014-09-30.
# 2019-05-06 10:58:39,949 - INFO - 22988 - Training dataset is between 2014-06-30 and 2014-08-29.
# 2019-05-06 10:58:39,958 - INFO - 22988 - Training a model to be tested between 2014-09-30 and 2014-10-31.
# 2019-05-06 10:58:39,960 - INFO - 22988 - Training dataset is between 2014-07-30 and 2014-09-29.
# 2019-05-06 10:58:39,968 - INFO - 22988 - Training a model to be tested between 2014-10-31 and 2014-11-30.
# 2019-05-06 10:58:39,969 - INFO - 22988 - Training dataset is between 2014-09-02 and 2014-10-30.
# 2019-05-06 10:58:39,978 - INFO - 22988 - Training a model to be tested between 2014-11-30 and 2014-12-31.
# 2019-05-06 10:58:39,980 - INFO - 22988 - Training dataset is between 2014-09-30 and 2014-11-28.
# 2019-05-06 10:58:39,988 - INFO - 22988 - Training a model to be tested between 2014-12-31 and 2015-01-31.
# 2019-05-06 10:58:39,991 - INFO - 22988 - Training dataset is between 2014-10-31 and 2014-12-30.
# 2019-05-06 10:58:39,999 - INFO - 22988 - Training a model to be tested between 2015-01-31 and 2015-02-28.
# 2019-05-06 10:58:40,001 - INFO - 22988 - Training dataset is between 2014-12-01 and 2015-01-30.
# 2019-05-06 10:58:40,010 - INFO - 22988 - Training a model to be tested between 2015-02-28 and 2015-03-31.
# 2019-05-06 10:58:40,012 - INFO - 22988 - Training dataset is between 2014-12-29 and 2015-02-27.
# 2019-05-06 10:58:40,020 - INFO - 22988 - Training a model to be tested between 2015-03-31 and 2015-04-30.
# 2019-05-06 10:58:40,023 - INFO - 22988 - Training dataset is between 2015-02-02 and 2015-03-30.
# 2019-05-06 10:58:40,032 - INFO - 22988 - Training a model to be tested between 2015-04-30 and 2015-05-31.
# 2019-05-06 10:58:40,034 - INFO - 22988 - Training dataset is between 2015-03-02 and 2015-04-29.
# 2019-05-06 10:58:40,045 - INFO - 22988 - Training a model to be tested between 2015-05-31 and 2015-06-30.
# 2019-05-06 10:58:40,047 - INFO - 22988 - Training dataset is between 2015-03-31 and 2015-05-29.
# 2019-05-06 10:58:40,056 - INFO - 22988 - Training a model to be tested between 2015-06-30 and 2015-07-31.
# 2019-05-06 10:58:40,060 - INFO - 22988 - Training dataset is between 2015-04-30 and 2015-06-29.
# 2019-05-06 10:58:40,070 - INFO - 22988 - Training a model to be tested between 2015-07-31 and 2015-08-31.
# 2019-05-06 10:58:40,072 - INFO - 22988 - Training dataset is between 2015-06-01 and 2015-07-30.
# 2019-05-06 10:58:40,082 - INFO - 22988 - Training a model to be tested between 2015-08-31 and 2015-09-30.
# 2019-05-06 10:58:40,084 - INFO - 22988 - Training dataset is between 2015-06-30 and 2015-08-28.
# 2019-05-06 10:58:40,092 - INFO - 22988 - Training a model to be tested between 2015-09-30 and 2015-10-31.
# 2019-05-06 10:58:40,096 - INFO - 22988 - Training dataset is between 2015-07-30 and 2015-09-29.
# 2019-05-06 10:58:40,106 - INFO - 22988 - Training a model to be tested between 2015-10-31 and 2015-11-30.
# 2019-05-06 10:58:40,108 - INFO - 22988 - Training dataset is between 2015-08-31 and 2015-10-30.
# 2019-05-06 10:58:40,117 - INFO - 22988 - Training a model to be tested between 2015-11-30 and 2015-12-31.
# 2019-05-06 10:58:40,119 - INFO - 22988 - Training dataset is between 2015-09-30 and 2015-11-27.
# 2019-05-06 10:58:40,129 - INFO - 22988 - Training a model to be tested between 2015-12-31 and 2016-01-31.
# 2019-05-06 10:58:40,132 - INFO - 22988 - Training dataset is between 2015-11-02 and 2015-12-30.
# 2019-05-06 10:58:40,140 - INFO - 22988 - Training a model to be tested between 2016-01-31 and 2016-02-29.
# 2019-05-06 10:58:40,142 - INFO - 22988 - Training dataset is between 2015-11-30 and 2016-01-29.
# 2019-05-06 10:58:40,150 - INFO - 22988 - Training a model to be tested between 2016-02-29 and 2016-03-31.
# 2019-05-06 10:58:40,152 - INFO - 22988 - Training dataset is between 2015-12-29 and 2016-02-26.
# 2019-05-06 10:58:40,160 - INFO - 22988 - Training a model to be tested between 2016-03-31 and 2016-04-30.
# 2019-05-06 10:58:40,162 - INFO - 22988 - Training dataset is between 2016-02-01 and 2016-03-30.
# 2019-05-06 10:58:40,171 - INFO - 22988 - Training a model to be tested between 2016-04-30 and 2016-05-31.
# 2019-05-06 10:58:40,173 - INFO - 22988 - Training dataset is between 2016-02-29 and 2016-04-29.
# 2019-05-06 10:58:40,182 - INFO - 22988 - Training a model to be tested between 2016-05-31 and 2016-06-30.
# 2019-05-06 10:58:40,184 - INFO - 22988 - Training dataset is between 2016-03-31 and 2016-05-27.
# 2019-05-06 10:58:40,192 - INFO - 22988 - Training a model to be tested between 2016-06-30 and 2016-07-31.
# 2019-05-06 10:58:40,194 - INFO - 22988 - Training dataset is between 2016-05-02 and 2016-06-29.
# 2019-05-06 10:58:40,204 - INFO - 22988 - Training a model to be tested between 2016-07-31 and 2016-08-31.
# 2019-05-06 10:58:40,206 - INFO - 22988 - Training dataset is between 2016-05-31 and 2016-07-29.
# 2019-05-06 10:58:40,216 - INFO - 22988 - Training a model to be tested between 2016-08-31 and 2016-09-30.
# 2019-05-06 10:58:40,219 - INFO - 22988 - Training dataset is between 2016-06-30 and 2016-08-30.
# 2019-05-06 10:58:40,227 - INFO - 22988 - Training a model to be tested between 2016-09-30 and 2016-10-31.
# 2019-05-06 10:58:40,230 - INFO - 22988 - Training dataset is between 2016-08-01 and 2016-09-29.
# 2019-05-06 10:58:40,240 - INFO - 22988 - Training a model to be tested between 2016-10-31 and 2016-11-30.
# 2019-05-06 10:58:40,242 - INFO - 22988 - Training dataset is between 2016-08-31 and 2016-10-28.
# 2019-05-06 10:58:40,250 - INFO - 22988 - Training a model to be tested between 2016-11-30 and 2016-12-31.
# 2019-05-06 10:58:40,253 - INFO - 22988 - Training dataset is between 2016-09-30 and 2016-11-29.
# 2019-05-06 10:58:40,264 - INFO - 22988 - Training a model to be tested between 2016-12-31 and 2017-01-31.
# 2019-05-06 10:58:40,266 - INFO - 22988 - Training dataset is between 2016-10-31 and 2016-12-30.
# 2019-05-06 10:58:40,276 - INFO - 22988 - Training a model to be tested between 2017-01-31 and 2017-02-28.
# 2019-05-06 10:58:40,278 - INFO - 22988 - Training dataset is between 2016-11-30 and 2017-01-30.
# 2019-05-06 10:58:40,287 - INFO - 22988 - Training a model to be tested between 2017-02-28 and 2017-03-31.
# 2019-05-06 10:58:40,290 - INFO - 22988 - Training dataset is between 2016-12-28 and 2017-02-27.
# 2019-05-06 10:58:40,298 - INFO - 22988 - Training a model to be tested between 2017-03-31 and 2017-04-30.
# 2019-05-06 10:58:40,300 - INFO - 22988 - Training dataset is between 2017-01-31 and 2017-03-30.
# 2019-05-06 10:58:40,308 - INFO - 22988 - Training a model to be tested between 2017-04-30 and 2017-05-31.
# 2019-05-06 10:58:40,310 - INFO - 22988 - Training dataset is between 2017-02-28 and 2017-04-28.
# 2019-05-06 10:58:40,318 - INFO - 22988 - Training a model to be tested between 2017-05-31 and 2017-06-30.
# 2019-05-06 10:58:40,320 - INFO - 22988 - Training dataset is between 2017-03-31 and 2017-05-30.
# 2019-05-06 10:58:40,329 - INFO - 22988 - Training a model to be tested between 2017-06-30 and 2017-07-31.
# 2019-05-06 10:58:40,330 - INFO - 22988 - Training dataset is between 2017-05-01 and 2017-06-29.
# 2019-05-06 10:58:40,339 - INFO - 22988 - Training a model to be tested between 2017-07-31 and 2017-08-31.
# 2019-05-06 10:58:40,341 - INFO - 22988 - Training dataset is between 2017-05-31 and 2017-07-28.
# 2019-05-06 10:58:40,349 - INFO - 22988 - Training a model to be tested between 2017-08-31 and 2017-09-30.
# 2019-05-06 10:58:40,351 - INFO - 22988 - Training dataset is between 2017-06-30 and 2017-08-30.
# 2019-05-06 10:58:40,360 - INFO - 22988 - Training a model to be tested between 2017-09-30 and 2017-10-31.
# 2019-05-06 10:58:40,362 - INFO - 22988 - Training dataset is between 2017-07-31 and 2017-09-29.
# 2019-05-06 10:58:40,369 - INFO - 22988 - Training a model to be tested between 2017-10-31 and 2017-11-30.
# 2019-05-06 10:58:40,371 - INFO - 22988 - Training dataset is between 2017-08-31 and 2017-10-30.
# 2019-05-06 10:58:40,381 - INFO - 22988 - Training a model to be tested between 2017-11-30 and 2017-12-31.
# 2019-05-06 10:58:40,383 - INFO - 22988 - Training dataset is between 2017-10-02 and 2017-11-29.
# 2019-05-06 10:58:40,391 - INFO - 22988 - Training a model to be tested between 2017-12-31 and 2018-01-31.
# 2019-05-06 10:58:40,394 - INFO - 22988 - Training dataset is between 2017-10-31 and 2017-12-29.
# 2019-05-06 10:58:40,402 - INFO - 22988 - Training a model to be tested between 2018-01-31 and 2018-02-28.
# 2019-05-06 10:58:40,405 - INFO - 22988 - Training dataset is between 2017-11-30 and 2018-01-30.
# 2019-05-06 10:58:40,413 - INFO - 22988 - Training a model to be tested between 2018-02-28 and 2018-03-31.
# 2019-05-06 10:58:40,416 - INFO - 22988 - Training dataset is between 2017-12-28 and 2018-02-27.
# 2019-05-06 10:58:40,424 - INFO - 22988 - Training a model to be tested between 2018-03-31 and 2018-04-30.
# 2019-05-06 10:58:40,425 - INFO - 22988 - Training dataset is between 2018-01-31 and 2018-03-29.
# 2019-05-06 10:58:40,433 - INFO - 22988 - Training a model to be tested between 2018-04-30 and 2018-05-31.
# 2019-05-06 10:58:40,436 - INFO - 22988 - Training dataset is between 2018-02-28 and 2018-04-27.
# 2019-05-06 10:58:40,445 - INFO - 22988 - Training a model to be tested between 2018-05-31 and 2018-06-30.
# 2019-05-06 10:58:40,447 - INFO - 22988 - Training dataset is between 2018-04-02 and 2018-05-30.
# 2019-05-06 10:58:40,455 - INFO - 22988 - Training a model to be tested between 2018-06-30 and 2018-07-31.
# 2019-05-06 10:58:40,457 - INFO - 22988 - Training dataset is between 2018-04-30 and 2018-06-29.
# 2019-05-06 10:58:40,465 - INFO - 22988 - Training a model to be tested between 2018-07-31 and 2018-08-31.
# 2019-05-06 10:58:40,467 - INFO - 22988 - Training dataset is between 2018-05-31 and 2018-07-30.
# 2019-05-06 10:58:40,475 - INFO - 22988 - Training a model to be tested between 2018-08-31 and 2018-09-30.
# 2019-05-06 10:58:40,477 - INFO - 22988 - Training dataset is between 2018-07-02 and 2018-08-30.
# 2019-05-06 10:58:40,485 - INFO - 22988 - Training a model to be tested between 2018-09-30 and 2018-10-31.
# 2019-05-06 10:58:40,487 - INFO - 22988 - Training dataset is between 2018-07-30 and 2018-09-28.
# 2019-05-06 10:58:40,495 - INFO - 22988 - Training a model to be tested between 2018-10-31 and 2018-11-30.
# 2019-05-06 10:58:40,498 - INFO - 22988 - Training dataset is between 2018-08-31 and 2018-10-30.
# 2019-05-06 10:58:40,506 - INFO - 22988 - Training a model to be tested between 2018-11-30 and 2018-12-31.
# 2019-05-06 10:58:40,508 - INFO - 22988 - Training dataset is between 2018-10-01 and 2018-11-29.

# %%
get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, with_benchmark=True, with_delta=True)
# Out:
#                      main     benchmark        delta
# alpha            0.431360  4.190292e-16          NaN
# beta             0.039590  1.000000e+00          NaN
# cagr             0.515458  5.169112e-02     0.463767
# max_drawdown    -0.194069 -5.518942e-01     0.357825
# return        2483.437082  1.580001e+00  2481.857081
# sharpe           2.284602  3.588021e-01     1.925800
# var             -0.015838 -1.920933e-02     0.003371
# volatility       0.190003  1.915877e-01    -0.001585

# %% [markdown]
# Taking 2 months the CAGR was reduced from 69% to 51%. Nevertheless, it is still huge. The look ahead bias
# is still present.
#
# Now lets discard the look ahead bias, keeping training data with no know return on evaluation time.
# We use the parameter `col_date_shift`. It tells to the backtest procedure, to don't train with data
# whose `col_date_shift` value is after the evaluation period. On our case, `col_date_shift` is `date_shift_20`,
# which contains the quote value after 20 business days. So, the regression will be trained with 2 months of
# history (because of `train_history_period=relativedelta(months=2)`), but `col_date_shift='date_shift_20'`
# warranty that there are no training data whose dependent value is on our evaluation time.
#
# This implies that in fact the training dataset won't be 2 month, will be in fact 1 month. Of the 2 months
# training dataset, the last 20 entries will be filtered by `col_date_shift` param.

# %%
x_vars = ['open_adj', 'low_adj', 'high_adj']
y_var = 'close_adj_shift_20'
buy_price_col = 'close_adj'
sell_price_col = 'close_adj_shift_1'
model_class = LinearRegression
model_params = {'fit_intercept': True}

df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
    buy_price_col=buy_price_col, sell_price_col=sell_price_col,
    model_class=model_class, model_params=model_params, 
    backtest_start='2000-03-01', backtest_end='2018-12-31', 
    model_update_frequency='M', train_history_period=relativedelta(months=2),
    col_date_shift='date_shift_20',
)
# Out:
# 2019-05-05 16:12:26,118 - DEBUG - 22988 - 227 periods to backtest: ['2000-03-01', '2000-03-31', '2000-04-30', '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31', '2000-09-30', '2000-10-31', '2000-11-30', '2000-12-31', '2001-01-31', '2001-02-28', '2001-03-31', '2001-04-30', '2001-05-31', '2001-06-30', '2001-07-31', '2001-08-31', '2001-09-30', '2001-10-31', '2001-11-30', '2001-12-31', '2002-01-31', '2002-02-28', '2002-03-31', '2002-04-30', '2002-05-31', '2002-06-30', '2002-07-31', '2002-08-31', '2002-09-30', '2002-10-31', '2002-11-30', '2002-12-31', '2003-01-31', '2003-02-28', '2003-03-31', '2003-04-30', '2003-05-31', '2003-06-30', '2003-07-31', '2003-08-31', '2003-09-30', '2003-10-31', '2003-11-30', '2003-12-31', '2004-01-31', '2004-02-29', '2004-03-31', '2004-04-30', '2004-05-31', '2004-06-30', '2004-07-31', '2004-08-31', '2004-09-30', '2004-10-31', '2004-11-30', '2004-12-31', '2005-01-31', '2005-02-28', '2005-03-31', '2005-04-30', '2005-05-31', '2005-06-30', '2005-07-31', '2005-08-31', '2005-09-30', '2005-10-31', '2005-11-30', '2005-12-31', '2006-01-31', '2006-02-28', '2006-03-31', '2006-04-30', '2006-05-31', '2006-06-30', '2006-07-31', '2006-08-31', '2006-09-30', '2006-10-31', '2006-11-30', '2006-12-31', '2007-01-31', '2007-02-28', '2007-03-31', '2007-04-30', '2007-05-31', '2007-06-30', '2007-07-31', '2007-08-31', '2007-09-30', '2007-10-31', '2007-11-30', '2007-12-31', '2008-01-31', '2008-02-29', '2008-03-31', '2008-04-30', '2008-05-31', '2008-06-30', '2008-07-31', '2008-08-31', '2008-09-30', '2008-10-31', '2008-11-30', '2008-12-31', '2009-01-31', '2009-02-28', '2009-03-31', '2009-04-30', '2009-05-31', '2009-06-30', '2009-07-31', '2009-08-31', '2009-09-30', '2009-10-31', '2009-11-30', '2009-12-31', '2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30', '2010-05-31', '2010-06-30', '2010-07-31', '2010-08-31', '2010-09-30', '2010-10-31', '2010-11-30', '2010-12-31', '2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30', '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31', '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31', '2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30', '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31', '2012-09-30', '2012-10-31', '2012-11-30', '2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31'].
# 2019-05-05 16:12:26,119 - INFO - 22988 - Training a model to be tested between 2000-03-01 and 2000-03-31.
# 2019-05-05 16:12:26,122 - INFO - 22988 - Training dataset is between 2000-01-03 and 2000-01-31.
# 2019-05-05 16:12:26,133 - INFO - 22988 - Training a model to be tested between 2000-03-31 and 2000-04-30.
# 2019-05-05 16:12:26,136 - INFO - 22988 - Training dataset is between 2000-01-31 and 2000-03-02.
# 2019-05-05 16:12:26,151 - INFO - 22988 - Training a model to be tested between 2000-04-30 and 2000-05-31.
# 2019-05-05 16:12:26,154 - INFO - 22988 - Training dataset is between 2000-02-29 and 2000-03-30.
# 2019-05-05 16:12:26,167 - INFO - 22988 - Training a model to be tested between 2000-05-31 and 2000-06-30.
# 2019-05-05 16:12:26,170 - INFO - 22988 - Training dataset is between 2000-03-31 and 2000-05-01.
# 2019-05-05 16:12:26,180 - INFO - 22988 - Training a model to be tested between 2000-06-30 and 2000-07-31.
# 2019-05-05 16:12:26,184 - INFO - 22988 - Training dataset is between 2000-05-01 and 2000-06-01.
# 2019-05-05 16:12:26,197 - INFO - 22988 - Training a model to be tested between 2000-07-31 and 2000-08-31.
# 2019-05-05 16:12:26,201 - INFO - 22988 - Training dataset is between 2000-05-31 and 2000-06-29.
# 2019-05-05 16:12:26,211 - INFO - 22988 - Training a model to be tested between 2000-08-31 and 2000-09-30.
# 2019-05-05 16:12:26,214 - INFO - 22988 - Training dataset is between 2000-06-30 and 2000-08-02.
# 2019-05-05 16:12:26,223 - INFO - 22988 - Training a model to be tested between 2000-09-30 and 2000-10-31.
# 2019-05-05 16:12:26,226 - INFO - 22988 - Training dataset is between 2000-07-31 and 2000-08-31.
# 2019-05-05 16:12:26,237 - INFO - 22988 - Training a model to be tested between 2000-10-31 and 2000-11-30.
# 2019-05-05 16:12:26,239 - INFO - 22988 - Training dataset is between 2000-08-31 and 2000-10-02.
# 2019-05-05 16:12:26,249 - INFO - 22988 - Training a model to be tested between 2000-11-30 and 2000-12-31.
# 2019-05-05 16:12:26,252 - INFO - 22988 - Training dataset is between 2000-10-02 and 2000-10-31.
# 2019-05-05 16:12:26,261 - INFO - 22988 - Training a model to be tested between 2000-12-31 and 2001-01-31.
# 2019-05-05 16:12:26,264 - INFO - 22988 - Training dataset is between 2000-10-31 and 2000-11-30.
# 2019-05-05 16:12:26,273 - INFO - 22988 - Training a model to be tested between 2001-01-31 and 2001-02-28.
# 2019-05-05 16:12:26,275 - INFO - 22988 - Training dataset is between 2000-11-30 and 2000-12-29.
# 2019-05-05 16:12:26,284 - INFO - 22988 - Training a model to be tested between 2001-02-28 and 2001-03-31.
# 2019-05-05 16:12:26,286 - INFO - 22988 - Training dataset is between 2000-12-28 and 2001-01-29.
# 2019-05-05 16:12:26,295 - INFO - 22988 - Training a model to be tested between 2001-03-31 and 2001-04-30.
# 2019-05-05 16:12:26,297 - INFO - 22988 - Training dataset is between 2001-01-31 and 2001-03-02.
# 2019-05-05 16:12:26,308 - INFO - 22988 - Training a model to be tested between 2001-04-30 and 2001-05-31.
# 2019-05-05 16:12:26,310 - INFO - 22988 - Training dataset is between 2001-02-28 and 2001-03-29.
# 2019-05-05 16:12:26,319 - INFO - 22988 - Training a model to be tested between 2001-05-31 and 2001-06-30.
# 2019-05-05 16:12:26,323 - INFO - 22988 - Training dataset is between 2001-04-02 and 2001-05-01.
# 2019-05-05 16:12:26,331 - INFO - 22988 - Training a model to be tested between 2001-06-30 and 2001-07-31.
# 2019-05-05 16:12:26,333 - INFO - 22988 - Training dataset is between 2001-04-30 and 2001-06-01.
# 2019-05-05 16:12:26,343 - INFO - 22988 - Training a model to be tested between 2001-07-31 and 2001-08-31.
# 2019-05-05 16:12:26,345 - INFO - 22988 - Training dataset is between 2001-05-31 and 2001-06-29.
# 2019-05-05 16:12:26,354 - INFO - 22988 - Training a model to be tested between 2001-08-31 and 2001-09-30.
# 2019-05-05 16:12:26,356 - INFO - 22988 - Training dataset is between 2001-07-02 and 2001-08-02.
# 2019-05-05 16:12:26,365 - INFO - 22988 - Training a model to be tested between 2001-09-30 and 2001-10-31.
# 2019-05-05 16:12:26,368 - INFO - 22988 - Training dataset is between 2001-07-30 and 2001-08-24.
# 2019-05-05 16:12:26,377 - INFO - 22988 - Training a model to be tested between 2001-10-31 and 2001-11-30.
# 2019-05-05 16:12:26,380 - INFO - 22988 - Training dataset is between 2001-08-31 and 2001-10-02.
# 2019-05-05 16:12:26,388 - INFO - 22988 - Training a model to be tested between 2001-11-30 and 2001-12-31.
# 2019-05-05 16:12:26,392 - INFO - 22988 - Training dataset is between 2001-10-01 and 2001-10-31.
# 2019-05-05 16:12:26,402 - INFO - 22988 - Training a model to be tested between 2001-12-31 and 2002-01-31.
# 2019-05-05 16:12:26,404 - INFO - 22988 - Training dataset is between 2001-10-31 and 2001-11-29.
# 2019-05-05 16:12:26,415 - INFO - 22988 - Training a model to be tested between 2002-01-31 and 2002-02-28.
# 2019-05-05 16:12:26,419 - INFO - 22988 - Training dataset is between 2001-11-30 and 2001-12-31.
# 2019-05-05 16:12:26,427 - INFO - 22988 - Training a model to be tested between 2002-02-28 and 2002-03-31.
# 2019-05-05 16:12:26,430 - INFO - 22988 - Training dataset is between 2001-12-28 and 2002-01-29.
# 2019-05-05 16:12:26,440 - INFO - 22988 - Training a model to be tested between 2002-03-31 and 2002-04-30.
# 2019-05-05 16:12:26,442 - INFO - 22988 - Training dataset is between 2002-01-31 and 2002-02-28.
# 2019-05-05 16:12:26,451 - INFO - 22988 - Training a model to be tested between 2002-04-30 and 2002-05-31.
# 2019-05-05 16:12:26,453 - INFO - 22988 - Training dataset is between 2002-02-28 and 2002-04-01.
# 2019-05-05 16:12:26,462 - INFO - 22988 - Training a model to be tested between 2002-05-31 and 2002-06-30.
# 2019-05-05 16:12:26,464 - INFO - 22988 - Training dataset is between 2002-04-01 and 2002-05-01.
# 2019-05-05 16:12:26,474 - INFO - 22988 - Training a model to be tested between 2002-06-30 and 2002-07-31.
# 2019-05-05 16:12:26,476 - INFO - 22988 - Training dataset is between 2002-04-30 and 2002-05-31.
# 2019-05-05 16:12:26,484 - INFO - 22988 - Training a model to be tested between 2002-07-31 and 2002-08-31.
# 2019-05-05 16:12:26,487 - INFO - 22988 - Training dataset is between 2002-05-31 and 2002-07-01.
# 2019-05-05 16:12:26,497 - INFO - 22988 - Training a model to be tested between 2002-08-31 and 2002-09-30.
# 2019-05-05 16:12:26,500 - INFO - 22988 - Training dataset is between 2002-07-01 and 2002-08-02.
# 2019-05-05 16:12:26,510 - INFO - 22988 - Training a model to be tested between 2002-09-30 and 2002-10-31.
# 2019-05-05 16:12:26,513 - INFO - 22988 - Training dataset is between 2002-07-30 and 2002-08-29.
# 2019-05-05 16:12:26,523 - INFO - 22988 - Training a model to be tested between 2002-10-31 and 2002-11-30.
# 2019-05-05 16:12:26,527 - INFO - 22988 - Training dataset is between 2002-09-03 and 2002-10-02.
# 2019-05-05 16:12:26,537 - INFO - 22988 - Training a model to be tested between 2002-11-30 and 2002-12-31.
# 2019-05-05 16:12:26,540 - INFO - 22988 - Training dataset is between 2002-09-30 and 2002-10-31.
# 2019-05-05 16:12:26,550 - INFO - 22988 - Training a model to be tested between 2002-12-31 and 2003-01-31.
# 2019-05-05 16:12:26,554 - INFO - 22988 - Training dataset is between 2002-10-31 and 2002-11-29.
# 2019-05-05 16:12:26,563 - INFO - 22988 - Training a model to be tested between 2003-01-31 and 2003-02-28.
# 2019-05-05 16:12:26,566 - INFO - 22988 - Training dataset is between 2002-12-02 and 2002-12-31.
# 2019-05-05 16:12:26,576 - INFO - 22988 - Training a model to be tested between 2003-02-28 and 2003-03-31.
# 2019-05-05 16:12:26,579 - INFO - 22988 - Training dataset is between 2002-12-30 and 2003-01-29.
# 2019-05-05 16:12:26,590 - INFO - 22988 - Training a model to be tested between 2003-03-31 and 2003-04-30.
# 2019-05-05 16:12:26,592 - INFO - 22988 - Training dataset is between 2003-01-31 and 2003-02-28.
# 2019-05-05 16:12:26,601 - INFO - 22988 - Training a model to be tested between 2003-04-30 and 2003-05-31.
# 2019-05-05 16:12:26,604 - INFO - 22988 - Training dataset is between 2003-02-28 and 2003-03-31.
# 2019-05-05 16:12:26,613 - INFO - 22988 - Training a model to be tested between 2003-05-31 and 2003-06-30.
# 2019-05-05 16:12:26,616 - INFO - 22988 - Training dataset is between 2003-03-31 and 2003-05-01.
# 2019-05-05 16:12:26,625 - INFO - 22988 - Training a model to be tested between 2003-06-30 and 2003-07-31.
# 2019-05-05 16:12:26,627 - INFO - 22988 - Training dataset is between 2003-04-30 and 2003-05-30.
# 2019-05-05 16:12:26,636 - INFO - 22988 - Training a model to be tested between 2003-07-31 and 2003-08-31.
# 2019-05-05 16:12:26,638 - INFO - 22988 - Training dataset is between 2003-06-02 and 2003-07-01.
# 2019-05-05 16:12:26,646 - INFO - 22988 - Training a model to be tested between 2003-08-31 and 2003-09-30.
# 2019-05-05 16:12:26,648 - INFO - 22988 - Training dataset is between 2003-06-30 and 2003-08-01.
# 2019-05-05 16:12:26,656 - INFO - 22988 - Training a model to be tested between 2003-09-30 and 2003-10-31.
# 2019-05-05 16:12:26,658 - INFO - 22988 - Training dataset is between 2003-07-30 and 2003-08-29.
# 2019-05-05 16:12:26,666 - INFO - 22988 - Training a model to be tested between 2003-10-31 and 2003-11-30.
# 2019-05-05 16:12:26,669 - INFO - 22988 - Training dataset is between 2003-09-02 and 2003-10-02.
# 2019-05-05 16:12:26,678 - INFO - 22988 - Training a model to be tested between 2003-11-30 and 2003-12-31.
# 2019-05-05 16:12:26,680 - INFO - 22988 - Training dataset is between 2003-09-30 and 2003-10-30.
# 2019-05-05 16:12:26,688 - INFO - 22988 - Training a model to be tested between 2003-12-31 and 2004-01-31.
# 2019-05-05 16:12:26,690 - INFO - 22988 - Training dataset is between 2003-10-31 and 2003-12-01.
# 2019-05-05 16:12:26,698 - INFO - 22988 - Training a model to be tested between 2004-01-31 and 2004-02-29.
# 2019-05-05 16:12:26,700 - INFO - 22988 - Training dataset is between 2003-12-01 and 2003-12-31.
# 2019-05-05 16:12:26,710 - INFO - 22988 - Training a model to be tested between 2004-02-29 and 2004-03-31.
# 2019-05-05 16:12:26,712 - INFO - 22988 - Training dataset is between 2003-12-29 and 2004-01-29.
# 2019-05-05 16:12:26,721 - INFO - 22988 - Training a model to be tested between 2004-03-31 and 2004-04-30.
# 2019-05-05 16:12:26,723 - INFO - 22988 - Training dataset is between 2004-02-02 and 2004-03-02.
# 2019-05-05 16:12:26,731 - INFO - 22988 - Training a model to be tested between 2004-04-30 and 2004-05-31.
# 2019-05-05 16:12:26,733 - INFO - 22988 - Training dataset is between 2004-03-01 and 2004-03-31.
# 2019-05-05 16:12:26,742 - INFO - 22988 - Training a model to be tested between 2004-05-31 and 2004-06-30.
# 2019-05-05 16:12:26,744 - INFO - 22988 - Training dataset is between 2004-03-31 and 2004-04-30.
# 2019-05-05 16:12:26,752 - INFO - 22988 - Training a model to be tested between 2004-06-30 and 2004-07-31.
# 2019-05-05 16:12:26,755 - INFO - 22988 - Training dataset is between 2004-04-30 and 2004-05-28.
# 2019-05-05 16:12:26,762 - INFO - 22988 - Training a model to be tested between 2004-07-31 and 2004-08-31.
# 2019-05-05 16:12:26,764 - INFO - 22988 - Training dataset is between 2004-06-01 and 2004-07-01.
# 2019-05-05 16:12:26,773 - INFO - 22988 - Training a model to be tested between 2004-08-31 and 2004-09-30.
# 2019-05-05 16:12:26,775 - INFO - 22988 - Training dataset is between 2004-06-30 and 2004-08-02.
# 2019-05-05 16:12:26,783 - INFO - 22988 - Training a model to be tested between 2004-09-30 and 2004-10-31.
# 2019-05-05 16:12:26,785 - INFO - 22988 - Training dataset is between 2004-07-30 and 2004-08-31.
# 2019-05-05 16:12:26,794 - INFO - 22988 - Training a model to be tested between 2004-10-31 and 2004-11-30.
# 2019-05-05 16:12:26,796 - INFO - 22988 - Training dataset is between 2004-08-31 and 2004-10-01.
# 2019-05-05 16:12:26,804 - INFO - 22988 - Training a model to be tested between 2004-11-30 and 2004-12-31.
# 2019-05-05 16:12:26,806 - INFO - 22988 - Training dataset is between 2004-09-30 and 2004-10-29.
# 2019-05-05 16:12:26,815 - INFO - 22988 - Training a model to be tested between 2004-12-31 and 2005-01-31.
# 2019-05-05 16:12:26,817 - INFO - 22988 - Training dataset is between 2004-11-01 and 2004-12-01.
# 2019-05-05 16:12:26,825 - INFO - 22988 - Training a model to be tested between 2005-01-31 and 2005-02-28.
# 2019-05-05 16:12:26,827 - INFO - 22988 - Training dataset is between 2004-11-30 and 2004-12-30.
# 2019-05-05 16:12:26,835 - INFO - 22988 - Training a model to be tested between 2005-02-28 and 2005-03-31.
# 2019-05-05 16:12:26,837 - INFO - 22988 - Training dataset is between 2004-12-28 and 2005-01-27.
# 2019-05-05 16:12:26,845 - INFO - 22988 - Training a model to be tested between 2005-03-31 and 2005-04-30.
# 2019-05-05 16:12:26,847 - INFO - 22988 - Training dataset is between 2005-01-31 and 2005-03-01.
# 2019-05-05 16:12:26,856 - INFO - 22988 - Training a model to be tested between 2005-04-30 and 2005-05-31.
# 2019-05-05 16:12:26,858 - INFO - 22988 - Training dataset is between 2005-02-28 and 2005-04-01.
# 2019-05-05 16:12:26,866 - INFO - 22988 - Training a model to be tested between 2005-05-31 and 2005-06-30.
# 2019-05-05 16:12:26,868 - INFO - 22988 - Training dataset is between 2005-03-31 and 2005-04-29.
# 2019-05-05 16:12:26,876 - INFO - 22988 - Training a model to be tested between 2005-06-30 and 2005-07-31.
# 2019-05-05 16:12:26,878 - INFO - 22988 - Training dataset is between 2005-05-02 and 2005-06-01.
# 2019-05-05 16:12:26,886 - INFO - 22988 - Training a model to be tested between 2005-07-31 and 2005-08-31.
# 2019-05-05 16:12:26,888 - INFO - 22988 - Training dataset is between 2005-05-31 and 2005-06-30.
# 2019-05-05 16:12:26,896 - INFO - 22988 - Training a model to be tested between 2005-08-31 and 2005-09-30.
# 2019-05-05 16:12:26,899 - INFO - 22988 - Training dataset is between 2005-06-30 and 2005-08-02.
# 2019-05-05 16:12:26,907 - INFO - 22988 - Training a model to be tested between 2005-09-30 and 2005-10-31.
# 2019-05-05 16:12:26,909 - INFO - 22988 - Training dataset is between 2005-08-01 and 2005-08-31.
# 2019-05-05 16:12:26,918 - INFO - 22988 - Training a model to be tested between 2005-10-31 and 2005-11-30.
# 2019-05-05 16:12:26,920 - INFO - 22988 - Training dataset is between 2005-08-31 and 2005-09-30.
# 2019-05-05 16:12:26,928 - INFO - 22988 - Training a model to be tested between 2005-11-30 and 2005-12-31.
# 2019-05-05 16:12:26,930 - INFO - 22988 - Training dataset is between 2005-09-30 and 2005-10-31.
# 2019-05-05 16:12:26,939 - INFO - 22988 - Training a model to be tested between 2005-12-31 and 2006-01-31.
# 2019-05-05 16:12:26,941 - INFO - 22988 - Training dataset is between 2005-10-31 and 2005-12-01.
# 2019-05-05 16:12:26,949 - INFO - 22988 - Training a model to be tested between 2006-01-31 and 2006-02-28.
# 2019-05-05 16:12:26,951 - INFO - 22988 - Training dataset is between 2005-11-30 and 2005-12-29.
# 2019-05-05 16:12:26,959 - INFO - 22988 - Training a model to be tested between 2006-02-28 and 2006-03-31.
# 2019-05-05 16:12:26,962 - INFO - 22988 - Training dataset is between 2005-12-28 and 2006-01-27.
# 2019-05-05 16:12:26,969 - INFO - 22988 - Training a model to be tested between 2006-03-31 and 2006-04-30.
# 2019-05-05 16:12:26,972 - INFO - 22988 - Training dataset is between 2006-01-31 and 2006-03-02.
# 2019-05-05 16:12:26,980 - INFO - 22988 - Training a model to be tested between 2006-04-30 and 2006-05-31.
# 2019-05-05 16:12:26,983 - INFO - 22988 - Training dataset is between 2006-02-28 and 2006-03-30.
# 2019-05-05 16:12:26,991 - INFO - 22988 - Training a model to be tested between 2006-05-31 and 2006-06-30.
# 2019-05-05 16:12:26,993 - INFO - 22988 - Training dataset is between 2006-03-31 and 2006-05-01.
# 2019-05-05 16:12:27,000 - INFO - 22988 - Training a model to be tested between 2006-06-30 and 2006-07-31.
# 2019-05-05 16:12:27,003 - INFO - 22988 - Training dataset is between 2006-05-01 and 2006-06-01.
# 2019-05-05 16:12:27,011 - INFO - 22988 - Training a model to be tested between 2006-07-31 and 2006-08-31.
# 2019-05-05 16:12:27,013 - INFO - 22988 - Training dataset is between 2006-05-31 and 2006-06-29.
# 2019-05-05 16:12:27,021 - INFO - 22988 - Training a model to be tested between 2006-08-31 and 2006-09-30.
# 2019-05-05 16:12:27,023 - INFO - 22988 - Training dataset is between 2006-06-30 and 2006-08-02.
# 2019-05-05 16:12:27,033 - INFO - 22988 - Training a model to be tested between 2006-09-30 and 2006-10-31.
# 2019-05-05 16:12:27,035 - INFO - 22988 - Training dataset is between 2006-07-31 and 2006-08-31.
# 2019-05-05 16:12:27,043 - INFO - 22988 - Training a model to be tested between 2006-10-31 and 2006-11-30.
# 2019-05-05 16:12:27,044 - INFO - 22988 - Training dataset is between 2006-08-31 and 2006-10-02.
# 2019-05-05 16:12:27,053 - INFO - 22988 - Training a model to be tested between 2006-11-30 and 2006-12-31.
# 2019-05-05 16:12:27,055 - INFO - 22988 - Training dataset is between 2006-10-02 and 2006-10-31.
# 2019-05-05 16:12:27,063 - INFO - 22988 - Training a model to be tested between 2006-12-31 and 2007-01-31.
# 2019-05-05 16:12:27,065 - INFO - 22988 - Training dataset is between 2006-10-31 and 2006-11-30.
# 2019-05-05 16:12:27,074 - INFO - 22988 - Training a model to be tested between 2007-01-31 and 2007-02-28.
# 2019-05-05 16:12:27,077 - INFO - 22988 - Training dataset is between 2006-11-30 and 2006-12-28.
# 2019-05-05 16:12:27,084 - INFO - 22988 - Training a model to be tested between 2007-02-28 and 2007-03-31.
# 2019-05-05 16:12:27,087 - INFO - 22988 - Training dataset is between 2006-12-28 and 2007-01-29.
# 2019-05-05 16:12:27,096 - INFO - 22988 - Training a model to be tested between 2007-03-31 and 2007-04-30.
# 2019-05-05 16:12:27,097 - INFO - 22988 - Training dataset is between 2007-01-31 and 2007-03-02.
# 2019-05-05 16:12:27,106 - INFO - 22988 - Training a model to be tested between 2007-04-30 and 2007-05-31.
# 2019-05-05 16:12:27,108 - INFO - 22988 - Training dataset is between 2007-02-28 and 2007-03-29.
# 2019-05-05 16:12:27,118 - INFO - 22988 - Training a model to be tested between 2007-05-31 and 2007-06-30.
# 2019-05-05 16:12:27,120 - INFO - 22988 - Training dataset is between 2007-04-02 and 2007-05-01.
# 2019-05-05 16:12:27,128 - INFO - 22988 - Training a model to be tested between 2007-06-30 and 2007-07-31.
# 2019-05-05 16:12:27,131 - INFO - 22988 - Training dataset is between 2007-04-30 and 2007-06-01.
# 2019-05-05 16:12:27,139 - INFO - 22988 - Training a model to be tested between 2007-07-31 and 2007-08-31.
# 2019-05-05 16:12:27,140 - INFO - 22988 - Training dataset is between 2007-05-31 and 2007-06-29.
# 2019-05-05 16:12:27,149 - INFO - 22988 - Training a model to be tested between 2007-08-31 and 2007-09-30.
# 2019-05-05 16:12:27,151 - INFO - 22988 - Training dataset is between 2007-07-02 and 2007-08-02.
# 2019-05-05 16:12:27,160 - INFO - 22988 - Training a model to be tested between 2007-09-30 and 2007-10-31.
# 2019-05-05 16:12:27,161 - INFO - 22988 - Training dataset is between 2007-07-30 and 2007-08-30.
# 2019-05-05 16:12:27,169 - INFO - 22988 - Training a model to be tested between 2007-10-31 and 2007-11-30.
# 2019-05-05 16:12:27,172 - INFO - 22988 - Training dataset is between 2007-08-31 and 2007-10-02.
# 2019-05-05 16:12:27,180 - INFO - 22988 - Training a model to be tested between 2007-11-30 and 2007-12-31.
# 2019-05-05 16:12:27,181 - INFO - 22988 - Training dataset is between 2007-10-01 and 2007-10-31.
# 2019-05-05 16:12:27,190 - INFO - 22988 - Training a model to be tested between 2007-12-31 and 2008-01-31.
# 2019-05-05 16:12:27,192 - INFO - 22988 - Training dataset is between 2007-10-31 and 2007-11-29.
# 2019-05-05 16:12:27,201 - INFO - 22988 - Training a model to be tested between 2008-01-31 and 2008-02-29.
# 2019-05-05 16:12:27,203 - INFO - 22988 - Training dataset is between 2007-11-30 and 2007-12-31.
# 2019-05-05 16:12:27,212 - INFO - 22988 - Training a model to be tested between 2008-02-29 and 2008-03-31.
# 2019-05-05 16:12:27,214 - INFO - 22988 - Training dataset is between 2007-12-31 and 2008-01-30.
# 2019-05-05 16:12:27,223 - INFO - 22988 - Training a model to be tested between 2008-03-31 and 2008-04-30.
# 2019-05-05 16:12:27,226 - INFO - 22988 - Training dataset is between 2008-01-31 and 2008-02-28.
# 2019-05-05 16:12:27,235 - INFO - 22988 - Training a model to be tested between 2008-04-30 and 2008-05-31.
# 2019-05-05 16:12:27,238 - INFO - 22988 - Training dataset is between 2008-02-29 and 2008-04-01.
# 2019-05-05 16:12:27,247 - INFO - 22988 - Training a model to be tested between 2008-05-31 and 2008-06-30.
# 2019-05-05 16:12:27,250 - INFO - 22988 - Training dataset is between 2008-03-31 and 2008-05-01.
# 2019-05-05 16:12:27,258 - INFO - 22988 - Training a model to be tested between 2008-06-30 and 2008-07-31.
# 2019-05-05 16:12:27,260 - INFO - 22988 - Training dataset is between 2008-04-30 and 2008-05-30.
# 2019-05-05 16:12:27,269 - INFO - 22988 - Training a model to be tested between 2008-07-31 and 2008-08-31.
# 2019-05-05 16:12:27,271 - INFO - 22988 - Training dataset is between 2008-06-02 and 2008-07-01.
# 2019-05-05 16:12:27,281 - INFO - 22988 - Training a model to be tested between 2008-08-31 and 2008-09-30.
# 2019-05-05 16:12:27,283 - INFO - 22988 - Training dataset is between 2008-06-30 and 2008-08-01.
# 2019-05-05 16:12:27,293 - INFO - 22988 - Training a model to be tested between 2008-09-30 and 2008-10-31.
# 2019-05-05 16:12:27,295 - INFO - 22988 - Training dataset is between 2008-07-30 and 2008-08-29.
# 2019-05-05 16:12:27,305 - INFO - 22988 - Training a model to be tested between 2008-10-31 and 2008-11-30.
# 2019-05-05 16:12:27,307 - INFO - 22988 - Training dataset is between 2008-09-02 and 2008-10-02.
# 2019-05-05 16:12:27,317 - INFO - 22988 - Training a model to be tested between 2008-11-30 and 2008-12-31.
# 2019-05-05 16:12:27,321 - INFO - 22988 - Training dataset is between 2008-09-30 and 2008-10-30.
# 2019-05-05 16:12:27,330 - INFO - 22988 - Training a model to be tested between 2008-12-31 and 2009-01-31.
# 2019-05-05 16:12:27,332 - INFO - 22988 - Training dataset is between 2008-10-31 and 2008-12-01.
# 2019-05-05 16:12:27,340 - INFO - 22988 - Training a model to be tested between 2009-01-31 and 2009-02-28.
# 2019-05-05 16:12:27,341 - INFO - 22988 - Training dataset is between 2008-12-01 and 2008-12-31.
# 2019-05-05 16:12:27,352 - INFO - 22988 - Training a model to be tested between 2009-02-28 and 2009-03-31.
# 2019-05-05 16:12:27,354 - INFO - 22988 - Training dataset is between 2008-12-29 and 2009-01-29.
# 2019-05-05 16:12:27,362 - INFO - 22988 - Training a model to be tested between 2009-03-31 and 2009-04-30.
# 2019-05-05 16:12:27,365 - INFO - 22988 - Training dataset is between 2009-02-02 and 2009-03-02.
# 2019-05-05 16:12:27,374 - INFO - 22988 - Training a model to be tested between 2009-04-30 and 2009-05-31.
# 2019-05-05 16:12:27,376 - INFO - 22988 - Training dataset is between 2009-03-02 and 2009-03-31.
# 2019-05-05 16:12:27,384 - INFO - 22988 - Training a model to be tested between 2009-05-31 and 2009-06-30.
# 2019-05-05 16:12:27,386 - INFO - 22988 - Training dataset is between 2009-03-31 and 2009-04-30.
# 2019-05-05 16:12:27,396 - INFO - 22988 - Training a model to be tested between 2009-06-30 and 2009-07-31.
# 2019-05-05 16:12:27,398 - INFO - 22988 - Training dataset is between 2009-04-30 and 2009-06-01.
# 2019-05-05 16:12:27,406 - INFO - 22988 - Training a model to be tested between 2009-07-31 and 2009-08-31.
# 2019-05-05 16:12:27,411 - INFO - 22988 - Training dataset is between 2009-06-01 and 2009-07-01.
# 2019-05-05 16:12:27,419 - INFO - 22988 - Training a model to be tested between 2009-08-31 and 2009-09-30.
# 2019-05-05 16:12:27,421 - INFO - 22988 - Training dataset is between 2009-06-30 and 2009-07-31.
# 2019-05-05 16:12:27,431 - INFO - 22988 - Training a model to be tested between 2009-09-30 and 2009-10-31.
# 2019-05-05 16:12:27,434 - INFO - 22988 - Training dataset is between 2009-07-30 and 2009-08-31.
# 2019-05-05 16:12:27,442 - INFO - 22988 - Training a model to be tested between 2009-10-31 and 2009-11-30.
# 2019-05-05 16:12:27,444 - INFO - 22988 - Training dataset is between 2009-08-31 and 2009-10-02.
# 2019-05-05 16:12:27,455 - INFO - 22988 - Training a model to be tested between 2009-11-30 and 2009-12-31.
# 2019-05-05 16:12:27,457 - INFO - 22988 - Training dataset is between 2009-09-30 and 2009-10-29.
# 2019-05-05 16:12:27,465 - INFO - 22988 - Training a model to be tested between 2009-12-31 and 2010-01-31.
# 2019-05-05 16:12:27,467 - INFO - 22988 - Training dataset is between 2009-11-02 and 2009-12-01.
# 2019-05-05 16:12:27,475 - INFO - 22988 - Training a model to be tested between 2010-01-31 and 2010-02-28.
# 2019-05-05 16:12:27,478 - INFO - 22988 - Training dataset is between 2009-11-30 and 2009-12-30.
# 2019-05-05 16:12:27,487 - INFO - 22988 - Training a model to be tested between 2010-02-28 and 2010-03-31.
# 2019-05-05 16:12:27,489 - INFO - 22988 - Training dataset is between 2009-12-28 and 2010-01-28.
# 2019-05-05 16:12:27,499 - INFO - 22988 - Training a model to be tested between 2010-03-31 and 2010-04-30.
# 2019-05-05 16:12:27,500 - INFO - 22988 - Training dataset is between 2010-02-01 and 2010-03-02.
# 2019-05-05 16:12:27,508 - INFO - 22988 - Training a model to be tested between 2010-04-30 and 2010-05-31.
# 2019-05-05 16:12:27,511 - INFO - 22988 - Training dataset is between 2010-03-01 and 2010-03-31.
# 2019-05-05 16:12:27,520 - INFO - 22988 - Training a model to be tested between 2010-05-31 and 2010-06-30.
# 2019-05-05 16:12:27,522 - INFO - 22988 - Training dataset is between 2010-03-31 and 2010-04-30.
# 2019-05-05 16:12:27,531 - INFO - 22988 - Training a model to be tested between 2010-06-30 and 2010-07-31.
# 2019-05-05 16:12:27,533 - INFO - 22988 - Training dataset is between 2010-04-30 and 2010-06-01.
# 2019-05-05 16:12:27,542 - INFO - 22988 - Training a model to be tested between 2010-07-31 and 2010-08-31.
# 2019-05-05 16:12:27,544 - INFO - 22988 - Training dataset is between 2010-06-01 and 2010-07-01.
# 2019-05-05 16:12:27,551 - INFO - 22988 - Training a model to be tested between 2010-08-31 and 2010-09-30.
# 2019-05-05 16:12:27,554 - INFO - 22988 - Training dataset is between 2010-06-30 and 2010-08-02.
# 2019-05-05 16:12:27,564 - INFO - 22988 - Training a model to be tested between 2010-09-30 and 2010-10-31.
# 2019-05-05 16:12:27,566 - INFO - 22988 - Training dataset is between 2010-07-30 and 2010-08-31.
# 2019-05-05 16:12:27,574 - INFO - 22988 - Training a model to be tested between 2010-10-31 and 2010-11-30.
# 2019-05-05 16:12:27,577 - INFO - 22988 - Training dataset is between 2010-08-31 and 2010-10-01.
# 2019-05-05 16:12:27,586 - INFO - 22988 - Training a model to be tested between 2010-11-30 and 2010-12-31.
# 2019-05-05 16:12:27,588 - INFO - 22988 - Training dataset is between 2010-09-30 and 2010-10-29.
# 2019-05-05 16:12:27,595 - INFO - 22988 - Training a model to be tested between 2010-12-31 and 2011-01-31.
# 2019-05-05 16:12:27,598 - INFO - 22988 - Training dataset is between 2010-11-01 and 2010-12-01.
# 2019-05-05 16:12:27,606 - INFO - 22988 - Training a model to be tested between 2011-01-31 and 2011-02-28.
# 2019-05-05 16:12:27,608 - INFO - 22988 - Training dataset is between 2010-11-30 and 2010-12-30.
# 2019-05-05 16:12:27,617 - INFO - 22988 - Training a model to be tested between 2011-02-28 and 2011-03-31.
# 2019-05-05 16:12:27,619 - INFO - 22988 - Training dataset is between 2010-12-28 and 2011-01-27.
# 2019-05-05 16:12:27,627 - INFO - 22988 - Training a model to be tested between 2011-03-31 and 2011-04-30.
# 2019-05-05 16:12:27,629 - INFO - 22988 - Training dataset is between 2011-01-31 and 2011-03-02.
# 2019-05-05 16:12:27,638 - INFO - 22988 - Training a model to be tested between 2011-04-30 and 2011-05-31.
# 2019-05-05 16:12:27,640 - INFO - 22988 - Training dataset is between 2011-02-28 and 2011-03-31.
# 2019-05-05 16:12:27,648 - INFO - 22988 - Training a model to be tested between 2011-05-31 and 2011-06-30.
# 2019-05-05 16:12:27,651 - INFO - 22988 - Training dataset is between 2011-03-31 and 2011-04-29.
# 2019-05-05 16:12:27,660 - INFO - 22988 - Training a model to be tested between 2011-06-30 and 2011-07-31.
# 2019-05-05 16:12:27,662 - INFO - 22988 - Training dataset is between 2011-05-02 and 2011-06-01.
# 2019-05-05 16:12:27,671 - INFO - 22988 - Training a model to be tested between 2011-07-31 and 2011-08-31.
# 2019-05-05 16:12:27,673 - INFO - 22988 - Training dataset is between 2011-05-31 and 2011-06-30.
# 2019-05-05 16:12:27,682 - INFO - 22988 - Training a model to be tested between 2011-08-31 and 2011-09-30.
# 2019-05-05 16:12:27,684 - INFO - 22988 - Training dataset is between 2011-06-30 and 2011-08-02.
# 2019-05-05 16:12:27,692 - INFO - 22988 - Training a model to be tested between 2011-09-30 and 2011-10-31.
# 2019-05-05 16:12:27,694 - INFO - 22988 - Training dataset is between 2011-08-01 and 2011-08-31.
# 2019-05-05 16:12:27,703 - INFO - 22988 - Training a model to be tested between 2011-10-31 and 2011-11-30.
# 2019-05-05 16:12:27,705 - INFO - 22988 - Training dataset is between 2011-08-31 and 2011-09-30.
# 2019-05-05 16:12:27,712 - INFO - 22988 - Training a model to be tested between 2011-11-30 and 2011-12-31.
# 2019-05-05 16:12:27,714 - INFO - 22988 - Training dataset is between 2011-09-30 and 2011-10-31.
# 2019-05-05 16:12:27,723 - INFO - 22988 - Training a model to be tested between 2011-12-31 and 2012-01-31.
# 2019-05-05 16:12:27,725 - INFO - 22988 - Training dataset is between 2011-10-31 and 2011-12-01.
# 2019-05-05 16:12:27,733 - INFO - 22988 - Training a model to be tested between 2012-01-31 and 2012-02-29.
# 2019-05-05 16:12:27,736 - INFO - 22988 - Training dataset is between 2011-11-30 and 2011-12-29.
# 2019-05-05 16:12:27,744 - INFO - 22988 - Training a model to be tested between 2012-02-29 and 2012-03-31.
# 2019-05-05 16:12:27,746 - INFO - 22988 - Training dataset is between 2011-12-29 and 2012-01-30.
# 2019-05-05 16:12:27,754 - INFO - 22988 - Training a model to be tested between 2012-03-31 and 2012-04-30.
# 2019-05-05 16:12:27,756 - INFO - 22988 - Training dataset is between 2012-01-31 and 2012-03-02.
# 2019-05-05 16:12:27,765 - INFO - 22988 - Training a model to be tested between 2012-04-30 and 2012-05-31.
# 2019-05-05 16:12:27,767 - INFO - 22988 - Training dataset is between 2012-02-29 and 2012-03-29.
# 2019-05-05 16:12:27,775 - INFO - 22988 - Training a model to be tested between 2012-05-31 and 2012-06-30.
# 2019-05-05 16:12:27,778 - INFO - 22988 - Training dataset is between 2012-04-02 and 2012-05-01.
# 2019-05-05 16:12:27,785 - INFO - 22988 - Training a model to be tested between 2012-06-30 and 2012-07-31.
# 2019-05-05 16:12:27,787 - INFO - 22988 - Training dataset is between 2012-04-30 and 2012-06-01.
# 2019-05-05 16:12:27,796 - INFO - 22988 - Training a model to be tested between 2012-07-31 and 2012-08-31.
# 2019-05-05 16:12:27,798 - INFO - 22988 - Training dataset is between 2012-05-31 and 2012-06-29.
# 2019-05-05 16:12:27,807 - INFO - 22988 - Training a model to be tested between 2012-08-31 and 2012-09-30.
# 2019-05-05 16:12:27,809 - INFO - 22988 - Training dataset is between 2012-07-02 and 2012-08-02.
# 2019-05-05 16:12:27,817 - INFO - 22988 - Training a model to be tested between 2012-09-30 and 2012-10-31.
# 2019-05-05 16:12:27,820 - INFO - 22988 - Training dataset is between 2012-07-30 and 2012-08-30.
# 2019-05-05 16:12:27,829 - INFO - 22988 - Training a model to be tested between 2012-10-31 and 2012-11-30.
# 2019-05-05 16:12:27,832 - INFO - 22988 - Training dataset is between 2012-08-31 and 2012-09-28.
# 2019-05-05 16:12:27,840 - INFO - 22988 - Training a model to be tested between 2012-11-30 and 2012-12-31.
# 2019-05-05 16:12:27,843 - INFO - 22988 - Training dataset is between 2012-10-01 and 2012-10-31.
# 2019-05-05 16:12:27,853 - INFO - 22988 - Training a model to be tested between 2012-12-31 and 2013-01-31.
# 2019-05-05 16:12:27,857 - INFO - 22988 - Training dataset is between 2012-10-31 and 2012-11-29.
# 2019-05-05 16:12:27,866 - INFO - 22988 - Training a model to be tested between 2013-01-31 and 2013-02-28.
# 2019-05-05 16:12:27,869 - INFO - 22988 - Training dataset is between 2012-11-30 and 2012-12-31.
# 2019-05-05 16:12:27,879 - INFO - 22988 - Training a model to be tested between 2013-02-28 and 2013-03-31.
# 2019-05-05 16:12:27,882 - INFO - 22988 - Training dataset is between 2012-12-28 and 2013-01-29.
# 2019-05-05 16:12:27,891 - INFO - 22988 - Training a model to be tested between 2013-03-31 and 2013-04-30.
# 2019-05-05 16:12:27,893 - INFO - 22988 - Training dataset is between 2013-01-31 and 2013-02-28.
# 2019-05-05 16:12:27,903 - INFO - 22988 - Training a model to be tested between 2013-04-30 and 2013-05-31.
# 2019-05-05 16:12:27,905 - INFO - 22988 - Training dataset is between 2013-02-28 and 2013-04-01.
# 2019-05-05 16:12:27,916 - INFO - 22988 - Training a model to be tested between 2013-05-31 and 2013-06-30.
# 2019-05-05 16:12:27,918 - INFO - 22988 - Training dataset is between 2013-04-01 and 2013-05-01.
# 2019-05-05 16:12:27,929 - INFO - 22988 - Training a model to be tested between 2013-06-30 and 2013-07-31.
# 2019-05-05 16:12:27,933 - INFO - 22988 - Training dataset is between 2013-04-30 and 2013-05-31.
# 2019-05-05 16:12:27,944 - INFO - 22988 - Training a model to be tested between 2013-07-31 and 2013-08-31.
# 2019-05-05 16:12:27,946 - INFO - 22988 - Training dataset is between 2013-05-31 and 2013-07-01.
# 2019-05-05 16:12:27,956 - INFO - 22988 - Training a model to be tested between 2013-08-31 and 2013-09-30.
# 2019-05-05 16:12:27,959 - INFO - 22988 - Training dataset is between 2013-07-01 and 2013-08-02.
# 2019-05-05 16:12:27,968 - INFO - 22988 - Training a model to be tested between 2013-09-30 and 2013-10-31.
# 2019-05-05 16:12:27,970 - INFO - 22988 - Training dataset is between 2013-07-30 and 2013-08-29.
# 2019-05-05 16:12:27,981 - INFO - 22988 - Training a model to be tested between 2013-10-31 and 2013-11-30.
# 2019-05-05 16:12:27,983 - INFO - 22988 - Training dataset is between 2013-09-03 and 2013-10-02.
# 2019-05-05 16:12:27,991 - INFO - 22988 - Training a model to be tested between 2013-11-30 and 2013-12-31.
# 2019-05-05 16:12:27,994 - INFO - 22988 - Training dataset is between 2013-09-30 and 2013-10-31.
# 2019-05-05 16:12:28,004 - INFO - 22988 - Training a model to be tested between 2013-12-31 and 2014-01-31.
# 2019-05-05 16:12:28,006 - INFO - 22988 - Training dataset is between 2013-10-31 and 2013-11-29.
# 2019-05-05 16:12:28,015 - INFO - 22988 - Training a model to be tested between 2014-01-31 and 2014-02-28.
# 2019-05-05 16:12:28,018 - INFO - 22988 - Training dataset is between 2013-12-02 and 2013-12-31.
# 2019-05-05 16:12:28,027 - INFO - 22988 - Training a model to be tested between 2014-02-28 and 2014-03-31.
# 2019-05-05 16:12:28,030 - INFO - 22988 - Training dataset is between 2013-12-30 and 2014-01-29.
# 2019-05-05 16:12:28,041 - INFO - 22988 - Training a model to be tested between 2014-03-31 and 2014-04-30.
# 2019-05-05 16:12:28,044 - INFO - 22988 - Training dataset is between 2014-01-31 and 2014-02-28.
# 2019-05-05 16:12:28,052 - INFO - 22988 - Training a model to be tested between 2014-04-30 and 2014-05-31.
# 2019-05-05 16:12:28,054 - INFO - 22988 - Training dataset is between 2014-02-28 and 2014-03-31.
# 2019-05-05 16:12:28,065 - INFO - 22988 - Training a model to be tested between 2014-05-31 and 2014-06-30.
# 2019-05-05 16:12:28,068 - INFO - 22988 - Training dataset is between 2014-03-31 and 2014-05-01.
# 2019-05-05 16:12:28,076 - INFO - 22988 - Training a model to be tested between 2014-06-30 and 2014-07-31.
# 2019-05-05 16:12:28,077 - INFO - 22988 - Training dataset is between 2014-04-30 and 2014-05-30.
# 2019-05-05 16:12:28,087 - INFO - 22988 - Training a model to be tested between 2014-07-31 and 2014-08-31.
# 2019-05-05 16:12:28,089 - INFO - 22988 - Training dataset is between 2014-06-02 and 2014-07-01.
# 2019-05-05 16:12:28,097 - INFO - 22988 - Training a model to be tested between 2014-08-31 and 2014-09-30.
# 2019-05-05 16:12:28,100 - INFO - 22988 - Training dataset is between 2014-06-30 and 2014-08-01.
# 2019-05-05 16:12:28,109 - INFO - 22988 - Training a model to be tested between 2014-09-30 and 2014-10-31.
# 2019-05-05 16:12:28,111 - INFO - 22988 - Training dataset is between 2014-07-30 and 2014-08-29.
# 2019-05-05 16:12:28,119 - INFO - 22988 - Training a model to be tested between 2014-10-31 and 2014-11-30.
# 2019-05-05 16:12:28,121 - INFO - 22988 - Training dataset is between 2014-09-02 and 2014-10-02.
# 2019-05-05 16:12:28,131 - INFO - 22988 - Training a model to be tested between 2014-11-30 and 2014-12-31.
# 2019-05-05 16:12:28,133 - INFO - 22988 - Training dataset is between 2014-09-30 and 2014-10-30.
# 2019-05-05 16:12:28,143 - INFO - 22988 - Training a model to be tested between 2014-12-31 and 2015-01-31.
# 2019-05-05 16:12:28,144 - INFO - 22988 - Training dataset is between 2014-10-31 and 2014-12-01.
# 2019-05-05 16:12:28,152 - INFO - 22988 - Training a model to be tested between 2015-01-31 and 2015-02-28.
# 2019-05-05 16:12:28,155 - INFO - 22988 - Training dataset is between 2014-12-01 and 2014-12-31.
# 2019-05-05 16:12:28,164 - INFO - 22988 - Training a model to be tested between 2015-02-28 and 2015-03-31.
# 2019-05-05 16:12:28,167 - INFO - 22988 - Training dataset is between 2014-12-29 and 2015-01-29.
# 2019-05-05 16:12:28,175 - INFO - 22988 - Training a model to be tested between 2015-03-31 and 2015-04-30.
# 2019-05-05 16:12:28,177 - INFO - 22988 - Training dataset is between 2015-02-02 and 2015-03-02.
# 2019-05-05 16:12:28,185 - INFO - 22988 - Training a model to be tested between 2015-04-30 and 2015-05-31.
# 2019-05-05 16:12:28,188 - INFO - 22988 - Training dataset is between 2015-03-02 and 2015-03-31.
# 2019-05-05 16:12:28,195 - INFO - 22988 - Training a model to be tested between 2015-05-31 and 2015-06-30.
# 2019-05-05 16:12:28,197 - INFO - 22988 - Training dataset is between 2015-03-31 and 2015-04-30.
# 2019-05-05 16:12:28,206 - INFO - 22988 - Training a model to be tested between 2015-06-30 and 2015-07-31.
# 2019-05-05 16:12:28,208 - INFO - 22988 - Training dataset is between 2015-04-30 and 2015-06-01.
# 2019-05-05 16:12:28,216 - INFO - 22988 - Training a model to be tested between 2015-07-31 and 2015-08-31.
# 2019-05-05 16:12:28,218 - INFO - 22988 - Training dataset is between 2015-06-01 and 2015-07-01.
# 2019-05-05 16:12:28,227 - INFO - 22988 - Training a model to be tested between 2015-08-31 and 2015-09-30.
# 2019-05-05 16:12:28,228 - INFO - 22988 - Training dataset is between 2015-06-30 and 2015-07-31.
# 2019-05-05 16:12:28,236 - INFO - 22988 - Training a model to be tested between 2015-09-30 and 2015-10-31.
# 2019-05-05 16:12:28,239 - INFO - 22988 - Training dataset is between 2015-07-30 and 2015-08-31.
# 2019-05-05 16:12:28,248 - INFO - 22988 - Training a model to be tested between 2015-10-31 and 2015-11-30.
# 2019-05-05 16:12:28,251 - INFO - 22988 - Training dataset is between 2015-08-31 and 2015-10-02.
# 2019-05-05 16:12:28,258 - INFO - 22988 - Training a model to be tested between 2015-11-30 and 2015-12-31.
# 2019-05-05 16:12:28,260 - INFO - 22988 - Training dataset is between 2015-09-30 and 2015-10-29.
# 2019-05-05 16:12:28,269 - INFO - 22988 - Training a model to be tested between 2015-12-31 and 2016-01-31.
# 2019-05-05 16:12:28,271 - INFO - 22988 - Training dataset is between 2015-11-02 and 2015-12-01.
# 2019-05-05 16:12:28,279 - INFO - 22988 - Training a model to be tested between 2016-01-31 and 2016-02-29.
# 2019-05-05 16:12:28,281 - INFO - 22988 - Training dataset is between 2015-11-30 and 2015-12-30.
# 2019-05-05 16:12:28,290 - INFO - 22988 - Training a model to be tested between 2016-02-29 and 2016-03-31.
# 2019-05-05 16:12:28,292 - INFO - 22988 - Training dataset is between 2015-12-29 and 2016-01-28.
# 2019-05-05 16:12:28,300 - INFO - 22988 - Training a model to be tested between 2016-03-31 and 2016-04-30.
# 2019-05-05 16:12:28,303 - INFO - 22988 - Training dataset is between 2016-02-01 and 2016-03-01.
# 2019-05-05 16:12:28,311 - INFO - 22988 - Training a model to be tested between 2016-04-30 and 2016-05-31.
# 2019-05-05 16:12:28,313 - INFO - 22988 - Training dataset is between 2016-02-29 and 2016-04-01.
# 2019-05-05 16:12:28,322 - INFO - 22988 - Training a model to be tested between 2016-05-31 and 2016-06-30.
# 2019-05-05 16:12:28,324 - INFO - 22988 - Training dataset is between 2016-03-31 and 2016-04-29.
# 2019-05-05 16:12:28,333 - INFO - 22988 - Training a model to be tested between 2016-06-30 and 2016-07-31.
# 2019-05-05 16:12:28,335 - INFO - 22988 - Training dataset is between 2016-05-02 and 2016-06-01.
# 2019-05-05 16:12:28,343 - INFO - 22988 - Training a model to be tested between 2016-07-31 and 2016-08-31.
# 2019-05-05 16:12:28,345 - INFO - 22988 - Training dataset is between 2016-05-31 and 2016-06-30.
# 2019-05-05 16:12:28,354 - INFO - 22988 - Training a model to be tested between 2016-08-31 and 2016-09-30.
# 2019-05-05 16:12:28,356 - INFO - 22988 - Training dataset is between 2016-06-30 and 2016-08-02.
# 2019-05-05 16:12:28,364 - INFO - 22988 - Training a model to be tested between 2016-09-30 and 2016-10-31.
# 2019-05-05 16:12:28,367 - INFO - 22988 - Training dataset is between 2016-08-01 and 2016-08-31.
# 2019-05-05 16:12:28,374 - INFO - 22988 - Training a model to be tested between 2016-10-31 and 2016-11-30.
# 2019-05-05 16:12:28,376 - INFO - 22988 - Training dataset is between 2016-08-31 and 2016-09-30.
# 2019-05-05 16:12:28,385 - INFO - 22988 - Training a model to be tested between 2016-11-30 and 2016-12-31.
# 2019-05-05 16:12:28,387 - INFO - 22988 - Training dataset is between 2016-09-30 and 2016-10-31.
# 2019-05-05 16:12:28,396 - INFO - 22988 - Training a model to be tested between 2016-12-31 and 2017-01-31.
# 2019-05-05 16:12:28,399 - INFO - 22988 - Training dataset is between 2016-10-31 and 2016-12-01.
# 2019-05-05 16:12:28,407 - INFO - 22988 - Training a model to be tested between 2017-01-31 and 2017-02-28.
# 2019-05-05 16:12:28,409 - INFO - 22988 - Training dataset is between 2016-11-30 and 2016-12-29.
# 2019-05-05 16:12:28,417 - INFO - 22988 - Training a model to be tested between 2017-02-28 and 2017-03-31.
# 2019-05-05 16:12:28,420 - INFO - 22988 - Training dataset is between 2016-12-28 and 2017-01-27.
# 2019-05-05 16:12:28,428 - INFO - 22988 - Training a model to be tested between 2017-03-31 and 2017-04-30.
# 2019-05-05 16:12:28,430 - INFO - 22988 - Training dataset is between 2017-01-31 and 2017-03-02.
# 2019-05-05 16:12:28,438 - INFO - 22988 - Training a model to be tested between 2017-04-30 and 2017-05-31.
# 2019-05-05 16:12:28,441 - INFO - 22988 - Training dataset is between 2017-02-28 and 2017-03-30.
# 2019-05-05 16:12:28,450 - INFO - 22988 - Training a model to be tested between 2017-05-31 and 2017-06-30.
# 2019-05-05 16:12:28,452 - INFO - 22988 - Training dataset is between 2017-03-31 and 2017-05-01.
# 2019-05-05 16:12:28,461 - INFO - 22988 - Training a model to be tested between 2017-06-30 and 2017-07-31.
# 2019-05-05 16:12:28,462 - INFO - 22988 - Training dataset is between 2017-05-01 and 2017-06-01.
# 2019-05-05 16:12:28,470 - INFO - 22988 - Training a model to be tested between 2017-07-31 and 2017-08-31.
# 2019-05-05 16:12:28,472 - INFO - 22988 - Training dataset is between 2017-05-31 and 2017-06-29.
# 2019-05-05 16:12:28,481 - INFO - 22988 - Training a model to be tested between 2017-08-31 and 2017-09-30.
# 2019-05-05 16:12:28,483 - INFO - 22988 - Training dataset is between 2017-06-30 and 2017-08-02.
# 2019-05-05 16:12:28,491 - INFO - 22988 - Training a model to be tested between 2017-09-30 and 2017-10-31.
# 2019-05-05 16:12:28,493 - INFO - 22988 - Training dataset is between 2017-07-31 and 2017-08-31.
# 2019-05-05 16:12:28,501 - INFO - 22988 - Training a model to be tested between 2017-10-31 and 2017-11-30.
# 2019-05-05 16:12:28,504 - INFO - 22988 - Training dataset is between 2017-08-31 and 2017-10-02.
# 2019-05-05 16:12:28,512 - INFO - 22988 - Training a model to be tested between 2017-11-30 and 2017-12-31.
# 2019-05-05 16:12:28,514 - INFO - 22988 - Training dataset is between 2017-10-02 and 2017-10-31.
# 2019-05-05 16:12:28,523 - INFO - 22988 - Training a model to be tested between 2017-12-31 and 2018-01-31.
# 2019-05-05 16:12:28,525 - INFO - 22988 - Training dataset is between 2017-10-31 and 2017-11-30.
# 2019-05-05 16:12:28,533 - INFO - 22988 - Training a model to be tested between 2018-01-31 and 2018-02-28.
# 2019-05-05 16:12:28,535 - INFO - 22988 - Training dataset is between 2017-11-30 and 2017-12-29.
# 2019-05-05 16:12:28,544 - INFO - 22988 - Training a model to be tested between 2018-02-28 and 2018-03-31.
# 2019-05-05 16:12:28,546 - INFO - 22988 - Training dataset is between 2017-12-28 and 2018-01-29.
# 2019-05-05 16:12:28,554 - INFO - 22988 - Training a model to be tested between 2018-03-31 and 2018-04-30.
# 2019-05-05 16:12:28,556 - INFO - 22988 - Training dataset is between 2018-01-31 and 2018-03-01.
# 2019-05-05 16:12:28,564 - INFO - 22988 - Training a model to be tested between 2018-04-30 and 2018-05-31.
# 2019-05-05 16:12:28,565 - INFO - 22988 - Training dataset is between 2018-02-28 and 2018-03-29.
# 2019-05-05 16:12:28,573 - INFO - 22988 - Training a model to be tested between 2018-05-31 and 2018-06-30.
# 2019-05-05 16:12:28,576 - INFO - 22988 - Training dataset is between 2018-04-02 and 2018-05-01.
# 2019-05-05 16:12:28,585 - INFO - 22988 - Training a model to be tested between 2018-06-30 and 2018-07-31.
# 2019-05-05 16:12:28,587 - INFO - 22988 - Training dataset is between 2018-04-30 and 2018-06-01.
# 2019-05-05 16:12:28,595 - INFO - 22988 - Training a model to be tested between 2018-07-31 and 2018-08-31.
# 2019-05-05 16:12:28,597 - INFO - 22988 - Training dataset is between 2018-05-31 and 2018-06-29.
# 2019-05-05 16:12:28,606 - INFO - 22988 - Training a model to be tested between 2018-08-31 and 2018-09-30.
# 2019-05-05 16:12:28,608 - INFO - 22988 - Training dataset is between 2018-07-02 and 2018-08-02.
# 2019-05-05 16:12:28,617 - INFO - 22988 - Training a model to be tested between 2018-09-30 and 2018-10-31.
# 2019-05-05 16:12:28,619 - INFO - 22988 - Training dataset is between 2018-07-30 and 2018-08-30.
# 2019-05-05 16:12:28,627 - INFO - 22988 - Training a model to be tested between 2018-10-31 and 2018-11-30.
# 2019-05-05 16:12:28,629 - INFO - 22988 - Training dataset is between 2018-08-31 and 2018-10-02.
# 2019-05-05 16:12:28,638 - INFO - 22988 - Training a model to be tested between 2018-11-30 and 2018-12-31.
# 2019-05-05 16:12:28,640 - INFO - 22988 - Training dataset is between 2018-10-01 and 2018-10-31.

# %%
get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, with_benchmark=True, with_delta=True)
# Out:
#                   main     benchmark     delta
# alpha        -0.032984  4.190292e-16       NaN
# beta          0.227990  1.000000e+00       NaN
# cagr         -0.035045  5.169112e-02 -0.086736
# max_drawdown -0.637050 -5.518942e-01 -0.085156
# return       -0.488736  1.580001e+00 -2.068737
# sharpe       -0.090189  3.588021e-01 -0.448991
# var          -0.018687 -1.920933e-02  0.000522
# volatility    0.191946  1.915877e-01  0.000359

# %% [markdown]
# Now that we don't have look ahead bias, the CAGR is -3.5%. It has more sense.
#
# The conclusion of this notebook is that happiness doesn't last too much.
