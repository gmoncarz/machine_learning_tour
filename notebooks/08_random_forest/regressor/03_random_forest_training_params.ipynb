# %% [markdown]
# # Tunning Random Forest training parameters

# %% [markdown]
# It is going to be analyzed the impact of the following random forest constrains:
# - max depth
# - minimum amount of samples per leaf
# - minimum amount of samples to split a node
# - Diferent error criteria: MSE, Friedman MSE, and MAE
# - Different amount of parallel trees

# %%
import logging
import imp
from dateutil.relativedelta import relativedelta
from collections import OrderedDict
import sys

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
sys.path.append('../..')

from helpers.dataset import read_quote_dataset, preprocess_quotes
from helpers.backtest import train_model_and_backtest_regressor, get_backtest_performance_metrics
from helpers.visualization import plot_return

# %%
# Configir logging module for jypter notebook
imp.reload(logging)
logging_format = '%(asctime)s - %(levelname)s - %(process)s - %(message)s'
logging.basicConfig(level=logging.DEBUG, format=logging_format)

# Disable backtesting logs
logging.getLogger('helpers.backtest').setLevel(level=logging.WARNING)

# %%
PARAM_DATASET = '../../../data/SPY_postprocess_adj.csv.gz'

# %%
df = read_quote_dataset(PARAM_DATASET)

# %%
df.head()
# Out:
#         date        open        high         low     close   close_adj  \
# 0 2000-01-03  148.250000  148.250000  143.875000  145.4375  101.425385
# 1 2000-01-04  143.531204  144.062500  139.640594  139.7500   97.459068
# 2 2000-01-05  139.937500  141.531204  137.250000  140.0000   97.633377
# 3 2000-01-06  139.625000  141.500000  137.750000  137.7500   96.064301
# 4 2000-01-07  140.312500  145.750000  140.062500  145.7500  101.643333
#
#      volume    open_adj     low_adj    high_adj  ...  \
# 0   8164300  103.386770  100.335727  103.386770  ...
# 1   8089800  100.096010   97.382770  100.466526  ...
# 2  12177900   97.589791   95.715579   98.701210  ...
# 3   6227200   97.371891   96.064301   98.679482  ...
# 4   8066500   97.851322   97.676977  101.643333  ...
#
#    ratio_close_adj_000_close_adj_005_norm  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ratio_close_adj_000_close_adj_020_norm  ratio_close_adj_000_ema_005_norm  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                          0.486630
# 4                                     NaN                          0.815422
#
#    ratio_close_adj_000_ema_010_norm  ratio_close_adj_000_ema_020_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ratio_close_adj_000_ema_050_norm  ratio_close_adj_000_sma_005_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                          0.740588
#
#    ratio_close_adj_000_sma_010_norm  ratio_close_adj_000_sma_020_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ratio_close_adj_000_sma_050_norm
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 173 columns]

# %%
vars_to_shift = ['close_adj', 'close_adj_norm', 'close_adj_std']
shift_periods = [1, 5, 10, 20]
vars_for_return = ['close_adj']
return_periods = [1, 5, 10, 20]

# %%
df = preprocess_quotes(
    df, vars_to_shift=vars_to_shift, shift_periods=shift_periods,
    vars_for_return=vars_for_return, return_periods=return_periods,
    shift_date=True
)

# %%
df[['date', 'close_adj', 'date_shift_1', 'close_adj_shift_1', 'close_adj_ret_1', 
    'date_shift_5', 'close_adj_shift_5', 'close_adj_ret_5']].head(10)
# Out:
#         date   close_adj date_shift_1  close_adj_shift_1  close_adj_ret_1  \
# 0 2000-01-03  101.425385   2000-01-04          97.459068        -0.039106
# 1 2000-01-04   97.459068   2000-01-05          97.633377         0.001789
# 2 2000-01-05   97.633377   2000-01-06          96.064301        -0.016071
# 3 2000-01-06   96.064301   2000-01-07         101.643333         0.058076
# 4 2000-01-07  101.643333   2000-01-10         101.992004         0.003430
# 5 2000-01-10  101.992004   2000-01-11         100.771645        -0.011965
# 6 2000-01-11  100.771645   2000-01-12          99.769150        -0.009948
# 7 2000-01-12   99.769150   2000-01-13         101.120308         0.013543
# 8 2000-01-13  101.120308   2000-01-14         102.493233         0.013577
# 9 2000-01-14  102.493233   2000-01-18         101.686958        -0.007867
#
#   date_shift_5  close_adj_shift_5  close_adj_ret_5
# 0   2000-01-10         101.992004         0.005587
# 1   2000-01-11         100.771645         0.033989
# 2   2000-01-12          99.769150         0.021875
# 3   2000-01-13         101.120308         0.052631
# 4   2000-01-14         102.493233         0.008362
# 5   2000-01-18         101.686958        -0.002991
# 6   2000-01-19         102.515060         0.017301
# 7   2000-01-20         100.945953         0.011795
# 8   2000-01-21         100.727989        -0.003880
# 9   2000-01-24          97.873047        -0.045078

# %% [markdown]
# # Processing all the input variables

# %% [markdown]
# On the data processing notebook, it was computed all the historical variables. Lets review them

# %%
x_vars_all = list(filter(lambda varname: 
                ('_adj' in varname or 'volume' in varname)and
                not '_shift_' in varname and
                not '_std' in varname and
                not '_norm' in varname and
                not '_ret_' in varname, 
            df.columns))

# %%
logging.info('There are in total %d dependent variables', len(x_vars_all))
# Out:
# 2019-06-23 19:21:11,095 - INFO - 8190 - There are in total 53 dependent variables

# %%
x_vars_all
# Out:
# ['close_adj',
#  'volume',
#  'open_adj',
#  'low_adj',
#  'high_adj',
#  'slope_close_adj_005',
#  'slope_volume_005',
#  'slope_close_adj_010',
#  'slope_volume_010',
#  'slope_close_adj_020',
#  'slope_volume_020',
#  'slope_close_adj_050',
#  'slope_volume_050',
#  'sma_close_adj_005',
#  'sma_volume_005',
#  'ema_close_adj_005',
#  'ema_volume_005',
#  'sma_close_adj_010',
#  'sma_volume_010',
#  'ema_close_adj_010',
#  'ema_volume_010',
#  'sma_close_adj_020',
#  'sma_volume_020',
#  'ema_close_adj_020',
#  'ema_volume_020',
#  'sma_close_adj_050',
#  'sma_volume_050',
#  'ema_close_adj_050',
#  'ema_volume_050',
#  'lag_close_adj_001',
#  'lag_volume_001',
#  'lag_close_adj_005',
#  'lag_volume_005',
#  'lag_close_adj_010',
#  'lag_volume_010',
#  'lag_close_adj_020',
#  'lag_volume_020',
#  'lag_close_adj_060',
#  'lag_volume_060',
#  'ratio_volume_000_sma_005',
#  'ratio_volume_000_sma_020',
#  'ratio_volume_000_ema_050',
#  'ratio_close_adj_000_close_adj_001',
#  'ratio_close_adj_000_close_adj_005',
#  'ratio_close_adj_000_close_adj_020',
#  'ratio_close_adj_000_ema_005',
#  'ratio_close_adj_000_ema_010',
#  'ratio_close_adj_000_ema_020',
#  'ratio_close_adj_000_ema_050',
#  'ratio_close_adj_000_sma_005',
#  'ratio_close_adj_000_sma_010',
#  'ratio_close_adj_000_sma_020',
#  'ratio_close_adj_000_sma_050']

# %% [markdown]
# Divive them by categories

# %%
x_vars_slope = list(filter(lambda var: var.startswith('slope_'), x_vars_all))
x_vars_sma = list(filter(lambda var: var.startswith('sma_'), x_vars_all))
x_vars_ema = list(filter(lambda var: var.startswith('ema_'), x_vars_all))
x_vars_lagged = list(filter(lambda var: var.startswith('lag_'), x_vars_all))
x_vars_ratio_close_adj = list(filter(lambda var: var.startswith('ratio_close_adj_'), x_vars_all))
x_vars_ratio_volume = list(filter(lambda var: var.startswith('ratio_volume_'), x_vars_all))

# %% [markdown]
# # Run backtests with different set of random forest parameters

# %% [markdown]
# Define the inputs

# %%
x_var_set = OrderedDict()
x_var_set['all'] = x_vars_all
x_var_set['close_adj'] = ['close_adj']
x_var_set['olh'] = ['open_adj', 'low_adj', 'high_adj']
x_var_set['olhc'] = ['open_adj', 'low_adj', 'high_adj', 'close_adj']
x_var_set['olhv'] = ['open_adj', 'low_adj', 'high_adj', 'volume']
x_var_set['olhcv'] = ['open_adj', 'low_adj', 'high_adj', 'close_adj', 'volume']
x_var_set['volume'] = ['volume']
#x_var_set['slope'] = x_vars_slope
x_var_set['sma'] = x_vars_sma
x_var_set['ema'] = x_vars_ema
x_var_set['lagged'] = x_vars_lagged
#x_var_set['ratio_closed_adj'] = x_vars_ratio_close_adj
#x_var_set['ratio_vol'] = x_vars_ratio_volume
x_var_set['olh_sma'] = ['open_adj', 'low_adj', 'high_adj'] + x_vars_sma
x_var_set['olh_ema'] = ['open_adj', 'low_adj', 'high_adj'] + x_vars_ema
x_var_set['olh_slope'] = ['open_adj', 'low_adj', 'high_adj'] + x_vars_slope

# %% [markdown]
# ### Try min sample per leaf

# %%
model_params = OrderedDict()

model_params['defalt'] = {'n_estimators': 10, 'random_state': 100, }

#model_params['depth3'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 3}
#model_params['depth4'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 4}
#model_params['depth5'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 5}
#model_params['depth6'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 6}
#model_params['depth7'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 7}
#model_params['depth8'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 8}
#model_params['depth9'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 10}

model_params['min_samp_leaf-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
model_params['min_samp_leaf-20'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
model_params['min_samp_leaf-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 50}
#model_params['min_samp_leaf-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 100}
#model_params['min_samp_leaf-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 200}
#model_params['min_samp_leaf-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 500}
#model_params['min_samp_leaf-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 1000}

#model_params['min_samp_split-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 100}
#model_params['min_samp_split-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 200}
#model_params['min_samp_split-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 500}
#model_params['min_samp_split-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 1000}

#model_params['friedman_mse'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'friedman_mse'}
#model_params['mae'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'mae'}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = RandomForestRegressor

        # logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# CPU times: user 2min 43s, sys: 227 ms, total: 2min 43s
# Wall time: 2min 43s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                                    alpha      beta      cagr  max_drawdown  \
# defalt-olh                  7.777427e-02  0.306185  0.083312     -0.381271
# defalt-sma                  6.151127e-02  0.265823  0.062991     -0.383837
# defalt-olh_ema              5.060987e-02  0.303266  0.054098     -0.296095
# defalt-olhcv                4.756235e-02  0.346221  0.053894     -0.393737
# defalt-olhv                 4.763374e-02  0.344222  0.053830     -0.440767
# benchmark                  -3.681556e-16  1.000000  0.049527     -0.551894
# defalt-ema                  4.330849e-02  0.321117  0.047672     -0.322004
# defalt-olhc                 3.127856e-02  0.316630  0.034839     -0.492169
# defalt-olh_sma              2.865874e-02  0.312087  0.031816     -0.331957
# defalt-close_adj            1.007786e-02  0.264984  0.009662     -0.471655
# min_samp_leaf-20-olh_sma    2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-all        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-20-olh_slope  2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-20-olh_ema    2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-20-ema        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-20-lagged     2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olh        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-20-sma        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-close_adj  2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-sma        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olhc       2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olhv       2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olhcv      2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-volume     2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-20-olhcv      2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-ema        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-lagged     2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olh_sma    2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olh_ema    2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_leaf-50-olh_slope  2.727019e-03  0.371949  0.009404     -0.442577
#
#                               return    sharpe       var  volatility
# defalt-olh                  3.413020  0.515020 -0.017202    0.190479
# defalt-sma                  2.105755  0.415700 -0.017515    0.190421
# defalt-olh_ema              1.657511  0.371909 -0.017450    0.190214
# defalt-olhcv                1.647997  0.370959 -0.017597    0.190172
# defalt-olhv                 1.645012  0.370654 -0.017450    0.190164
# benchmark                   1.451705  0.349346 -0.019044    0.190026
# defalt-ema                  1.372525  0.339788 -0.017588    0.190195
# defalt-olhc                 0.887614  0.275023 -0.017722    0.190158
# defalt-olh_sma              0.787899  0.259567 -0.017588    0.190227
# defalt-close_adj            0.195288  0.145478 -0.018061    0.190193
# min_samp_leaf-20-olh_sma    0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-all        0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-20-olh_slope  0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-20-olh_ema    0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-20-ema        0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-20-lagged     0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olh        0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-20-sma        0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-close_adj  0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-sma        0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olhc       0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olhv       0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olhcv      0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-volume     0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-20-olhcv      0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-ema        0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-lagged     0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olh_sma    0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olh_ema    0.189640  0.144100 -0.017657    0.190276
# min_samp_leaf-50-olh_slope  0.189640  0.144100 -0.017657    0.190276

# %% [markdown]
# According the tests, constraining the amount of samples per leaf doesn't help. Default params with OLH quotes is still the best model.

# %% [markdown]
# ### Try min sample split

# %%
model_params = OrderedDict()

model_params['defalt'] = {'n_estimators': 10, 'random_state': 100, }

#model_params['depth3'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 3}
#model_params['depth4'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 4}
#model_params['depth5'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 5}
#model_params['depth6'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 6}
#model_params['depth7'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 7}
#model_params['depth8'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 8}
#model_params['depth9'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 10}

#model_params['min_samp_leaf-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 50}
#model_params['min_samp_leaf-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 100}
#model_params['min_samp_leaf-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 200}
#model_params['min_samp_leaf-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 500}
#model_params['min_samp_leaf-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 1000}

model_params['min_samp_split-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 10}
model_params['min_samp_split-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 50}
model_params['min_samp_split-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 100}
#model_params['min_samp_split-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 200}
#model_params['min_samp_split-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 500}
#model_params['min_samp_split-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 1000}

#model_params['friedman_mse'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'friedman_mse'}
#model_params['mae'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'mae'}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = RandomForestRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-23 19:36:15,744 - INFO - 8190 - Backtesting with defalt - all
# 2019-06-23 19:36:18,951 - INFO - 8190 - Backtesting with defalt - close_adj
# 2019-06-23 19:36:21,794 - INFO - 8190 - Backtesting with defalt - olh
# 2019-06-23 19:36:24,771 - INFO - 8190 - Backtesting with defalt - olhc
# 2019-06-23 19:36:27,728 - INFO - 8190 - Backtesting with defalt - olhv
# 2019-06-23 19:36:30,826 - INFO - 8190 - Backtesting with defalt - olhcv
# 2019-06-23 19:36:34,440 - INFO - 8190 - Backtesting with defalt - volume
# 2019-06-23 19:36:37,458 - INFO - 8190 - Backtesting with defalt - sma
# 2019-06-23 19:36:40,334 - INFO - 8190 - Backtesting with defalt - ema
# 2019-06-23 19:36:43,469 - INFO - 8190 - Backtesting with defalt - lagged
# 2019-06-23 19:36:46,387 - INFO - 8190 - Backtesting with defalt - olh_sma
# 2019-06-23 19:36:49,274 - INFO - 8190 - Backtesting with defalt - olh_ema
# 2019-06-23 19:36:52,263 - INFO - 8190 - Backtesting with defalt - olh_slope
# 2019-06-23 19:36:55,165 - INFO - 8190 - Backtesting with min_samp_split-10 - all
# 2019-06-23 19:36:58,322 - INFO - 8190 - Backtesting with min_samp_split-10 - close_adj
# 2019-06-23 19:37:01,124 - INFO - 8190 - Backtesting with min_samp_split-10 - olh
# 2019-06-23 19:37:04,052 - INFO - 8190 - Backtesting with min_samp_split-10 - olhc
# 2019-06-23 19:37:06,985 - INFO - 8190 - Backtesting with min_samp_split-10 - olhv
# 2019-06-23 19:37:09,935 - INFO - 8190 - Backtesting with min_samp_split-10 - olhcv
# 2019-06-23 19:37:12,958 - INFO - 8190 - Backtesting with min_samp_split-10 - volume
# 2019-06-23 19:37:15,851 - INFO - 8190 - Backtesting with min_samp_split-10 - sma
# 2019-06-23 19:37:19,020 - INFO - 8190 - Backtesting with min_samp_split-10 - ema
# 2019-06-23 19:37:22,154 - INFO - 8190 - Backtesting with min_samp_split-10 - lagged
# 2019-06-23 19:37:25,299 - INFO - 8190 - Backtesting with min_samp_split-10 - olh_sma
# 2019-06-23 19:37:28,600 - INFO - 8190 - Backtesting with min_samp_split-10 - olh_ema
# 2019-06-23 19:37:31,737 - INFO - 8190 - Backtesting with min_samp_split-10 - olh_slope
# 2019-06-23 19:37:34,944 - INFO - 8190 - Backtesting with min_samp_split-50 - all
# 2019-06-23 19:37:38,325 - INFO - 8190 - Backtesting with min_samp_split-50 - close_adj
# 2019-06-23 19:37:41,518 - INFO - 8190 - Backtesting with min_samp_split-50 - olh
# 2019-06-23 19:37:44,653 - INFO - 8190 - Backtesting with min_samp_split-50 - olhc
# 2019-06-23 19:37:47,696 - INFO - 8190 - Backtesting with min_samp_split-50 - olhv
# 2019-06-23 19:37:50,924 - INFO - 8190 - Backtesting with min_samp_split-50 - olhcv
# 2019-06-23 19:37:54,211 - INFO - 8190 - Backtesting with min_samp_split-50 - volume
# 2019-06-23 19:37:57,306 - INFO - 8190 - Backtesting with min_samp_split-50 - sma
# 2019-06-23 19:38:00,356 - INFO - 8190 - Backtesting with min_samp_split-50 - ema
# 2019-06-23 19:38:03,452 - INFO - 8190 - Backtesting with min_samp_split-50 - lagged
# 2019-06-23 19:38:06,498 - INFO - 8190 - Backtesting with min_samp_split-50 - olh_sma
# 2019-06-23 19:38:09,570 - INFO - 8190 - Backtesting with min_samp_split-50 - olh_ema
# 2019-06-23 19:38:12,716 - INFO - 8190 - Backtesting with min_samp_split-50 - olh_slope
# 2019-06-23 19:38:15,808 - INFO - 8190 - Backtesting with min_samp_split-100 - all
# 2019-06-23 19:38:19,010 - INFO - 8190 - Backtesting with min_samp_split-100 - close_adj
# 2019-06-23 19:38:22,105 - INFO - 8190 - Backtesting with min_samp_split-100 - olh
# 2019-06-23 19:38:25,308 - INFO - 8190 - Backtesting with min_samp_split-100 - olhc
# 2019-06-23 19:38:28,397 - INFO - 8190 - Backtesting with min_samp_split-100 - olhv
# 2019-06-23 19:38:31,601 - INFO - 8190 - Backtesting with min_samp_split-100 - olhcv
# 2019-06-23 19:38:34,914 - INFO - 8190 - Backtesting with min_samp_split-100 - volume
# 2019-06-23 19:38:37,952 - INFO - 8190 - Backtesting with min_samp_split-100 - sma
# 2019-06-23 19:38:41,074 - INFO - 8190 - Backtesting with min_samp_split-100 - ema
# 2019-06-23 19:38:44,201 - INFO - 8190 - Backtesting with min_samp_split-100 - lagged
# 2019-06-23 19:38:47,376 - INFO - 8190 - Backtesting with min_samp_split-100 - olh_sma
# 2019-06-23 19:38:50,557 - INFO - 8190 - Backtesting with min_samp_split-100 - olh_ema
# 2019-06-23 19:38:53,746 - INFO - 8190 - Backtesting with min_samp_split-100 - olh_slope
# CPU times: user 2min 41s, sys: 292 ms, total: 2min 41s
# Wall time: 2min 41s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                                      alpha      beta      cagr  max_drawdown  \
# defalt-olh                    7.777427e-02  0.306185  0.083312     -0.381271
# defalt-sma                    6.151127e-02  0.265823  0.062991     -0.383837
# defalt-olh_ema                5.060987e-02  0.303266  0.054098     -0.296095
# defalt-olhcv                  4.756235e-02  0.346221  0.053894     -0.393737
# defalt-olhv                   4.763374e-02  0.344222  0.053830     -0.440767
# benchmark                    -3.681556e-16  1.000000  0.049527     -0.551894
# defalt-ema                    4.330849e-02  0.321117  0.047672     -0.322004
# min_samp_split-10-olhv        3.538180e-02  0.328121  0.039884     -0.368624
# min_samp_split-10-olhc        3.148797e-02  0.323168  0.035501     -0.368624
# defalt-olhc                   3.127856e-02  0.316630  0.034839     -0.492169
# defalt-olh_sma                2.865874e-02  0.312087  0.031816     -0.331957
# min_samp_split-10-olhcv       1.686680e-02  0.352337  0.022451     -0.405874
# min_samp_split-10-sma         1.888494e-02  0.294862  0.020614     -0.419106
# min_samp_split-10-olh         1.441298e-02  0.315491  0.017453     -0.385245
# defalt-close_adj              1.007786e-02  0.264984  0.009662     -0.471655
# min_samp_split-100-olh_ema    2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-olhc       2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-50-olh_sma     2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-50-olh_ema     2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-50-olh_slope   2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-all        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-close_adj  2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-olh        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-volume     2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-olhv       2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-olhcv      2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-sma        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-50-ema         2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-ema        2.727019e-03  0.371949  0.009404     -0.442577
# min_samp_split-100-lagged     2.727019e-03  0.371949  0.009404     -0.442577
#
#                                 return    sharpe       var  volatility
# defalt-olh                    3.413020  0.515020 -0.017202    0.190479
# defalt-sma                    2.105755  0.415700 -0.017515    0.190421
# defalt-olh_ema                1.657511  0.371909 -0.017450    0.190214
# defalt-olhcv                  1.647997  0.370959 -0.017597    0.190172
# defalt-olhv                   1.645012  0.370654 -0.017450    0.190164
# benchmark                     1.451705  0.349346 -0.019044    0.190026
# defalt-ema                    1.372525  0.339788 -0.017588    0.190195
# min_samp_split-10-olhv        1.065843  0.300555 -0.017450    0.190195
# min_samp_split-10-olhc        0.910151  0.278322 -0.017597    0.190216
# defalt-olhc                   0.887614  0.275023 -0.017722    0.190158
# defalt-olh_sma                0.787899  0.259567 -0.017588    0.190227
# min_samp_split-10-olhcv       0.509667  0.211651 -0.017795    0.190202
# min_samp_split-10-sma         0.460151  0.202195 -0.017657    0.190209
# min_samp_split-10-olh         0.378499  0.185891 -0.017768    0.190202
# defalt-close_adj              0.195288  0.145478 -0.018061    0.190193
# min_samp_split-100-olh_ema    0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-olhc       0.189640  0.144100 -0.017657    0.190276
# min_samp_split-50-olh_sma     0.189640  0.144100 -0.017657    0.190276
# min_samp_split-50-olh_ema     0.189640  0.144100 -0.017657    0.190276
# min_samp_split-50-olh_slope   0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-all        0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-close_adj  0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-olh        0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-volume     0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-olhv       0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-olhcv      0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-sma        0.189640  0.144100 -0.017657    0.190276
# min_samp_split-50-ema         0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-ema        0.189640  0.144100 -0.017657    0.190276
# min_samp_split-100-lagged     0.189640  0.144100 -0.017657    0.190276

# %% [markdown]
# `min_sample_split` neither seems to help

# %% [markdown]
# ### Try different error criterions

# %%
model_params = OrderedDict()

model_params['defalt'] = {'n_estimators': 10, 'random_state': 100, }

#model_params['depth3'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 3}
#model_params['depth4'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 4}
#model_params['depth5'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 5}
#model_params['depth6'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 6}
#model_params['depth7'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 7}
#model_params['depth8'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 8}
#model_params['depth9'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 10}

#model_params['min_samp_leaf-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 50}
#model_params['min_samp_leaf-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 100}
#model_params['min_samp_leaf-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 200}
#model_params['min_samp_leaf-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 500}
#model_params['min_samp_leaf-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 1000}

#model_params['min_samp_split-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 100}
#model_params['min_samp_split-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 200}
#model_params['min_samp_split-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 500}
#model_params['min_samp_split-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 1000}

model_params['friedman_mse'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'friedman_mse'}
model_params['mae'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'mae'}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = RandomForestRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-23 19:41:51,499 - INFO - 8190 - Backtesting with defalt - all
# 2019-06-23 19:41:54,780 - INFO - 8190 - Backtesting with defalt - close_adj
# 2019-06-23 19:41:57,846 - INFO - 8190 - Backtesting with defalt - olh
# 2019-06-23 19:42:00,939 - INFO - 8190 - Backtesting with defalt - olhc
# 2019-06-23 19:42:04,559 - INFO - 8190 - Backtesting with defalt - olhv
# 2019-06-23 19:42:08,126 - INFO - 8190 - Backtesting with defalt - olhcv
# 2019-06-23 19:42:11,603 - INFO - 8190 - Backtesting with defalt - volume
# 2019-06-23 19:42:14,916 - INFO - 8190 - Backtesting with defalt - sma
# 2019-06-23 19:42:18,125 - INFO - 8190 - Backtesting with defalt - ema
# 2019-06-23 19:42:21,313 - INFO - 8190 - Backtesting with defalt - lagged
# 2019-06-23 19:42:24,455 - INFO - 8190 - Backtesting with defalt - olh_sma
# 2019-06-23 19:42:27,620 - INFO - 8190 - Backtesting with defalt - olh_ema
# 2019-06-23 19:42:30,891 - INFO - 8190 - Backtesting with defalt - olh_slope
# 2019-06-23 19:42:34,081 - INFO - 8190 - Backtesting with friedman_mse - all
# 2019-06-23 19:42:37,797 - INFO - 8190 - Backtesting with friedman_mse - close_adj
# 2019-06-23 19:42:40,977 - INFO - 8190 - Backtesting with friedman_mse - olh
# 2019-06-23 19:42:44,154 - INFO - 8190 - Backtesting with friedman_mse - olhc
# 2019-06-23 19:42:47,382 - INFO - 8190 - Backtesting with friedman_mse - olhv
# 2019-06-23 19:42:50,641 - INFO - 8190 - Backtesting with friedman_mse - olhcv
# 2019-06-23 19:42:53,963 - INFO - 8190 - Backtesting with friedman_mse - volume
# 2019-06-23 19:42:57,313 - INFO - 8190 - Backtesting with friedman_mse - sma
# 2019-06-23 19:43:00,789 - INFO - 8190 - Backtesting with friedman_mse - ema
# 2019-06-23 19:43:04,019 - INFO - 8190 - Backtesting with friedman_mse - lagged
# 2019-06-23 19:43:07,133 - INFO - 8190 - Backtesting with friedman_mse - olh_sma
# 2019-06-23 19:43:10,101 - INFO - 8190 - Backtesting with friedman_mse - olh_ema
# 2019-06-23 19:43:13,105 - INFO - 8190 - Backtesting with friedman_mse - olh_slope
# 2019-06-23 19:43:16,134 - INFO - 8190 - Backtesting with mae - all
# 2019-06-23 19:43:20,084 - INFO - 8190 - Backtesting with mae - close_adj
# 2019-06-23 19:43:23,162 - INFO - 8190 - Backtesting with mae - olh
# 2019-06-23 19:43:26,297 - INFO - 8190 - Backtesting with mae - olhc
# 2019-06-23 19:43:29,431 - INFO - 8190 - Backtesting with mae - olhv
# 2019-06-23 19:43:32,589 - INFO - 8190 - Backtesting with mae - olhcv
# 2019-06-23 19:43:35,865 - INFO - 8190 - Backtesting with mae - volume
# 2019-06-23 19:43:38,920 - INFO - 8190 - Backtesting with mae - sma
# 2019-06-23 19:43:42,067 - INFO - 8190 - Backtesting with mae - ema
# 2019-06-23 19:43:45,173 - INFO - 8190 - Backtesting with mae - lagged
# 2019-06-23 19:43:48,336 - INFO - 8190 - Backtesting with mae - olh_sma
# 2019-06-23 19:43:51,751 - INFO - 8190 - Backtesting with mae - olh_ema
# 2019-06-23 19:43:55,488 - INFO - 8190 - Backtesting with mae - olh_slope
# CPU times: user 2min 7s, sys: 168 ms, total: 2min 7s
# Wall time: 2min 7s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                                alpha      beta      cagr  max_drawdown  \
# friedman_mse-olh        8.059738e-02  0.306582  0.086403     -0.344321
# defalt-olh              7.777427e-02  0.306185  0.083312     -0.381271
# mae-olhv                6.819692e-02  0.350583  0.076171     -0.378730
# mae-olh_ema             5.883727e-02  0.318802  0.063900     -0.350207
# friedman_mse-olh_ema    5.898965e-02  0.306731  0.063209     -0.294884
# defalt-sma              6.151127e-02  0.265823  0.062991     -0.383837
# mae-olh                 5.791268e-02  0.308074  0.062143     -0.426838
# friedman_mse-olhv       5.425485e-02  0.343742  0.060796     -0.329102
# mae-olh_sma             5.482867e-02  0.283557  0.057155     -0.359319
# friedman_mse-ema        5.012877e-02  0.317155  0.054560     -0.328484
# defalt-olh_ema          5.060987e-02  0.303266  0.054098     -0.296095
# defalt-olhcv            4.756235e-02  0.346221  0.053894     -0.393737
# defalt-olhv             4.763374e-02  0.344222  0.053830     -0.440767
# friedman_mse-sma        5.297354e-02  0.255089  0.053203     -0.406608
# benchmark              -3.681556e-16  1.000000  0.049527     -0.551894
# defalt-ema              4.330849e-02  0.321117  0.047672     -0.322004
# mae-sma                 4.383410e-02  0.259610  0.043934     -0.444163
# friedman_mse-olh_sma    3.379741e-02  0.312450  0.037157     -0.408495
# friedman_mse-olhcv      2.975746e-02  0.367274  0.036743     -0.424193
# mae-olhcv               3.065380e-02  0.337519  0.035624     -0.349215
# defalt-olhc             3.127856e-02  0.316630  0.034839     -0.492169
# defalt-olh_sma          2.865874e-02  0.312087  0.031816     -0.331957
# mae-ema                 2.767533e-02  0.320653  0.031389     -0.361743
# mae-olhc                2.484819e-02  0.318418  0.028328     -0.412952
# mae-all                 2.032060e-02  0.360517  0.026540     -0.420163
# friedman_mse-olhc       1.558506e-02  0.323831  0.019214     -0.482525
# mae-lagged              1.316856e-02  0.313719  0.016067     -0.373683
# mae-close_adj           1.554725e-02  0.266945  0.015331     -0.475161
# friedman_mse-close_adj  1.007786e-02  0.264984  0.009662     -0.471655
# defalt-close_adj        1.007786e-02  0.264984  0.009662     -0.471655
#
#                           return    sharpe       var  volatility
# friedman_mse-olh        3.652542  0.529977 -0.017256    0.190479
# defalt-olh              3.413020  0.515020 -0.017202    0.190479
# mae-olhv                2.903417  0.480804 -0.017202    0.190245
# mae-olh_ema             2.155386  0.420536 -0.017376    0.190236
# friedman_mse-olh_ema    2.117567  0.417086 -0.017333    0.190253
# defalt-sma              2.105755  0.415700 -0.017515    0.190421
# mae-olh                 2.060077  0.411361 -0.017411    0.190500
# friedman_mse-olhv       1.988881  0.405293 -0.017375    0.190169
# mae-olh_sma             1.804220  0.386773 -0.017515    0.190429
# friedman_mse-ema        1.679247  0.374172 -0.017362    0.190242
# defalt-olh_ema          1.657511  0.371909 -0.017450    0.190214
# defalt-olhcv            1.647997  0.370959 -0.017597    0.190172
# defalt-olhv             1.645012  0.370654 -0.017450    0.190164
# friedman_mse-sma        1.615995  0.367088 -0.017588    0.190438
# benchmark               1.451705  0.349346 -0.019044    0.190026
# defalt-ema              1.372525  0.339788 -0.017588    0.190195
# mae-sma                 1.220302  0.320626 -0.017657    0.190466
# friedman_mse-olh_sma    0.967614  0.286720 -0.017597    0.190218
# friedman_mse-olhcv      0.953081  0.284634 -0.017597    0.190205
# mae-olhcv               0.914356  0.278947 -0.017795    0.190215
# defalt-olhc             0.887614  0.275023 -0.017722    0.190158
# defalt-olh_sma          0.787899  0.259567 -0.017588    0.190227
# mae-ema                 0.774240  0.257416 -0.017795    0.190205
# mae-olhc                0.679042  0.241824 -0.017801    0.190165
# mae-all                 0.625707  0.232571 -0.017588    0.190280
# friedman_mse-olhc       0.423426  0.195014 -0.017801    0.190153
# mae-lagged              0.344076  0.178713 -0.017621    0.190220
# mae-close_adj           0.326119  0.174914 -0.017991    0.190198
# friedman_mse-close_adj  0.195288  0.145478 -0.018061    0.190193
# defalt-close_adj        0.195288  0.145478 -0.018061    0.190193

# %% [markdown]
# The three criterion are in the top-3: MSE, Friedman MSE and MAE. The three criterion have to be tested with more depth.

# %% [markdown]
# ### Try the most important parameter: the depth

# %%
model_params = OrderedDict()

model_params['defalt'] = {'n_estimators': 10, 'random_state': 100, }

model_params['depth3'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 3}
model_params['depth4'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 4}
model_params['depth5'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 5}
model_params['depth6'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 6}
model_params['depth7'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 7}
model_params['depth8'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 8}
model_params['depth9'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 9}
model_params['depth10'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 10}

#model_params['min_samp_leaf-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 50}
#model_params['min_samp_leaf-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 100}
#model_params['min_samp_leaf-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 200}
#model_params['min_samp_leaf-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 500}
#model_params['min_samp_leaf-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 1000}

#model_params['min_samp_split-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 100}
#model_params['min_samp_split-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 200}
#model_params['min_samp_split-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 500}
#model_params['min_samp_split-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 1000}

# model_params['friedman_mse'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'friedman_mse'}
#model_params['mae'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'mae'}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = RandomForestRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-23 19:45:57,901 - INFO - 8190 - Backtesting with defalt - all
# 2019-06-23 19:46:01,222 - INFO - 8190 - Backtesting with defalt - close_adj
# 2019-06-23 19:46:04,490 - INFO - 8190 - Backtesting with defalt - olh
# 2019-06-23 19:46:07,770 - INFO - 8190 - Backtesting with defalt - olhc
# 2019-06-23 19:46:10,976 - INFO - 8190 - Backtesting with defalt - olhv
# 2019-06-23 19:46:14,246 - INFO - 8190 - Backtesting with defalt - olhcv
# 2019-06-23 19:46:17,507 - INFO - 8190 - Backtesting with defalt - volume
# 2019-06-23 19:46:20,685 - INFO - 8190 - Backtesting with defalt - sma
# 2019-06-23 19:46:23,846 - INFO - 8190 - Backtesting with defalt - ema
# 2019-06-23 19:46:27,031 - INFO - 8190 - Backtesting with defalt - lagged
# 2019-06-23 19:46:30,257 - INFO - 8190 - Backtesting with defalt - olh_sma
# 2019-06-23 19:46:33,516 - INFO - 8190 - Backtesting with defalt - olh_ema
# 2019-06-23 19:46:36,720 - INFO - 8190 - Backtesting with defalt - olh_slope
# 2019-06-23 19:46:39,905 - INFO - 8190 - Backtesting with depth3 - all
# 2019-06-23 19:46:43,329 - INFO - 8190 - Backtesting with depth3 - close_adj
# 2019-06-23 19:46:46,396 - INFO - 8190 - Backtesting with depth3 - olh
# 2019-06-23 19:46:49,500 - INFO - 8190 - Backtesting with depth3 - olhc
# 2019-06-23 19:46:52,622 - INFO - 8190 - Backtesting with depth3 - olhv
# 2019-06-23 19:46:55,796 - INFO - 8190 - Backtesting with depth3 - olhcv
# 2019-06-23 19:46:58,979 - INFO - 8190 - Backtesting with depth3 - volume
# 2019-06-23 19:47:02,088 - INFO - 8190 - Backtesting with depth3 - sma
# 2019-06-23 19:47:05,236 - INFO - 8190 - Backtesting with depth3 - ema
# 2019-06-23 19:47:08,355 - INFO - 8190 - Backtesting with depth3 - lagged
# 2019-06-23 19:47:11,503 - INFO - 8190 - Backtesting with depth3 - olh_sma
# 2019-06-23 19:47:14,625 - INFO - 8190 - Backtesting with depth3 - olh_ema
# 2019-06-23 19:47:17,746 - INFO - 8190 - Backtesting with depth3 - olh_slope
# 2019-06-23 19:47:20,970 - INFO - 8190 - Backtesting with depth4 - all
# 2019-06-23 19:47:24,502 - INFO - 8190 - Backtesting with depth4 - close_adj
# 2019-06-23 19:47:27,683 - INFO - 8190 - Backtesting with depth4 - olh
# 2019-06-23 19:47:30,895 - INFO - 8190 - Backtesting with depth4 - olhc
# 2019-06-23 19:47:34,056 - INFO - 8190 - Backtesting with depth4 - olhv
# 2019-06-23 19:47:37,306 - INFO - 8190 - Backtesting with depth4 - olhcv
# 2019-06-23 19:47:40,569 - INFO - 8190 - Backtesting with depth4 - volume
# 2019-06-23 19:47:43,745 - INFO - 8190 - Backtesting with depth4 - sma
# 2019-06-23 19:47:46,939 - INFO - 8190 - Backtesting with depth4 - ema
# 2019-06-23 19:47:50,201 - INFO - 8190 - Backtesting with depth4 - lagged
# 2019-06-23 19:47:53,405 - INFO - 8190 - Backtesting with depth4 - olh_sma
# 2019-06-23 19:47:56,627 - INFO - 8190 - Backtesting with depth4 - olh_ema
# 2019-06-23 19:47:59,844 - INFO - 8190 - Backtesting with depth4 - olh_slope
# 2019-06-23 19:48:03,132 - INFO - 8190 - Backtesting with depth5 - all
# 2019-06-23 19:48:06,684 - INFO - 8190 - Backtesting with depth5 - close_adj
# 2019-06-23 19:48:09,793 - INFO - 8190 - Backtesting with depth5 - olh
# 2019-06-23 19:48:12,947 - INFO - 8190 - Backtesting with depth5 - olhc
# 2019-06-23 19:48:16,103 - INFO - 8190 - Backtesting with depth5 - olhv
# 2019-06-23 19:48:19,286 - INFO - 8190 - Backtesting with depth5 - olhcv
# 2019-06-23 19:48:22,536 - INFO - 8190 - Backtesting with depth5 - volume
# 2019-06-23 19:48:25,644 - INFO - 8190 - Backtesting with depth5 - sma
# 2019-06-23 19:48:28,757 - INFO - 8190 - Backtesting with depth5 - ema
# 2019-06-23 19:48:31,983 - INFO - 8190 - Backtesting with depth5 - lagged
# 2019-06-23 19:48:35,114 - INFO - 8190 - Backtesting with depth5 - olh_sma
# 2019-06-23 19:48:38,269 - INFO - 8190 - Backtesting with depth5 - olh_ema
# 2019-06-23 19:48:41,424 - INFO - 8190 - Backtesting with depth5 - olh_slope
# 2019-06-23 19:48:44,513 - INFO - 8190 - Backtesting with depth6 - all
# 2019-06-23 19:48:47,861 - INFO - 8190 - Backtesting with depth6 - close_adj
# 2019-06-23 19:48:50,918 - INFO - 8190 - Backtesting with depth6 - olh
# 2019-06-23 19:48:54,229 - INFO - 8190 - Backtesting with depth6 - olhc
# 2019-06-23 19:48:57,722 - INFO - 8190 - Backtesting with depth6 - olhv
# 2019-06-23 19:49:01,098 - INFO - 8190 - Backtesting with depth6 - olhcv
# 2019-06-23 19:49:04,382 - INFO - 8190 - Backtesting with depth6 - volume
# 2019-06-23 19:49:07,523 - INFO - 8190 - Backtesting with depth6 - sma
# 2019-06-23 19:49:10,751 - INFO - 8190 - Backtesting with depth6 - ema
# 2019-06-23 19:49:13,949 - INFO - 8190 - Backtesting with depth6 - lagged
# 2019-06-23 19:49:17,177 - INFO - 8190 - Backtesting with depth6 - olh_sma
# 2019-06-23 19:49:20,460 - INFO - 8190 - Backtesting with depth6 - olh_ema
# 2019-06-23 19:49:23,691 - INFO - 8190 - Backtesting with depth6 - olh_slope
# 2019-06-23 19:49:26,896 - INFO - 8190 - Backtesting with depth7 - all
# 2019-06-23 19:49:30,536 - INFO - 8190 - Backtesting with depth7 - close_adj
# 2019-06-23 19:49:33,812 - INFO - 8190 - Backtesting with depth7 - olh
# 2019-06-23 19:49:36,949 - INFO - 8190 - Backtesting with depth7 - olhc
# 2019-06-23 19:49:40,103 - INFO - 8190 - Backtesting with depth7 - olhv
# 2019-06-23 19:49:43,384 - INFO - 8190 - Backtesting with depth7 - olhcv
# 2019-06-23 19:49:46,508 - INFO - 8190 - Backtesting with depth7 - volume
# 2019-06-23 19:49:49,434 - INFO - 8190 - Backtesting with depth7 - sma
# 2019-06-23 19:49:52,447 - INFO - 8190 - Backtesting with depth7 - ema
# 2019-06-23 19:49:55,417 - INFO - 8190 - Backtesting with depth7 - lagged
# 2019-06-23 19:49:58,416 - INFO - 8190 - Backtesting with depth7 - olh_sma
# 2019-06-23 19:50:01,505 - INFO - 8190 - Backtesting with depth7 - olh_ema
# 2019-06-23 19:50:04,580 - INFO - 8190 - Backtesting with depth7 - olh_slope
# 2019-06-23 19:50:07,509 - INFO - 8190 - Backtesting with depth8 - all
# 2019-06-23 19:50:10,734 - INFO - 8190 - Backtesting with depth8 - close_adj
# 2019-06-23 19:50:13,634 - INFO - 8190 - Backtesting with depth8 - olh
# 2019-06-23 19:50:16,681 - INFO - 8190 - Backtesting with depth8 - olhc
# 2019-06-23 19:50:19,663 - INFO - 8190 - Backtesting with depth8 - olhv
# 2019-06-23 19:50:22,649 - INFO - 8190 - Backtesting with depth8 - olhcv
# 2019-06-23 19:50:25,639 - INFO - 8190 - Backtesting with depth8 - volume
# 2019-06-23 19:50:28,520 - INFO - 8190 - Backtesting with depth8 - sma
# 2019-06-23 19:50:31,475 - INFO - 8190 - Backtesting with depth8 - ema
# 2019-06-23 19:50:34,399 - INFO - 8190 - Backtesting with depth8 - lagged
# 2019-06-23 19:50:37,337 - INFO - 8190 - Backtesting with depth8 - olh_sma
# 2019-06-23 19:50:40,307 - INFO - 8190 - Backtesting with depth8 - olh_ema
# 2019-06-23 19:50:43,246 - INFO - 8190 - Backtesting with depth8 - olh_slope
# 2019-06-23 19:50:46,161 - INFO - 8190 - Backtesting with depth9 - all
# 2019-06-23 19:50:49,417 - INFO - 8190 - Backtesting with depth9 - close_adj
# 2019-06-23 19:50:52,312 - INFO - 8190 - Backtesting with depth9 - olh
# 2019-06-23 19:50:55,408 - INFO - 8190 - Backtesting with depth9 - olhc
# 2019-06-23 19:50:58,469 - INFO - 8190 - Backtesting with depth9 - olhv
# 2019-06-23 19:51:01,574 - INFO - 8190 - Backtesting with depth9 - olhcv
# 2019-06-23 19:51:04,613 - INFO - 8190 - Backtesting with depth9 - volume
# 2019-06-23 19:51:07,521 - INFO - 8190 - Backtesting with depth9 - sma
# 2019-06-23 19:51:10,436 - INFO - 8190 - Backtesting with depth9 - ema
# 2019-06-23 19:51:13,344 - INFO - 8190 - Backtesting with depth9 - lagged
# 2019-06-23 19:51:16,268 - INFO - 8190 - Backtesting with depth9 - olh_sma
# 2019-06-23 19:51:19,226 - INFO - 8190 - Backtesting with depth9 - olh_ema
# 2019-06-23 19:51:22,168 - INFO - 8190 - Backtesting with depth9 - olh_slope
# 2019-06-23 19:51:25,104 - INFO - 8190 - Backtesting with depth10 - all
# 2019-06-23 19:51:28,368 - INFO - 8190 - Backtesting with depth10 - close_adj
# 2019-06-23 19:51:31,245 - INFO - 8190 - Backtesting with depth10 - olh
# 2019-06-23 19:51:34,134 - INFO - 8190 - Backtesting with depth10 - olhc
# 2019-06-23 19:51:37,063 - INFO - 8190 - Backtesting with depth10 - olhv
# 2019-06-23 19:51:40,042 - INFO - 8190 - Backtesting with depth10 - olhcv
# 2019-06-23 19:51:43,032 - INFO - 8190 - Backtesting with depth10 - volume
# 2019-06-23 19:51:45,952 - INFO - 8190 - Backtesting with depth10 - sma
# 2019-06-23 19:51:48,866 - INFO - 8190 - Backtesting with depth10 - ema
# 2019-06-23 19:51:51,814 - INFO - 8190 - Backtesting with depth10 - lagged
# 2019-06-23 19:51:54,781 - INFO - 8190 - Backtesting with depth10 - olh_sma
# 2019-06-23 19:51:57,777 - INFO - 8190 - Backtesting with depth10 - olh_ema
# 2019-06-23 19:52:00,706 - INFO - 8190 - Backtesting with depth10 - olh_slope
# CPU times: user 6min 5s, sys: 496 ms, total: 6min 5s
# Wall time: 6min 5s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                     alpha      beta      cagr  max_drawdown    return  \
# defalt-olh       0.077774  0.306185  0.083312     -0.381271  3.413020
# depth8-olh       0.077774  0.306185  0.083312     -0.381271  3.413020
# depth10-olh      0.077774  0.306185  0.083312     -0.381271  3.413020
# depth9-olh       0.077774  0.306185  0.083312     -0.381271  3.413020
# depth6-olh       0.077740  0.306567  0.083303     -0.392694  3.412288
# depth7-olh       0.068023  0.331444  0.074616     -0.381271  2.800141
# depth4-olh       0.062309  0.330746  0.068443     -0.391240  2.414959
# depth5-olh       0.058726  0.332907  0.064774     -0.409587  2.203838
# depth6-sma       0.062703  0.270413  0.064582     -0.383837  2.193140
# depth5-sma       0.061891  0.269759  0.063672     -0.383837  2.142864
# depth7-sma       0.061954  0.265933  0.063470     -0.383837  2.131786
# depth9-sma       0.061511  0.265823  0.062991     -0.383837  2.105755
# depth8-sma       0.061511  0.265823  0.062991     -0.383837  2.105755
# defalt-sma       0.061511  0.265823  0.062991     -0.383837  2.105755
# depth10-sma      0.061511  0.265823  0.062991     -0.383837  2.105755
# depth5-olhv      0.056066  0.339902  0.062448     -0.451337  2.076449
# depth3-olhv      0.055268  0.340307  0.061628     -0.375277  2.032680
# depth5-olhcv     0.054164  0.354973  0.061488     -0.410556  2.025291
# depth4-olhv      0.053817  0.348554  0.060670     -0.423898  1.982320
# depth6-olhv      0.051011  0.339655  0.057073     -0.456112  1.800201
# depth7-olhcv     0.048290  0.345121  0.054584     -0.393737  1.680346
# depth4-sma       0.053812  0.262028  0.054574     -0.358125  1.679881
# depth10-olh_ema  0.050610  0.303266  0.054098     -0.296095  1.657511
# depth9-olh_ema   0.050610  0.303266  0.054098     -0.296095  1.657511
# depth7-olh_ema   0.050610  0.303266  0.054098     -0.296095  1.657511
# depth8-olh_ema   0.050610  0.303266  0.054098     -0.296095  1.657511
# defalt-olh_ema   0.050610  0.303266  0.054098     -0.296095  1.657511
# depth9-olhcv     0.047562  0.346221  0.053894     -0.393737  1.647997
# depth10-olhcv    0.047562  0.346221  0.053894     -0.393737  1.647997
# defalt-olhcv     0.047562  0.346221  0.053894     -0.393737  1.647997
#
#                    sharpe       var  volatility
# defalt-olh       0.515020 -0.017202    0.190479
# depth8-olh       0.515020 -0.017202    0.190479
# depth10-olh      0.515020 -0.017202    0.190479
# depth9-olh       0.515020 -0.017202    0.190479
# depth6-olh       0.514973 -0.017202    0.190479
# depth7-olh       0.473153 -0.017256    0.190269
# depth4-olh       0.442846 -0.017375    0.190282
# depth5-olh       0.424751 -0.017333    0.190290
# depth6-sma       0.423540 -0.017425    0.190429
# depth5-sma       0.419047 -0.017515    0.190429
# depth7-sma       0.418064 -0.017515    0.190420
# depth9-sma       0.415700 -0.017515    0.190421
# depth8-sma       0.415700 -0.017515    0.190421
# defalt-sma       0.415700 -0.017515    0.190421
# depth10-sma      0.415700 -0.017515    0.190421
# depth5-olhv      0.413486 -0.017398    0.190165
# depth3-olhv      0.409397 -0.017375    0.190180
# depth5-olhcv     0.408667 -0.017515    0.190201
# depth4-olhv      0.404675 -0.017411    0.190166
# depth6-olhv      0.386797 -0.017411    0.190175
# depth7-olhcv     0.374400 -0.017588    0.190173
# depth4-sma       0.373948 -0.017597    0.190420
# depth10-olh_ema  0.371909 -0.017450    0.190214
# depth9-olh_ema   0.371909 -0.017450    0.190214
# depth7-olh_ema   0.371909 -0.017450    0.190214
# depth8-olh_ema   0.371909 -0.017450    0.190214
# defalt-olh_ema   0.371909 -0.017450    0.190214
# depth9-olhcv     0.370959 -0.017597    0.190172
# depth10-olhcv    0.370959 -0.017597    0.190172
# defalt-olhcv     0.370959 -0.017597    0.190172

# %% [markdown]
# Several depths are having good returns. Nevertheless, the best performance is still the default, with no max-depth. This is probably because the dataset has no too much historical inputs.

# %% [markdown]
# ### Try the amount of parallel trees

# %%
model_params = OrderedDict()

model_params['defalt'] = {'n_estimators': 10, 'random_state': 100, }

#model_params['depth3'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 3}
#model_params['depth4'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 4}
#model_params['depth5'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 5}
#model_params['depth6'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 6}
#model_params['depth7'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 7}
#model_params['depth8'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 8}
#model_params['depth9'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'n_estimators': 10, 'max_depth': 10}

#model_params['min_samp_leaf-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 50}
#model_params['min_samp_leaf-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 100}
#model_params['min_samp_leaf-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 200}
#model_params['min_samp_leaf-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 500}
#model_params['min_samp_leaf-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_leaf': 1000}

#model_params['min_samp_split-10'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 100}
#model_params['min_samp_split-200'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 200}
#model_params['min_samp_split-500'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 500}
#model_params['min_samp_split-1000'] = {'random_state': 100, 'n_estimators': 10, 'min_samples_split': 1000}

# model_params['friedman_mse'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'friedman_mse'}
#model_params['mae'] = {'random_state': 100, 'n_estimators': 10, 'criterion': 'mae'}

model_params['defalt-n20'] = {'n_estimators': 20, 'random_state': 100, }
model_params['defalt-n50'] = {'n_estimators': 50, 'random_state': 100, }
model_params['defalt-n100'] = {'n_estimators': 100, 'random_state': 100, }

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = RandomForestRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-23 20:09:45,630 - INFO - 8190 - Backtesting with defalt - all
# 2019-06-23 20:09:48,858 - INFO - 8190 - Backtesting with defalt - close_adj
# 2019-06-23 20:09:51,719 - INFO - 8190 - Backtesting with defalt - olh
# 2019-06-23 20:09:54,891 - INFO - 8190 - Backtesting with defalt - olhc
# 2019-06-23 20:09:58,073 - INFO - 8190 - Backtesting with defalt - olhv
# 2019-06-23 20:10:01,112 - INFO - 8190 - Backtesting with defalt - olhcv
# 2019-06-23 20:10:04,102 - INFO - 8190 - Backtesting with defalt - volume
# 2019-06-23 20:10:06,985 - INFO - 8190 - Backtesting with defalt - sma
# 2019-06-23 20:10:10,022 - INFO - 8190 - Backtesting with defalt - ema
# 2019-06-23 20:10:12,931 - INFO - 8190 - Backtesting with defalt - lagged
# 2019-06-23 20:10:15,842 - INFO - 8190 - Backtesting with defalt - olh_sma
# 2019-06-23 20:10:18,762 - INFO - 8190 - Backtesting with defalt - olh_ema
# 2019-06-23 20:10:21,669 - INFO - 8190 - Backtesting with defalt - olh_slope
# 2019-06-23 20:10:24,587 - INFO - 8190 - Backtesting with defalt-n20 - all
# 2019-06-23 20:10:28,696 - INFO - 8190 - Backtesting with defalt-n20 - close_adj
# 2019-06-23 20:10:32,264 - INFO - 8190 - Backtesting with defalt-n20 - olh
# 2019-06-23 20:10:35,865 - INFO - 8190 - Backtesting with defalt-n20 - olhc
# 2019-06-23 20:10:39,497 - INFO - 8190 - Backtesting with defalt-n20 - olhv
# 2019-06-23 20:10:43,286 - INFO - 8190 - Backtesting with defalt-n20 - olhcv
# 2019-06-23 20:10:47,216 - INFO - 8190 - Backtesting with defalt-n20 - volume
# 2019-06-23 20:10:51,024 - INFO - 8190 - Backtesting with defalt-n20 - sma
# 2019-06-23 20:10:55,196 - INFO - 8190 - Backtesting with defalt-n20 - ema
# 2019-06-23 20:10:59,116 - INFO - 8190 - Backtesting with defalt-n20 - lagged
# 2019-06-23 20:11:03,989 - INFO - 8190 - Backtesting with defalt-n20 - olh_sma
# 2019-06-23 20:11:08,964 - INFO - 8190 - Backtesting with defalt-n20 - olh_ema
# 2019-06-23 20:11:13,735 - INFO - 8190 - Backtesting with defalt-n20 - olh_slope
# 2019-06-23 20:11:17,871 - INFO - 8190 - Backtesting with defalt-n50 - all
# 2019-06-23 20:11:26,334 - INFO - 8190 - Backtesting with defalt-n50 - close_adj
# 2019-06-23 20:11:35,536 - INFO - 8190 - Backtesting with defalt-n50 - olh
# 2019-06-23 20:11:41,893 - INFO - 8190 - Backtesting with defalt-n50 - olhc
# 2019-06-23 20:11:47,744 - INFO - 8190 - Backtesting with defalt-n50 - olhv
# 2019-06-23 20:11:54,278 - INFO - 8190 - Backtesting with defalt-n50 - olhcv
# 2019-06-23 20:12:01,217 - INFO - 8190 - Backtesting with defalt-n50 - volume
# 2019-06-23 20:12:07,511 - INFO - 8190 - Backtesting with defalt-n50 - sma
# 2019-06-23 20:12:14,084 - INFO - 8190 - Backtesting with defalt-n50 - ema
# 2019-06-23 20:12:21,300 - INFO - 8190 - Backtesting with defalt-n50 - lagged
# 2019-06-23 20:12:29,302 - INFO - 8190 - Backtesting with defalt-n50 - olh_sma
# 2019-06-23 20:12:35,740 - INFO - 8190 - Backtesting with defalt-n50 - olh_ema
# 2019-06-23 20:12:41,969 - INFO - 8190 - Backtesting with defalt-n50 - olh_slope
# 2019-06-23 20:12:48,179 - INFO - 8190 - Backtesting with defalt-n100 - all
# 2019-06-23 20:13:01,464 - INFO - 8190 - Backtesting with defalt-n100 - close_adj
# 2019-06-23 20:13:11,166 - INFO - 8190 - Backtesting with defalt-n100 - olh
# 2019-06-23 20:13:20,875 - INFO - 8190 - Backtesting with defalt-n100 - olhc
# 2019-06-23 20:13:30,542 - INFO - 8190 - Backtesting with defalt-n100 - olhv
# 2019-06-23 20:13:40,336 - INFO - 8190 - Backtesting with defalt-n100 - olhcv
# 2019-06-23 20:13:50,239 - INFO - 8190 - Backtesting with defalt-n100 - volume
# 2019-06-23 20:13:59,754 - INFO - 8190 - Backtesting with defalt-n100 - sma
# 2019-06-23 20:14:09,645 - INFO - 8190 - Backtesting with defalt-n100 - ema
# 2019-06-23 20:14:20,316 - INFO - 8190 - Backtesting with defalt-n100 - lagged
# 2019-06-23 20:14:31,002 - INFO - 8190 - Backtesting with defalt-n100 - olh_sma
# 2019-06-23 20:14:41,606 - INFO - 8190 - Backtesting with defalt-n100 - olh_ema
# 2019-06-23 20:14:51,785 - INFO - 8190 - Backtesting with defalt-n100 - olh_slope
# CPU times: user 5min 16s, sys: 260 ms, total: 5min 16s
# Wall time: 5min 16s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                              alpha      beta      cagr  max_drawdown  \
# defalt-olh            7.777427e-02  0.306185  0.083312     -0.381271
# defalt-n100-olh       7.606789e-02  0.279493  0.079557     -0.393737
# defalt-n20-olh        6.889861e-02  0.284408  0.072189     -0.381271
# defalt-n100-sma       6.835473e-02  0.259655  0.069849     -0.376199
# defalt-n100-olh_sma   6.756302e-02  0.268586  0.069639     -0.357648
# defalt-n50-sma        6.814312e-02  0.259269  0.069597     -0.352038
# defalt-n50-olh        6.521810e-02  0.293832  0.068919     -0.392694
# defalt-n50-olh_sma    6.511565e-02  0.270771  0.067179     -0.379794
# defalt-n100-olhv      5.755828e-02  0.349596  0.064713     -0.387281
# defalt-sma            6.151127e-02  0.265823  0.062991     -0.383837
# defalt-n20-olh_ema    6.021164e-02  0.284302  0.062927     -0.299712
# defalt-n20-olh_sma    6.059803e-02  0.268678  0.062220     -0.322687
# defalt-n100-ema       5.557389e-02  0.309152  0.059755     -0.354490
# defalt-n100-olh_ema   5.443119e-02  0.306621  0.058368     -0.374882
# defalt-n20-olhv       5.067822e-02  0.353553  0.057696     -0.373997
# defalt-olh_ema        5.060987e-02  0.303266  0.054098     -0.296095
# defalt-olhcv          4.756235e-02  0.346221  0.053894     -0.393737
# defalt-olhv           4.763374e-02  0.344222  0.053830     -0.440767
# defalt-n50-olh_ema    4.965883e-02  0.299777  0.052850     -0.314845
# defalt-n20-olhcv      4.554646e-02  0.338919  0.051262     -0.388593
# defalt-n20-sma        5.015353e-02  0.252953  0.050089     -0.413167
# benchmark            -3.681556e-16  1.000000  0.049527     -0.551894
# defalt-ema            4.330849e-02  0.321117  0.047672     -0.322004
# defalt-n20-ema        4.392636e-02  0.307611  0.047378     -0.370856
# defalt-n20-close_adj  4.492103e-02  0.287270  0.047007     -0.413253
# defalt-n50-ema        4.275921e-02  0.306889  0.046106     -0.359186
# defalt-n50-olhc       4.122267e-02  0.300636  0.044070     -0.480332
# defalt-n100-olhc      3.657525e-02  0.297736  0.039029     -0.483346
# defalt-olhc           3.127856e-02  0.316630  0.034839     -0.492169
# defalt-n50-olhv       2.877798e-02  0.345744  0.034250     -0.493197
#
#                         return    sharpe       var  volatility
# defalt-olh            3.413020  0.515020 -0.017202    0.190479
# defalt-n100-olh       3.137696  0.496981 -0.017256    0.190394
# defalt-n20-olh        2.644048  0.460811 -0.017256    0.190488
# defalt-n100-sma       2.499309  0.449411 -0.017425    0.190454
# defalt-n100-olh_sma   2.486533  0.448428 -0.017362    0.190428
# defalt-n50-sma        2.483998  0.448197 -0.017515    0.190440
# defalt-n50-olh        2.443302  0.444780 -0.017411    0.190485
# defalt-n50-olh_sma    2.340785  0.436347 -0.017376    0.190423
# defalt-n100-olhv      2.200439  0.424524 -0.017375    0.190251
# defalt-sma            2.105755  0.415700 -0.017515    0.190421
# defalt-n20-olh_ema    2.102262  0.415740 -0.017450    0.190227
# defalt-n20-olh_sma    2.064247  0.411845 -0.017376    0.190446
# defalt-n100-ema       1.934948  0.400008 -0.017425    0.190239
# defalt-n100-olh_ema   1.864489  0.393142 -0.017588    0.190227
# defalt-n20-olhv       1.830931  0.389859 -0.017375    0.190194
# defalt-olh_ema        1.657511  0.371909 -0.017450    0.190214
# defalt-olhcv          1.647997  0.370959 -0.017597    0.190172
# defalt-olhv           1.645012  0.370654 -0.017450    0.190164
# defalt-n50-olh_ema    1.599776  0.365648 -0.017588    0.190236
# defalt-n20-olhcv      1.527968  0.357808 -0.017722    0.190173
# defalt-n20-sma        1.476157  0.351542 -0.017621    0.190435
# benchmark             1.451705  0.349346 -0.019044    0.190026
# defalt-ema            1.372525  0.339788 -0.017588    0.190195
# defalt-n20-ema        1.360216  0.338276 -0.017621    0.190220
# defalt-n20-close_adj  1.344748  0.336440 -0.017588    0.190202
# defalt-n50-ema        1.307600  0.331880 -0.017597    0.190225
# defalt-n50-olhc       1.225681  0.321704 -0.017597    0.190176
# defalt-n100-olhc      1.034551  0.296246 -0.017597    0.190181
# defalt-olhc           0.887614  0.275023 -0.017722    0.190158
# defalt-n50-olhv       0.867788  0.272007 -0.017588    0.190180

# %% [markdown]
# The default with 10 parallel trees is still the best options.

# %% [markdown]
# For the moment, the default alternative was in the top of the list. Now would worth to combine all the parameters together. Having the experience of previous notebook, the parameter combination will be done on the next notebook, combining with different historical window lenght. Adding more history, adds more data to the dataset and some parameters could produce a better perfomance than the model with 1 month of history.
