# %% [markdown]
# # Tunning GBM training parameters

# %% [markdown]
# It is going to be analyzed the impact of the following GBM constrains:
# - max depth
# - minimum amount of samples per leaf.
# - minimum amount of samples to split a node.
# - Diferent error criteria: MSE, Friedman MSE, and MAE.
# - Different amount of boosted trees.
# - Different losses: Least Squares, Least Absolute Deviation, Huber and Quantile.

# %%
import logging
import imp
from dateutil.relativedelta import relativedelta
from collections import OrderedDict
import sys

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor

# %%
sys.path.append('../..')

from helpers.dataset import read_quote_dataset, preprocess_quotes
from helpers.backtest import train_model_and_backtest_regressor, get_backtest_performance_metrics
from helpers.visualization import plot_return

# %%
# Configir logging module for jypter notebook
imp.reload(logging)
logging_format = '%(asctime)s - %(levelname)s - %(process)s - %(message)s'
logging.basicConfig(level=logging.DEBUG, format=logging_format)

# Disable backtesting logs
logging.getLogger('helpers.backtest').setLevel(level=logging.WARNING)

# %%
PARAM_DATASET = '../../../data/SPY_postprocess_adj.csv.gz'

# %%
df = read_quote_dataset(PARAM_DATASET)

# %%
df.head()
# Out:
#         date        open        high         low     close   close_adj  \
# 0 2000-01-03  148.250000  148.250000  143.875000  145.4375  101.425385
# 1 2000-01-04  143.531204  144.062500  139.640594  139.7500   97.459068
# 2 2000-01-05  139.937500  141.531204  137.250000  140.0000   97.633377
# 3 2000-01-06  139.625000  141.500000  137.750000  137.7500   96.064301
# 4 2000-01-07  140.312500  145.750000  140.062500  145.7500  101.643333
#
#      volume    open_adj     low_adj    high_adj  ...  \
# 0   8164300  103.386770  100.335727  103.386770  ...
# 1   8089800  100.096010   97.382770  100.466526  ...
# 2  12177900   97.589791   95.715579   98.701210  ...
# 3   6227200   97.371891   96.064301   98.679482  ...
# 4   8066500   97.851322   97.676977  101.643333  ...
#
#    ratio_close_adj_000_close_adj_005_norm  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ratio_close_adj_000_close_adj_020_norm  ratio_close_adj_000_ema_005_norm  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                          0.486630
# 4                                     NaN                          0.815422
#
#    ratio_close_adj_000_ema_010_norm  ratio_close_adj_000_ema_020_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ratio_close_adj_000_ema_050_norm  ratio_close_adj_000_sma_005_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                          0.740588
#
#    ratio_close_adj_000_sma_010_norm  ratio_close_adj_000_sma_020_norm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    ratio_close_adj_000_sma_050_norm
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 173 columns]

# %%
vars_to_shift = ['close_adj', 'close_adj_norm', 'close_adj_std']
shift_periods = [1, 5, 10, 20]
vars_for_return = ['close_adj']
return_periods = [1, 5, 10, 20]

# %%
df = preprocess_quotes(
    df, vars_to_shift=vars_to_shift, shift_periods=shift_periods,
    vars_for_return=vars_for_return, return_periods=return_periods,
    shift_date=True
)

# %%
df[['date', 'close_adj', 'date_shift_1', 'close_adj_shift_1', 'close_adj_ret_1', 
    'date_shift_5', 'close_adj_shift_5', 'close_adj_ret_5']].head(10)
# Out:
#         date   close_adj date_shift_1  close_adj_shift_1  close_adj_ret_1  \
# 0 2000-01-03  101.425385   2000-01-04          97.459068        -0.039106
# 1 2000-01-04   97.459068   2000-01-05          97.633377         0.001789
# 2 2000-01-05   97.633377   2000-01-06          96.064301        -0.016071
# 3 2000-01-06   96.064301   2000-01-07         101.643333         0.058076
# 4 2000-01-07  101.643333   2000-01-10         101.992004         0.003430
# 5 2000-01-10  101.992004   2000-01-11         100.771645        -0.011965
# 6 2000-01-11  100.771645   2000-01-12          99.769150        -0.009948
# 7 2000-01-12   99.769150   2000-01-13         101.120308         0.013543
# 8 2000-01-13  101.120308   2000-01-14         102.493233         0.013577
# 9 2000-01-14  102.493233   2000-01-18         101.686958        -0.007867
#
#   date_shift_5  close_adj_shift_5  close_adj_ret_5
# 0   2000-01-10         101.992004         0.005587
# 1   2000-01-11         100.771645         0.033989
# 2   2000-01-12          99.769150         0.021875
# 3   2000-01-13         101.120308         0.052631
# 4   2000-01-14         102.493233         0.008362
# 5   2000-01-18         101.686958        -0.002991
# 6   2000-01-19         102.515060         0.017301
# 7   2000-01-20         100.945953         0.011795
# 8   2000-01-21         100.727989        -0.003880
# 9   2000-01-24          97.873047        -0.045078

# %% [markdown]
# # Processing all the input variables

# %% [markdown]
# On the data processing notebook, it was computed all the historical variables. Lets review them

# %%
x_vars_all = list(filter(lambda varname: 
                ('_adj' in varname or 'volume' in varname)and
                not '_shift_' in varname and
                not '_std' in varname and
                not '_norm' in varname and
                not '_ret_' in varname, 
            df.columns))

# %%
logging.info('There are in total %d dependent variables', len(x_vars_all))
# Out:
# 2019-06-24 15:23:16,966 - INFO - 24085 - There are in total 53 dependent variables

# %%
x_vars_all
# Out:
# ['close_adj',
#  'volume',
#  'open_adj',
#  'low_adj',
#  'high_adj',
#  'slope_close_adj_005',
#  'slope_volume_005',
#  'slope_close_adj_010',
#  'slope_volume_010',
#  'slope_close_adj_020',
#  'slope_volume_020',
#  'slope_close_adj_050',
#  'slope_volume_050',
#  'sma_close_adj_005',
#  'sma_volume_005',
#  'ema_close_adj_005',
#  'ema_volume_005',
#  'sma_close_adj_010',
#  'sma_volume_010',
#  'ema_close_adj_010',
#  'ema_volume_010',
#  'sma_close_adj_020',
#  'sma_volume_020',
#  'ema_close_adj_020',
#  'ema_volume_020',
#  'sma_close_adj_050',
#  'sma_volume_050',
#  'ema_close_adj_050',
#  'ema_volume_050',
#  'lag_close_adj_001',
#  'lag_volume_001',
#  'lag_close_adj_005',
#  'lag_volume_005',
#  'lag_close_adj_010',
#  'lag_volume_010',
#  'lag_close_adj_020',
#  'lag_volume_020',
#  'lag_close_adj_060',
#  'lag_volume_060',
#  'ratio_volume_000_sma_005',
#  'ratio_volume_000_sma_020',
#  'ratio_volume_000_ema_050',
#  'ratio_close_adj_000_close_adj_001',
#  'ratio_close_adj_000_close_adj_005',
#  'ratio_close_adj_000_close_adj_020',
#  'ratio_close_adj_000_ema_005',
#  'ratio_close_adj_000_ema_010',
#  'ratio_close_adj_000_ema_020',
#  'ratio_close_adj_000_ema_050',
#  'ratio_close_adj_000_sma_005',
#  'ratio_close_adj_000_sma_010',
#  'ratio_close_adj_000_sma_020',
#  'ratio_close_adj_000_sma_050']

# %% [markdown]
# Divive them by categories

# %%
x_vars_slope = list(filter(lambda var: var.startswith('slope_'), x_vars_all))
x_vars_sma = list(filter(lambda var: var.startswith('sma_'), x_vars_all))
x_vars_ema = list(filter(lambda var: var.startswith('ema_'), x_vars_all))
x_vars_lagged = list(filter(lambda var: var.startswith('lag_'), x_vars_all))
x_vars_ratio_close_adj = list(filter(lambda var: var.startswith('ratio_close_adj_'), x_vars_all))
x_vars_ratio_volume = list(filter(lambda var: var.startswith('ratio_volume_'), x_vars_all))

# %% [markdown]
# # Run backtests with different set of GBM parameters

# %% [markdown]
# Define the inputs

# %%
x_var_set = OrderedDict()
x_var_set['all'] = x_vars_all
x_var_set['close_adj'] = ['close_adj']
x_var_set['olh'] = ['open_adj', 'low_adj', 'high_adj']
x_var_set['olhc'] = ['open_adj', 'low_adj', 'high_adj', 'close_adj']
x_var_set['olhv'] = ['open_adj', 'low_adj', 'high_adj', 'volume']
x_var_set['olhcv'] = ['open_adj', 'low_adj', 'high_adj', 'close_adj', 'volume']
x_var_set['volume'] = ['volume']
#x_var_set['slope'] = x_vars_slope
x_var_set['sma'] = x_vars_sma
x_var_set['ema'] = x_vars_ema
x_var_set['lagged'] = x_vars_lagged
#x_var_set['ratio_closed_adj'] = x_vars_ratio_close_adj
#x_var_set['ratio_vol'] = x_vars_ratio_volume
x_var_set['olh_sma'] = ['open_adj', 'low_adj', 'high_adj'] + x_vars_sma
x_var_set['olh_ema'] = ['open_adj', 'low_adj', 'high_adj'] + x_vars_ema
x_var_set['olh_slope'] = ['open_adj', 'low_adj', 'high_adj'] + x_vars_slope

# %% [markdown]
# ### Try min sample per leaf

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

#model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
#model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
#model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
#model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
#model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
#model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
#model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

#model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

#model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
#model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

#model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
#model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
#model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}


#model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
#model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
#model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}


#model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
#model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
#model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        # logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# CPU times: user 8min 40s, sys: 547 ms, total: 8min 41s
# Wall time: 8min 46s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                                    alpha      beta      cagr  max_drawdown  \
# defalt-olh_sma              7.758844e-02  0.288603  0.081842     -0.371374
# defalt-olh                  7.254280e-02  0.279200  0.075729     -0.348481
# defalt-olh_ema              6.950265e-02  0.316354  0.075134     -0.293878
# defalt-olhv                 6.713122e-02  0.302398  0.071588     -0.323638
# defalt-ema                  6.201691e-02  0.314121  0.066958     -0.290552
# defalt-olhc                 5.457540e-02  0.291177  0.057425     -0.339725
# benchmark                  -3.681556e-16  1.000000  0.049527     -0.551894
# defalt-sma                  4.335895e-02  0.271590  0.044273     -0.328392
# defalt-lagged               3.411949e-02  0.325692  0.038403     -0.405632
# defalt-olhcv                3.001081e-02  0.311660  0.033185     -0.444309
# min_samp_leaf-20-olh_ema    2.204835e-02  0.310637  0.024917     -0.415264
# min_samp_leaf-10-olh_ema    2.204835e-02  0.310637  0.024917     -0.415264
# min_samp_leaf-10-olh_sma    2.063414e-02  0.312267  0.023580     -0.453207
# min_samp_leaf-20-olh_sma    2.063414e-02  0.312267  0.023580     -0.453207
# min_samp_leaf-20-olhcv      1.335819e-02  0.369722  0.020045     -0.493459
# min_samp_leaf-10-olhcv      1.335819e-02  0.369722  0.020045     -0.493459
# min_samp_leaf-20-sma        1.510479e-02  0.328556  0.019037     -0.444267
# min_samp_leaf-10-sma        1.510479e-02  0.328556  0.019037     -0.444267
# defalt-close_adj            1.806259e-02  0.270328  0.018115     -0.454769
# min_samp_leaf-20-olhv       8.959468e-03  0.355698  0.014622     -0.449823
# min_samp_leaf-10-olhv       8.959468e-03  0.355698  0.014622     -0.449823
# defalt-volume               7.590113e-03  0.364082  0.013793     -0.393190
# min_samp_leaf-10-olh_slope  6.536298e-03  0.373494  0.013360     -0.411964
# min_samp_leaf-20-olh_slope  6.536298e-03  0.373494  0.013360     -0.411964
# min_samp_leaf-50-volume     5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_leaf-50-sma        5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_leaf-50-all        5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_leaf-50-olhcv      5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_leaf-50-olhv       5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_leaf-50-lagged     5.317983e-03  0.376128  0.012303     -0.442381
#
#                               return    sharpe       var  volatility
# defalt-olh_sma              3.303236  0.507701 -0.017450    0.190560
# defalt-olh                  2.873806  0.478037 -0.017411    0.190524
# defalt-olh_ema              2.834283  0.475849 -0.017332    0.190195
# defalt-olhv                 2.606296  0.458247 -0.017282    0.190303
# defalt-ema                  2.327930  0.435661 -0.017362    0.190216
# defalt-olhc                 1.817529  0.388185 -0.017450    0.190387
# benchmark                   1.451705  0.349346 -0.019044    0.190026
# defalt-sma                  1.233732  0.322438 -0.017859    0.190388
# defalt-lagged               1.011927  0.293021 -0.017621    0.190227
# defalt-olhcv                0.832423  0.266577 -0.017597    0.190191
# min_samp_leaf-20-olh_ema    0.578683  0.224272 -0.017621    0.190260
# min_samp_leaf-10-olh_ema    0.578683  0.224272 -0.017621    0.190260
# min_samp_leaf-10-olh_sma    0.540907  0.217415 -0.017588    0.190253
# min_samp_leaf-20-olh_sma    0.540907  0.217415 -0.017588    0.190253
# min_samp_leaf-20-olhcv      0.445123  0.199257 -0.017657    0.190218
# min_samp_leaf-10-olhcv      0.445123  0.199257 -0.017657    0.190218
# min_samp_leaf-20-sma        0.418846  0.194024 -0.017795    0.190265
# min_samp_leaf-10-sma        0.418846  0.194024 -0.017795    0.190265
# defalt-close_adj            0.395228  0.189297 -0.017768    0.190222
# min_samp_leaf-20-olhv       0.309047  0.171218 -0.017768    0.190239
# min_samp_leaf-10-olhv       0.309047  0.171218 -0.017768    0.190239
# defalt-volume               0.289336  0.166876 -0.017795    0.190319
# min_samp_leaf-10-olh_slope  0.279162  0.164648 -0.017722    0.190289
# min_samp_leaf-20-olh_slope  0.279162  0.164648 -0.017722    0.190289
# min_samp_leaf-50-volume     0.254631  0.159160 -0.017597    0.190295
# min_samp_leaf-50-sma        0.254631  0.159160 -0.017597    0.190295
# min_samp_leaf-50-all        0.254631  0.159160 -0.017597    0.190295
# min_samp_leaf-50-olhcv      0.254631  0.159160 -0.017597    0.190295
# min_samp_leaf-50-olhv       0.254631  0.159160 -0.017597    0.190295
# min_samp_leaf-50-lagged     0.254631  0.159160 -0.017597    0.190295

# %% [markdown]
# According the tests, constraining the amount of samples per leaf doesn't help. Default params with OLH and SMA quotes is the best model.

# %% [markdown]
# ### Try min sample split

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

#model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
#model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
#model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
#model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
#model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
#model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
#model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

#model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

#model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
#model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

#model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
#model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
#model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}


#model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
#model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
#model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}


#model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
#model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
#model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-24 15:40:59,732 - INFO - 24085 - Backtesting with defalt - all
# 2019-06-24 15:41:16,713 - INFO - 24085 - Backtesting with defalt - close_adj
# 2019-06-24 15:41:28,555 - INFO - 24085 - Backtesting with defalt - olh
# 2019-06-24 15:41:40,612 - INFO - 24085 - Backtesting with defalt - olhc
# 2019-06-24 15:41:52,735 - INFO - 24085 - Backtesting with defalt - olhv
# 2019-06-24 15:42:05,250 - INFO - 24085 - Backtesting with defalt - olhcv
# 2019-06-24 15:42:15,989 - INFO - 24085 - Backtesting with defalt - volume
# 2019-06-24 15:42:27,326 - INFO - 24085 - Backtesting with defalt - sma
# 2019-06-24 15:42:39,832 - INFO - 24085 - Backtesting with defalt - ema
# 2019-06-24 15:42:49,031 - INFO - 24085 - Backtesting with defalt - lagged
# 2019-06-24 15:42:58,611 - INFO - 24085 - Backtesting with defalt - olh_sma
# 2019-06-24 15:43:07,947 - INFO - 24085 - Backtesting with defalt - olh_ema
# 2019-06-24 15:43:17,250 - INFO - 24085 - Backtesting with defalt - olh_slope
# 2019-06-24 15:43:28,151 - INFO - 24085 - Backtesting with min_samp_split-10 - all
# 2019-06-24 15:43:43,913 - INFO - 24085 - Backtesting with min_samp_split-10 - close_adj
# 2019-06-24 15:43:53,931 - INFO - 24085 - Backtesting with min_samp_split-10 - olh
# 2019-06-24 15:44:04,137 - INFO - 24085 - Backtesting with min_samp_split-10 - olhc
# 2019-06-24 15:44:14,434 - INFO - 24085 - Backtesting with min_samp_split-10 - olhv
# 2019-06-24 15:44:24,966 - INFO - 24085 - Backtesting with min_samp_split-10 - olhcv
# 2019-06-24 15:44:36,303 - INFO - 24085 - Backtesting with min_samp_split-10 - volume
# 2019-06-24 15:44:48,274 - INFO - 24085 - Backtesting with min_samp_split-10 - sma
# 2019-06-24 15:45:00,683 - INFO - 24085 - Backtesting with min_samp_split-10 - ema
# 2019-06-24 15:45:12,997 - INFO - 24085 - Backtesting with min_samp_split-10 - lagged
# 2019-06-24 15:45:25,497 - INFO - 24085 - Backtesting with min_samp_split-10 - olh_sma
# 2019-06-24 15:45:38,162 - INFO - 24085 - Backtesting with min_samp_split-10 - olh_ema
# 2019-06-24 15:45:50,779 - INFO - 24085 - Backtesting with min_samp_split-10 - olh_slope
# 2019-06-24 15:46:03,374 - INFO - 24085 - Backtesting with min_samp_split-50 - all
# 2019-06-24 15:46:14,370 - INFO - 24085 - Backtesting with min_samp_split-50 - close_adj
# 2019-06-24 15:46:24,803 - INFO - 24085 - Backtesting with min_samp_split-50 - olh
# 2019-06-24 15:46:34,927 - INFO - 24085 - Backtesting with min_samp_split-50 - olhc
# 2019-06-24 15:46:43,465 - INFO - 24085 - Backtesting with min_samp_split-50 - olhv
# 2019-06-24 15:46:54,903 - INFO - 24085 - Backtesting with min_samp_split-50 - olhcv
# 2019-06-24 15:47:04,071 - INFO - 24085 - Backtesting with min_samp_split-50 - volume
# 2019-06-24 15:47:12,276 - INFO - 24085 - Backtesting with min_samp_split-50 - sma
# 2019-06-24 15:47:21,390 - INFO - 24085 - Backtesting with min_samp_split-50 - ema
# 2019-06-24 15:47:30,164 - INFO - 24085 - Backtesting with min_samp_split-50 - lagged
# 2019-06-24 15:47:41,712 - INFO - 24085 - Backtesting with min_samp_split-50 - olh_sma
# 2019-06-24 15:47:53,238 - INFO - 24085 - Backtesting with min_samp_split-50 - olh_ema
# 2019-06-24 15:48:04,804 - INFO - 24085 - Backtesting with min_samp_split-50 - olh_slope
# 2019-06-24 15:48:13,525 - INFO - 24085 - Backtesting with min_samp_split-100 - all
# 2019-06-24 15:48:21,947 - INFO - 24085 - Backtesting with min_samp_split-100 - close_adj
# 2019-06-24 15:48:30,075 - INFO - 24085 - Backtesting with min_samp_split-100 - olh
# 2019-06-24 15:48:38,073 - INFO - 24085 - Backtesting with min_samp_split-100 - olhc
# 2019-06-24 15:48:46,190 - INFO - 24085 - Backtesting with min_samp_split-100 - olhv
# 2019-06-24 15:48:54,369 - INFO - 24085 - Backtesting with min_samp_split-100 - olhcv
# 2019-06-24 15:49:04,757 - INFO - 24085 - Backtesting with min_samp_split-100 - volume
# 2019-06-24 15:49:16,340 - INFO - 24085 - Backtesting with min_samp_split-100 - sma
# 2019-06-24 15:49:27,747 - INFO - 24085 - Backtesting with min_samp_split-100 - ema
# 2019-06-24 15:49:38,954 - INFO - 24085 - Backtesting with min_samp_split-100 - lagged
# 2019-06-24 15:49:50,117 - INFO - 24085 - Backtesting with min_samp_split-100 - olh_sma
# 2019-06-24 15:50:02,406 - INFO - 24085 - Backtesting with min_samp_split-100 - olh_ema
# 2019-06-24 15:50:14,868 - INFO - 24085 - Backtesting with min_samp_split-100 - olh_slope
# CPU times: user 9min 25s, sys: 584 ms, total: 9min 25s
# Wall time: 9min 27s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                                      alpha      beta      cagr  max_drawdown  \
# min_samp_split-10-olh         8.355586e-02  0.296302  0.088879     -0.343385
# min_samp_split-10-olh_ema     7.619025e-02  0.316687  0.082373     -0.290552
# defalt-olh_sma                7.758844e-02  0.288603  0.081842     -0.371374
# min_samp_split-10-olh_sma     7.549319e-02  0.255526  0.077221     -0.315306
# defalt-olh                    7.254280e-02  0.279200  0.075729     -0.348481
# defalt-olh_ema                6.950265e-02  0.316354  0.075134     -0.293878
# defalt-olhv                   6.713122e-02  0.302398  0.071588     -0.323638
# min_samp_split-10-olhv        6.193384e-02  0.340978  0.068771     -0.442934
# min_samp_split-10-olhc        6.508305e-02  0.280084  0.067807     -0.340293
# defalt-ema                    6.201691e-02  0.314121  0.066958     -0.290552
# defalt-olhc                   5.457540e-02  0.291177  0.057425     -0.339725
# min_samp_split-10-ema         4.997090e-02  0.341369  0.056095     -0.339178
# min_samp_split-10-sma         4.901912e-02  0.262469  0.049566     -0.344644
# benchmark                    -3.681556e-16  1.000000  0.049527     -0.551894
# defalt-sma                    4.335895e-02  0.271590  0.044273     -0.328392
# defalt-lagged                 3.411949e-02  0.325692  0.038403     -0.405632
# defalt-olhcv                  3.001081e-02  0.311660  0.033185     -0.444309
# min_samp_split-10-volume      1.791648e-02  0.372277  0.024875     -0.391148
# min_samp_split-10-lagged      1.871953e-02  0.321365  0.022242     -0.407022
# min_samp_split-10-close_adj   2.191208e-02  0.258596  0.021248     -0.466408
# min_samp_split-10-olhcv       1.703529e-02  0.329025  0.021045     -0.501661
# defalt-close_adj              1.806259e-02  0.270328  0.018115     -0.454769
# min_samp_split-10-all         9.774324e-03  0.337323  0.014218     -0.399037
# defalt-volume                 7.590113e-03  0.364082  0.013793     -0.393190
# min_samp_split-100-volume     5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_split-100-close_adj  5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_split-100-olh        5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_split-100-olhc       5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_split-100-olhv       5.317983e-03  0.376128  0.012303     -0.442381
# min_samp_split-100-olhcv      5.317983e-03  0.376128  0.012303     -0.442381
#
#                                 return    sharpe       var  volatility
# min_samp_split-10-olh         3.853263  0.541974 -0.017168    0.190463
# min_samp_split-10-olh_ema     3.342542  0.511165 -0.017376    0.190180
# defalt-olh_sma                3.303236  0.507701 -0.017450    0.190560
# min_samp_split-10-olh_sma     2.974702  0.485571 -0.017229    0.190407
# defalt-olh                    2.873806  0.478037 -0.017411    0.190524
# defalt-olh_ema                2.834283  0.475849 -0.017332    0.190195
# defalt-olhv                   2.606296  0.458247 -0.017282    0.190303
# min_samp_split-10-olhv        2.434451  0.444547 -0.017132    0.190238
# min_samp_split-10-olhc        2.377454  0.439525 -0.017588    0.190379
# defalt-ema                    2.327930  0.435661 -0.017362    0.190216
# defalt-olhc                   1.817529  0.388185 -0.017450    0.190387
# min_samp_split-10-ema         1.752519  0.381947 -0.017376    0.190164
# min_samp_split-10-sma         1.453374  0.349029 -0.017722    0.190366
# benchmark                     1.451705  0.349346 -0.019044    0.190026
# defalt-sma                    1.233732  0.322438 -0.017859    0.190388
# defalt-lagged                 1.011927  0.293021 -0.017621    0.190227
# defalt-olhcv                  0.832423  0.266577 -0.017597    0.190191
# min_samp_split-10-volume      0.577471  0.224035 -0.017597    0.190284
# min_samp_split-10-lagged      0.503972  0.210575 -0.017908    0.190209
# min_samp_split-10-close_adj   0.477062  0.205471 -0.017722    0.190192
# min_samp_split-10-olhcv       0.471634  0.204462 -0.017768    0.190146
# defalt-close_adj              0.395228  0.189297 -0.017768    0.190222
# min_samp_split-10-all         0.299416  0.169187 -0.017823    0.190130
# defalt-volume                 0.289336  0.166876 -0.017795    0.190319
# min_samp_split-100-volume     0.254631  0.159160 -0.017597    0.190295
# min_samp_split-100-close_adj  0.254631  0.159160 -0.017597    0.190295
# min_samp_split-100-olh        0.254631  0.159160 -0.017597    0.190295
# min_samp_split-100-olhc       0.254631  0.159160 -0.017597    0.190295
# min_samp_split-100-olhv       0.254631  0.159160 -0.017597    0.190295
# min_samp_split-100-olhcv      0.254631  0.159160 -0.017597    0.190295

# %% [markdown]
# `min_sample_split` could help. While the default strategy  has almost the same CAGR than with `min_sample_split` equal 10, the max drawdown was reduced from 37% to 29%.

# %% [markdown]
# ### Try different error criterions

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

#model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
#model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
#model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
#model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
#model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
#model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
#model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

#model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

#model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

#model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
#model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
#model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}


#model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
#model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
#model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}


#model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
#model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
#model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# mse-olhv        0.458247 -0.017282    0.190303
# mae-olh         0.448117 -0.017411    0.190387
# mae-olhc        0.446528 -0.017333    0.190421
# mae-olh_sma     0.441069 -0.017376    0.190433
# defalt-ema      0.435661 -0.017362    0.190216
# mse-ema         0.435661 -0.017362    0.190216
# defalt-olhc     0.388185 -0.017450    0.190387
# mse-olhc        0.388185 -0.017450    0.190387
# mae-sma         0.361156 -0.017597    0.190410
# mae-olhcv       0.358634 -0.017515    0.190192
# benchmark       0.349346 -0.019044    0.190026
# mse-sma         0.322438 -0.017859    0.190388
# defalt-sma      0.322438 -0.017859    0.190388
# mae-lagged      0.320959 -0.017621    0.190249
# mse-lagged      0.293021 -0.017621    0.190227
# defalt-lagged   0.293021 -0.017621    0.190227
# defalt-olhcv    0.266577 -0.017597    0.190191
# mse-olhcv       0.266577 -0.017597    0.190191
# mae-close_adj   0.194710 -0.017845    0.190191
# mse-close_adj   0.189297 -0.017768    0.190222

# %% [markdown]
# The three criterion are in the top-3: MSE, Friedman MSE and MAE. The three criterion have to be tested with more depth.

# %% [markdown]
# ### Try the most important parameter: the depth

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

#model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

#model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

#model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
#model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

#model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
#model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
#model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}


#model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
#model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
#model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}


#model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
#model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
#model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-24 15:59:46,174 - INFO - 24085 - Backtesting with defalt - all
# 2019-06-24 16:00:03,308 - INFO - 24085 - Backtesting with defalt - close_adj
# 2019-06-24 16:00:15,713 - INFO - 24085 - Backtesting with defalt - olh
# 2019-06-24 16:00:28,122 - INFO - 24085 - Backtesting with defalt - olhc
# 2019-06-24 16:00:40,523 - INFO - 24085 - Backtesting with defalt - olhv
# 2019-06-24 16:00:53,414 - INFO - 24085 - Backtesting with defalt - olhcv
# 2019-06-24 16:01:06,208 - INFO - 24085 - Backtesting with defalt - volume
# 2019-06-24 16:01:18,167 - INFO - 24085 - Backtesting with defalt - sma
# 2019-06-24 16:01:31,393 - INFO - 24085 - Backtesting with defalt - ema
# 2019-06-24 16:01:45,051 - INFO - 24085 - Backtesting with defalt - lagged
# 2019-06-24 16:01:58,950 - INFO - 24085 - Backtesting with defalt - olh_sma
# 2019-06-24 16:02:12,576 - INFO - 24085 - Backtesting with defalt - olh_ema
# 2019-06-24 16:02:26,340 - INFO - 24085 - Backtesting with defalt - olh_slope
# 2019-06-24 16:02:39,948 - INFO - 24085 - Backtesting with depth3 - all
# 2019-06-24 16:02:57,547 - INFO - 24085 - Backtesting with depth3 - close_adj
# 2019-06-24 16:03:09,881 - INFO - 24085 - Backtesting with depth3 - olh
# 2019-06-24 16:03:22,697 - INFO - 24085 - Backtesting with depth3 - olhc
# 2019-06-24 16:03:35,245 - INFO - 24085 - Backtesting with depth3 - olhv
# 2019-06-24 16:03:48,336 - INFO - 24085 - Backtesting with depth3 - olhcv
# 2019-06-24 16:04:00,792 - INFO - 24085 - Backtesting with depth3 - volume
# 2019-06-24 16:04:13,132 - INFO - 24085 - Backtesting with depth3 - sma
# 2019-06-24 16:04:26,140 - INFO - 24085 - Backtesting with depth3 - ema
# 2019-06-24 16:04:38,943 - INFO - 24085 - Backtesting with depth3 - lagged
# 2019-06-24 16:04:52,341 - INFO - 24085 - Backtesting with depth3 - olh_sma
# 2019-06-24 16:21:32,963 - INFO - 24085 - Backtesting with depth9 - sma
# 2019-06-24 16:21:46,721 - INFO - 24085 - Backtesting with depth9 - ema
# 2019-06-24 16:22:00,398 - INFO - 24085 - Backtesting with depth9 - lagged
# 2019-06-24 16:22:14,324 - INFO - 24085 - Backtesting with depth9 - olh_sma
# 2019-06-24 16:22:28,984 - INFO - 24085 - Backtesting with depth9 - olh_ema
# 2019-06-24 16:22:43,366 - INFO - 24085 - Backtesting with depth9 - olh_slope
# 2019-06-24 16:22:57,499 - INFO - 24085 - Backtesting with depth10 - all
# 2019-06-24 16:23:16,856 - INFO - 24085 - Backtesting with depth10 - close_adj
# 2019-06-24 16:23:29,477 - INFO - 24085 - Backtesting with depth10 - olh
# 2019-06-24 16:23:42,289 - INFO - 24085 - Backtesting with depth10 - olhc
# 2019-06-24 16:23:55,210 - INFO - 24085 - Backtesting with depth10 - olhv
# 2019-06-24 16:24:08,478 - INFO - 24085 - Backtesting with depth10 - olhcv
# 2019-06-24 16:24:21,697 - INFO - 24085 - Backtesting with depth10 - volume
# 2019-06-24 16:24:34,241 - INFO - 24085 - Backtesting with depth10 - sma
# 2019-06-24 16:24:47,746 - INFO - 24085 - Backtesting with depth10 - ema
# 2019-06-24 16:25:00,954 - INFO - 24085 - Backtesting with depth10 - lagged
# 2019-06-24 16:25:14,492 - INFO - 24085 - Backtesting with depth10 - olh_sma
# 2019-06-24 16:25:27,281 - INFO - 24085 - Backtesting with depth10 - olh_ema
# 2019-06-24 16:25:41,159 - INFO - 24085 - Backtesting with depth10 - olh_slope
# CPU times: user 26min 6s, sys: 1.22 s, total: 26min 7s
# Wall time: 26min 8s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                     alpha      beta      cagr  max_drawdown    return  \
# depth4-olh_ema   0.106635  0.313632  0.115600     -0.290552  6.609563
# depth6-olh       0.107879  0.272252  0.113898     -0.345964  6.396992
# depth7-olh       0.105171  0.271602  0.110838     -0.374404  6.028975
# depth10-olh      0.102063  0.267706  0.107105     -0.405297  5.603511
# depth8-olh       0.101043  0.275589  0.106556     -0.377599  5.543035
# depth9-olh       0.100908  0.267986  0.105849     -0.405297  5.465818
# depth6-olh_ema   0.088652  0.339619  0.097612     -0.271001  4.628503
# depth5-olh_ema   0.087599  0.344127  0.096786     -0.305589  4.550448
# depth5-olh       0.091194  0.276604  0.095789     -0.358915  4.457511
# depth4-olhv      0.088746  0.300363  0.094852     -0.330352  4.371593
# depth7-olh_ema   0.085110  0.340127  0.093770     -0.271001  4.273970
# depth10-olh_ema  0.082115  0.340179  0.090502     -0.271001  3.989195
# depth9-olh_ema   0.082115  0.340179  0.090502     -0.271001  3.989195
# depth8-olh_ema   0.080944  0.340725  0.089265     -0.271001  3.885285
# depth8-olhv      0.083888  0.279652  0.088033     -0.292089  3.783789
# depth7-olh_sma   0.080446  0.313848  0.086763     -0.290552  3.681181
# depth9-olhv      0.082059  0.280839  0.086131     -0.292089  3.630970
# depth10-olhv     0.082059  0.280839  0.086131     -0.292089  3.630970
# depth5-olh_sma   0.080157  0.303664  0.085713     -0.291534  3.598053
# depth7-olhv      0.079897  0.281543  0.083836     -0.333730  3.452780
# depth4-olh_sma   0.077355  0.292510  0.081874     -0.303223  3.305559
# defalt-olh_sma   0.077588  0.288603  0.081842     -0.371374  3.303236
# depth3-olh_sma   0.077588  0.288603  0.081842     -0.371374  3.303236
# depth6-olh_sma   0.075722  0.315044  0.081727     -0.291534  3.294723
# depth4-olh       0.076856  0.283134  0.080660     -0.339725  3.216828
# depth8-olh_sma   0.074760  0.314597  0.080655     -0.290552  3.216441
# depth10-olh_sma  0.074454  0.314207  0.080296     -0.290552  3.190546
# depth9-olh_sma   0.074454  0.314207  0.080296     -0.290552  3.190546
# depth4-olhc      0.070823  0.318812  0.076710     -0.339725  2.939900
# defalt-olh       0.072543  0.279200  0.075729     -0.348481  2.873806
#
#                    sharpe       var  volatility
# depth4-olh_ema   0.670151 -0.017020    0.190189
# depth6-olh       0.660939 -0.017109    0.190565
# depth7-olh       0.646482 -0.017127    0.190572
# depth10-olh      0.628829 -0.017145    0.190568
# depth8-olh       0.626247 -0.017168    0.190561
# depth9-olh       0.622861 -0.017145    0.190570
# depth6-olh_ema   0.584695 -0.017256    0.190180
# depth5-olh_ema   0.580740 -0.017376    0.190178
# depth5-olh       0.574998 -0.017256    0.190533
# depth4-olhv      0.571151 -0.017202    0.190292
# depth7-olh_ema   0.566254 -0.017362    0.190179
# depth10-olh_ema  0.550504 -0.017362    0.190185
# depth9-olh_ema   0.550504 -0.017362    0.190185
# depth8-olh_ema   0.544533 -0.017362    0.190187
# depth8-olhv      0.537735 -0.017240    0.190526
# depth7-olh_sma   0.531692 -0.017450    0.190489
# depth9-olhv      0.528542 -0.017282    0.190529
# depth10-olhv     0.528542 -0.017282    0.190529
# depth5-olh_sma   0.526619 -0.017450    0.190490
# depth7-olhv      0.517437 -0.017333    0.190530
# depth4-olh_sma   0.507976 -0.017515    0.190507
# defalt-olh_sma   0.507701 -0.017450    0.190560
# depth3-olh_sma   0.507701 -0.017450    0.190560
# depth6-olh_sma   0.507303 -0.017588    0.190490
# depth4-olh       0.502033 -0.017411    0.190529
# depth8-olh_sma   0.502082 -0.017515    0.190496
# depth10-olh_sma  0.500338 -0.017515    0.190497
# depth9-olh_sma   0.500338 -0.017515    0.190497
# depth4-olhc      0.482907 -0.017375    0.190486
# defalt-olh       0.478037 -0.017411    0.190524

# %% [markdown]
# Several depths are having good returns. Now the default is on position #30. While the default depth has a CAGR near 7.5%, changing the depth a CAGR of 11% was reached.

# %% [markdown]
# ### Try different kind of losses

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

#model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
#model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
#model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
#model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
#model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
#model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
#model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

#model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

#model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

#model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
#model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}


#model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
#model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
#model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}


#model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
#model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
#model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-24 18:12:18,490 - INFO - 24085 - Backtesting with defalt - all
# 2019-06-24 18:12:30,315 - INFO - 24085 - Backtesting with defalt - close_adj
# 2019-06-24 18:12:40,808 - INFO - 24085 - Backtesting with defalt - olh
# 2019-06-24 18:12:48,609 - INFO - 24085 - Backtesting with defalt - olhc
# 2019-06-24 18:12:56,961 - INFO - 24085 - Backtesting with defalt - olhv
# 2019-06-24 18:13:05,254 - INFO - 24085 - Backtesting with defalt - olhcv
# 2019-06-24 18:34:01,836 - INFO - 24085 - Backtesting with quant - volume
# 2019-06-24 18:34:29,884 - INFO - 24085 - Backtesting with quant - sma
# 2019-06-24 18:34:56,810 - INFO - 24085 - Backtesting with quant - ema
# 2019-06-24 18:35:25,118 - INFO - 24085 - Backtesting with quant - lagged
# 2019-06-24 18:35:49,205 - INFO - 24085 - Backtesting with quant - olh_sma
# 2019-06-24 18:36:14,784 - INFO - 24085 - Backtesting with quant - olh_ema
# 2019-06-24 18:36:39,170 - INFO - 24085 - Backtesting with quant - olh_slope
# CPU times: user 24min 28s, sys: 919 ms, total: 24min 29s
# Wall time: 24min 44s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                         alpha      beta      cagr  max_drawdown    return  \
# huber-olh_ema    7.721875e-02  0.347044  0.085670     -0.340293  3.594639
# lad-ema          7.646537e-02  0.320055  0.082911     -0.316074  3.382762
# defalt-olh_sma   7.758844e-02  0.288603  0.081842     -0.371374  3.303236
# huber-olh_sma    7.202875e-02  0.290556  0.075992     -0.383324  2.891427
# defalt-olh       7.254280e-02  0.279200  0.075729     -0.348481  2.873806
# defalt-olh_ema   6.950265e-02  0.316354  0.075134     -0.293878  2.834283
# quant-olhv       4.961196e-02  0.577815  0.072417     -0.392214  2.658454
# defalt-olhv      6.713122e-02  0.302398  0.071588     -0.323638  2.606296
# lad-olh_ema      6.544231e-02  0.305390  0.069996     -0.355756  2.508227
# quant-olhcv      4.524817e-02  0.592408  0.068785     -0.468951  2.435259
# defalt-ema       6.201691e-02  0.314121  0.066958     -0.290552  2.327930
# huber-olh        6.171745e-02  0.270373  0.063524     -0.366947  2.134761
# huber-ema        5.755863e-02  0.323634  0.062880     -0.289942  2.099742
# huber-olhc       5.749406e-02  0.292433  0.060604     -0.339725  1.978895
# lad-olhcv        5.605508e-02  0.312878  0.060533     -0.452423  1.975176
# lad-olh          5.404351e-02  0.315776  0.058596     -0.347406  1.876001
# defalt-olhc      5.457540e-02  0.291177  0.057425     -0.339725  1.817529
# lad-olhc         5.439273e-02  0.268170  0.055620     -0.493631  1.729627
# quant-close_adj  2.989174e-02  0.634361  0.055433     -0.412659  1.720651
# lad-olhv         4.956149e-02  0.335449  0.055240     -0.359820  1.711470
# quant-ema        3.057738e-02  0.574753  0.051984     -0.357975  1.560382
# huber-olhv       4.809055e-02  0.296772  0.050994     -0.486737  1.516046
# benchmark       -3.681556e-16  1.000000  0.049527     -0.551894  1.451705
# huber-sma        4.840441e-02  0.270028  0.049445     -0.344293  1.448122
# quant-olh        2.599501e-02  0.597971  0.048793     -0.446891  1.420084
# quant-olh_ema    2.479981e-02  0.601152  0.047762     -0.446404  1.376296
# quant-olhc       2.110841e-02  0.618381  0.045097     -0.469639  1.266659
# quant-olh_sma    2.137561e-02  0.609787  0.044779     -0.446404  1.253896
# defalt-sma       4.335895e-02  0.271590  0.044273     -0.328392  1.233732
# huber-olhcv      3.965362e-02  0.313939  0.043355     -0.503870  1.197593
#
#                    sharpe       var  volatility
# huber-olh_ema    0.527103 -0.017411    0.190204
# lad-ema          0.513717 -0.017168    0.190206
# defalt-olh_sma   0.507701 -0.017450    0.190560
# huber-olh_sma    0.479490 -0.017450    0.190447
# defalt-olh       0.478037 -0.017411    0.190524
# defalt-olh_ema   0.475849 -0.017332    0.190195
# quant-olhv       0.462642 -0.018230    0.190147
# defalt-olhv      0.458247 -0.017282    0.190303
# lad-olh_ema      0.450566 -0.017202    0.190240
# quant-olhcv      0.444842 -0.018300    0.190124
# defalt-ema       0.435661 -0.017362    0.190216
# huber-olh        0.418124 -0.017515    0.190532
# huber-ema        0.415456 -0.017332    0.190256
# huber-olhc       0.403963 -0.017588    0.190382
# lad-olhcv        0.404017 -0.017398    0.190154
# lad-olh          0.394172 -0.017411    0.190288
# defalt-olhc      0.388185 -0.017450    0.190387
# lad-olhc         0.379245 -0.017450    0.190365
# quant-close_adj  0.378676 -0.018440    0.190146
# lad-olhv         0.377489 -0.017450    0.190284
# quant-ema        0.361422 -0.018136    0.190172
# huber-olhv       0.356445 -0.017333    0.190189
# benchmark        0.349346 -0.019044    0.190026
# huber-sma        0.348360 -0.017657    0.190407
# quant-olh        0.345520 -0.018483    0.190123
# quant-olh_ema    0.340336 -0.018372    0.190128
# quant-olhc       0.326970 -0.018476    0.190108
# quant-olh_sma    0.325345 -0.018425    0.190125
# defalt-sma       0.322438 -0.017859    0.190388
# huber-olhcv      0.318131 -0.017398    0.190156

# %% [markdown]
# There is no improvement using different losses

# %% [markdown]
# ### Try different learning rates

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

#model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
#model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
#model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
#model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
#model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
#model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
#model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

#model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

#model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

#model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
#model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

#model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
#model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
#model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}

model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}

#model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
#model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
#model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-24 18:40:50,580 - INFO - 24085 - Backtesting with defalt - all
# 2019-06-24 18:41:05,907 - INFO - 24085 - Backtesting with defalt - close_adj
# 2019-06-24 18:41:15,634 - INFO - 24085 - Backtesting with defalt - olh
# 2019-06-24 18:41:26,918 - INFO - 24085 - Backtesting with defalt - olhc
# 2019-06-24 18:41:37,283 - INFO - 24085 - Backtesting with defalt - olhv
# 2019-06-24 18:41:48,355 - INFO - 24085 - Backtesting with defalt - olhcv
# 2019-06-24 18:41:56,648 - INFO - 24085 - Backtesting with defalt - volume
# 2019-06-24 18:42:04,794 - INFO - 24085 - Backtesting with defalt - sma
# 2019-06-24 18:42:13,499 - INFO - 24085 - Backtesting with defalt - ema
# 2019-06-24 18:42:23,749 - INFO - 24085 - Backtesting with defalt - lagged
# 2019-06-24 18:42:36,890 - INFO - 24085 - Backtesting with defalt - olh_sma
# 2019-06-24 18:42:50,665 - INFO - 24085 - Backtesting with defalt - olh_ema
# 2019-06-24 18:43:04,145 - INFO - 24085 - Backtesting with defalt - olh_slope
# 2019-06-24 18:43:16,267 - INFO - 24085 - Backtesting with lr.01 - all
# 2019-06-24 18:43:31,067 - INFO - 24085 - Backtesting with lr.01 - close_adj
# 2019-06-24 18:43:41,331 - INFO - 24085 - Backtesting with lr.01 - olh
# 2019-06-24 18:43:51,612 - INFO - 24085 - Backtesting with lr.01 - olhc
# 2019-06-24 18:44:02,250 - INFO - 24085 - Backtesting with lr.01 - olhv
# 2019-06-24 18:44:13,965 - INFO - 24085 - Backtesting with lr.01 - olhcv
# 2019-06-24 18:44:24,350 - INFO - 24085 - Backtesting with lr.01 - volume
# 2019-06-24 18:44:34,115 - INFO - 24085 - Backtesting with lr.01 - sma
# 2019-06-24 18:44:45,054 - INFO - 24085 - Backtesting with lr.01 - ema
# 2019-06-24 18:44:56,912 - INFO - 24085 - Backtesting with lr.01 - lagged
# 2019-06-24 18:45:09,956 - INFO - 24085 - Backtesting with lr.01 - olh_sma
# 2019-06-24 18:45:23,453 - INFO - 24085 - Backtesting with lr.01 - olh_ema
# 2019-06-24 18:45:36,735 - INFO - 24085 - Backtesting with lr.01 - olh_slope
# 2019-06-24 18:45:49,869 - INFO - 24085 - Backtesting with lr.05 - all
# 2019-06-24 18:46:07,524 - INFO - 24085 - Backtesting with lr.05 - close_adj
# 2019-06-24 18:46:19,396 - INFO - 24085 - Backtesting with lr.05 - olh
# 2019-06-24 18:46:31,175 - INFO - 24085 - Backtesting with lr.05 - olhc
# 2019-06-24 18:46:39,850 - INFO - 24085 - Backtesting with lr.05 - olhv
# 2019-06-24 18:46:51,208 - INFO - 24085 - Backtesting with lr.05 - olhcv
# 2019-06-24 18:47:03,457 - INFO - 24085 - Backtesting with lr.05 - volume
# 2019-06-24 18:47:12,756 - INFO - 24085 - Backtesting with lr.05 - sma
# 2019-06-24 18:47:21,502 - INFO - 24085 - Backtesting with lr.05 - ema
# 2019-06-24 18:47:31,009 - INFO - 24085 - Backtesting with lr.05 - lagged
# 2019-06-24 18:47:40,320 - INFO - 24085 - Backtesting with lr.05 - olh_sma
# 2019-06-24 18:47:49,429 - INFO - 24085 - Backtesting with lr.05 - olh_ema
# 2019-06-24 18:47:58,534 - INFO - 24085 - Backtesting with lr.05 - olh_slope
# 2019-06-24 18:48:07,507 - INFO - 24085 - Backtesting with lr.001 - all
# 2019-06-24 18:48:19,236 - INFO - 24085 - Backtesting with lr.001 - close_adj
# 2019-06-24 18:48:27,332 - INFO - 24085 - Backtesting with lr.001 - olh
# 2019-06-24 18:48:36,025 - INFO - 24085 - Backtesting with lr.001 - olhc
# 2019-06-24 18:48:44,913 - INFO - 24085 - Backtesting with lr.001 - olhv
# 2019-06-24 18:48:53,562 - INFO - 24085 - Backtesting with lr.001 - olhcv
# 2019-06-24 18:49:02,110 - INFO - 24085 - Backtesting with lr.001 - volume
# 2019-06-24 18:49:10,416 - INFO - 24085 - Backtesting with lr.001 - sma
# 2019-06-24 18:49:19,006 - INFO - 24085 - Backtesting with lr.001 - ema
# 2019-06-24 18:49:30,496 - INFO - 24085 - Backtesting with lr.001 - lagged
# 2019-06-24 18:49:39,477 - INFO - 24085 - Backtesting with lr.001 - olh_sma
# 2019-06-24 18:49:48,309 - INFO - 24085 - Backtesting with lr.001 - olh_ema
# 2019-06-24 18:49:57,184 - INFO - 24085 - Backtesting with lr.001 - olh_slope
# CPU times: user 9min 11s, sys: 664 ms, total: 9min 11s
# Wall time: 9min 15s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                          alpha      beta      cagr  max_drawdown    return  \
# benchmark         0.349346 -0.019044    0.190026
# lr.05-olhc        0.332550 -0.017588    0.190388
# defalt-sma        0.322438 -0.017859    0.190388
# lr.01-olh_sma     0.307028 -0.017657    0.190336
# lr.01-olhcv       0.305042 -0.017332    0.190337
# lr.01-olh_ema     0.297430 -0.017768    0.190330
# defalt-lagged     0.293021 -0.017621    0.190227
# lr.01-lagged      0.284926 -0.017425    0.190326
# lr.05-olhcv       0.266855 -0.017588    0.190189
# defalt-olhcv      0.266577 -0.017597    0.190191
# lr.05-lagged      0.248482 -0.017795    0.190224
# lr.05-close_adj   0.209895 -0.017768    0.190191
# lr.05-volume      0.201154 -0.017597    0.190289
# lr.01-sma         0.194806 -0.017845    0.190263
# defalt-close_adj  0.189297 -0.017768    0.190222

# %% [markdown]
# Using a reduction of the learning rate produces a slighty bigger CAGR, and also a reduction in the max drawdown.

# %% [markdown]
# ### Try different amount of booested trees

# %%
model_params = OrderedDict()

model_params['defalt'] = {'random_state': 100, }

#model_params['depth3'] =  {'random_state': 100, 'max_depth': 3}
#model_params['depth4'] =  {'random_state': 100, 'max_depth': 4}
#model_params['depth5'] =  {'random_state': 100, 'max_depth': 5}
#model_params['depth6'] =  {'random_state': 100, 'max_depth': 6}
#model_params['depth7'] =  {'random_state': 100, 'max_depth': 7}
#model_params['depth8'] =  {'random_state': 100, 'max_depth': 8}
#model_params['depth9'] =  {'random_state': 100, 'max_depth': 9}
#model_params['depth10'] = {'random_state': 100, 'max_depth': 10}

#model_params['min_samp_leaf-10'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-20'] =   {'random_state': 100, 'min_samples_leaf': 10}
#model_params['min_samp_leaf-50'] =   {'random_state': 100, 'min_samples_leaf': 50}

#model_params['min_samp_split-10'] = {'random_state': 100, 'min_samples_split': 10}
#model_params['min_samp_split-50'] = {'random_state': 100, 'min_samples_split': 50}
#model_params['min_samp_split-100'] = {'random_state': 100, 'min_samples_split': 100}

#model_params['mse'] = {'random_state': 100, 'criterion': 'mse'}
#model_params['mae'] = {'random_state': 100, 'criterion': 'mae'}

#model_params['lad'] = {'random_state': 100, 'loss': 'lad'}
#model_params['huber'] = {'random_state': 100, 'loss': 'huber'}
#model_params['quant'] = {'random_state': 100, 'loss': 'quantile'}

#model_params['lr.01'] = {'random_state': 100, 'learning_rate': .01}
#model_params['lr.05'] = {'random_state': 100, 'learning_rate': .05}
#model_params['lr.001'] = {'random_state': 100, 'learning_rate': .001}

model_params['n10'] = {'random_state': 100, 'n_estimators': 10}
model_params['n50'] = {'random_state': 100, 'n_estimators': 50}
model_params['n200'] = {'random_state': 100, 'n_estimators': 200}

# %%
# %%time
backtest_summaries_list = []
performance_track = OrderedDict()
for model_params_name, current_model_params in model_params.items():
    for inputs_name, x_var_current in x_var_set.items():
        x_vars = x_var_current
        y_var = 'close_adj_shift_1'
        buy_price_col = 'close_adj'
        sell_price_col = 'close_adj_shift_1'
        model_class = GradientBoostingRegressor

        logging.info('Backtesting with %s - %s', model_params_name, inputs_name)
        df_backtest = train_model_and_backtest_regressor(df, x_vars=x_vars, y_var=y_var, 
            buy_price_col=buy_price_col, sell_price_col=sell_price_col,
            model_class=model_class, model_params=current_model_params, 
            backtest_start='2000-06-01', backtest_end='2018-12-31', 
            model_update_frequency='M', train_history_period=relativedelta(months=1, days=1),
            col_date_shift='date_shift_1'
        )
        name = '%s-%s' % (model_params_name, inputs_name)
        performance_track[name] = df_backtest[['date', 'ret']]
        backtest_summary = get_backtest_performance_metrics(df_backtest.ret, df_backtest.benchmark_ret, 
                                                            with_benchmark=True, with_delta=True)
        backtest_summary_no_benchmark = backtest_summary['main']
        backtest_summary_no_benchmark.name = name
        backtest_summaries_list.append(backtest_summary_no_benchmark)
backtest_summaries_list.append(backtest_summary.benchmark)
performance_track['benchmark'] = df_backtest[['date', 'benchmark_ret']].rename({'benchmark_ret': 'ret'}, axis=1)
# Out:
# 2019-06-24 18:50:06,249 - INFO - 24085 - Backtesting with defalt - all
# 2019-06-24 18:50:17,766 - INFO - 24085 - Backtesting with defalt - close_adj
# 2019-06-24 18:50:26,069 - INFO - 24085 - Backtesting with defalt - olh
# 2019-06-24 18:50:37,782 - INFO - 24085 - Backtesting with defalt - olhc
# 2019-06-24 18:50:49,970 - INFO - 24085 - Backtesting with defalt - olhv
# 2019-06-24 18:51:01,200 - INFO - 24085 - Backtesting with defalt - olhcv
# 2019-06-24 18:51:13,565 - INFO - 24085 - Backtesting with defalt - volume
# 2019-06-24 18:51:24,323 - INFO - 24085 - Backtesting with defalt - sma
# 2019-06-24 18:51:35,243 - INFO - 24085 - Backtesting with defalt - ema
# 2019-06-24 18:51:45,987 - INFO - 24085 - Backtesting with defalt - lagged
# 2019-06-24 18:51:56,707 - INFO - 24085 - Backtesting with defalt - olh_sma
# 2019-06-24 18:52:08,960 - INFO - 24085 - Backtesting with defalt - olh_ema
# 2019-06-24 18:52:22,039 - INFO - 24085 - Backtesting with defalt - olh_slope
# 2019-06-24 18:52:32,948 - INFO - 24085 - Backtesting with n10 - all
# 2019-06-24 18:52:37,582 - INFO - 24085 - Backtesting with n10 - close_adj
# 2019-06-24 18:52:42,382 - INFO - 24085 - Backtesting with n10 - olh
# 2019-06-24 18:52:48,173 - INFO - 24085 - Backtesting with n10 - olhc
# 2019-06-24 18:52:53,826 - INFO - 24085 - Backtesting with n10 - olhv
# 2019-06-24 18:53:00,609 - INFO - 24085 - Backtesting with n10 - olhcv
# 2019-06-24 18:53:07,582 - INFO - 24085 - Backtesting with n10 - volume
# 2019-06-24 18:53:14,208 - INFO - 24085 - Backtesting with n10 - sma
# 2019-06-24 18:53:20,333 - INFO - 24085 - Backtesting with n10 - ema
# 2019-06-24 18:53:25,453 - INFO - 24085 - Backtesting with n10 - lagged
# 2019-06-24 18:53:31,246 - INFO - 24085 - Backtesting with n10 - olh_sma
# 2019-06-24 18:53:37,676 - INFO - 24085 - Backtesting with n10 - olh_ema
# 2019-06-24 18:53:43,649 - INFO - 24085 - Backtesting with n10 - olh_slope
# 2019-06-24 18:53:49,418 - INFO - 24085 - Backtesting with n50 - all
# 2019-06-24 18:54:00,045 - INFO - 24085 - Backtesting with n50 - close_adj
# 2019-06-24 18:54:07,238 - INFO - 24085 - Backtesting with n50 - olh
# 2019-06-24 18:54:13,797 - INFO - 24085 - Backtesting with n50 - olhc
# 2019-06-24 18:54:19,307 - INFO - 24085 - Backtesting with n50 - olhv
# 2019-06-24 18:54:25,966 - INFO - 24085 - Backtesting with n50 - olhcv
# 2019-06-24 18:54:34,281 - INFO - 24085 - Backtesting with n50 - volume
# 2019-06-24 18:54:41,543 - INFO - 24085 - Backtesting with n50 - sma
# 2019-06-24 18:54:49,949 - INFO - 24085 - Backtesting with n50 - ema
# 2019-06-24 18:54:59,374 - INFO - 24085 - Backtesting with n50 - lagged
# 2019-06-24 18:55:08,860 - INFO - 24085 - Backtesting with n50 - olh_sma
# 2019-06-24 18:55:19,616 - INFO - 24085 - Backtesting with n50 - olh_ema
# 2019-06-24 18:55:30,130 - INFO - 24085 - Backtesting with n50 - olh_slope
# 2019-06-24 18:55:40,513 - INFO - 24085 - Backtesting with n200 - all
# 2019-06-24 18:56:04,320 - INFO - 24085 - Backtesting with n200 - close_adj
# 2019-06-24 18:56:23,457 - INFO - 24085 - Backtesting with n200 - olh
# 2019-06-24 18:56:41,958 - INFO - 24085 - Backtesting with n200 - olhc
# 2019-06-24 18:57:00,019 - INFO - 24085 - Backtesting with n200 - olhv
# 2019-06-24 18:57:18,404 - INFO - 24085 - Backtesting with n200 - olhcv
# 2019-06-24 18:57:36,760 - INFO - 24085 - Backtesting with n200 - volume
# 2019-06-24 18:57:54,419 - INFO - 24085 - Backtesting with n200 - sma
# 2019-06-24 18:58:12,944 - INFO - 24085 - Backtesting with n200 - ema
# 2019-06-24 18:58:31,499 - INFO - 24085 - Backtesting with n200 - lagged
# 2019-06-24 18:58:49,816 - INFO - 24085 - Backtesting with n200 - olh_sma
# 2019-06-24 18:59:08,391 - INFO - 24085 - Backtesting with n200 - olh_ema
# 2019-06-24 18:59:27,100 - INFO - 24085 - Backtesting with n200 - olh_slope
# CPU times: user 9min 36s, sys: 564 ms, total: 9min 36s
# Wall time: 9min 39s

# %%
pd.concat(backtest_summaries_list, axis=1).T.sort_values('return', ascending=False)[:30]
# Out:
#                        alpha      beta      cagr  max_drawdown    return  \
# defalt-olh_sma  7.758844e-02  0.288603  0.081842     -0.371374  3.303236
# n50-olh_sma     7.750058e-02  0.289197  0.081790     -0.369175  3.299369
# n50-olhv        7.507809e-02  0.298191  0.079833     -0.323638  3.157330
# n50-olh         7.346000e-02  0.286649  0.077248     -0.345447  2.976570
# n50-olh_ema     7.064586e-02  0.315675  0.076316     -0.293878  2.913196
# defalt-olh      7.254280e-02  0.279200  0.075729     -0.348481  2.873806
# defalt-olh_ema  6.950265e-02  0.316354  0.075134     -0.293878  2.834283
# n200-olh_ema    6.950265e-02  0.316354  0.075134     -0.293878  2.834283
# n200-olh        7.173647e-02  0.278134  0.074786     -0.372331  2.811288
# n200-olh_sma    7.176940e-02  0.273647  0.074504     -0.366621  2.792806
# defalt-olhv     6.713122e-02  0.302398  0.071588     -0.323638  2.606296
# n200-olhv       6.554664e-02  0.302251  0.069881     -0.323638  2.501194
# defalt-ema      6.201691e-02  0.314121  0.066958     -0.290552  2.327930
# n200-ema        6.201691e-02  0.314121  0.066958     -0.290552  2.327930
# n50-ema         5.976297e-02  0.314893  0.064610     -0.290552  2.194684
# n200-olhc       5.702606e-02  0.289750  0.059919     -0.339725  1.943390
# defalt-olhc     5.457540e-02  0.291177  0.057425     -0.339725  1.817529
# n10-olhc        4.709753e-02  0.350286  0.053679     -0.375757  1.637988
# n50-olhc        4.956681e-02  0.287792  0.051906     -0.365510  1.556872
# benchmark      -3.681556e-16  1.000000  0.049527     -0.551894  1.451705
# n10-lagged      4.231753e-02  0.351088  0.048710     -0.428467  1.416524
# n10-olh         4.175926e-02  0.354703  0.048377     -0.375757  1.402325
# n200-sma        4.693416e-02  0.268674  0.047810     -0.328392  1.378327
# n10-olhcv       3.774267e-02  0.366019  0.044958     -0.376369  1.261066
# defalt-sma      4.335895e-02  0.271590  0.044273     -0.328392  1.233732
# n10-olh_sma     3.654121e-02  0.364836  0.043623     -0.376047  1.208069
# n50-sma         4.040412e-02  0.270978  0.041150     -0.354231  1.112993
# n50-lagged      3.443604e-02  0.323954  0.038612     -0.396980  1.019449
# defalt-lagged   3.411949e-02  0.325692  0.038403     -0.405632  1.011927
# n200-lagged     3.411949e-02  0.325692  0.038403     -0.405632  1.011927
#
#                   sharpe       var  volatility
# defalt-olh_sma  0.507701 -0.017450    0.190560
# n50-olh_sma     0.507447 -0.017450    0.190560
# n50-olhv        0.498458 -0.017202    0.190334
# n50-olh         0.485438 -0.017375    0.190527
# n50-olh_ema     0.481626 -0.017332    0.190193
# defalt-olh      0.478037 -0.017411    0.190524
# defalt-olh_ema  0.475849 -0.017332    0.190195
# n200-olh_ema    0.475849 -0.017332    0.190195
# n200-olh        0.473434 -0.017450    0.190524
# n200-olh_sma    0.472156 -0.017515    0.190478
# defalt-olhv     0.458247 -0.017282    0.190303
# n200-olhv       0.449863 -0.017282    0.190306
# defalt-ema      0.435661 -0.017362    0.190216
# n200-ema        0.435661 -0.017362    0.190216
# n50-ema         0.424074 -0.017362    0.190219
# n200-olhc       0.400561 -0.017411    0.190386
# defalt-olhc     0.388185 -0.017450    0.190387
# n10-olhc        0.369653 -0.017240    0.190317
# n50-olhc        0.360700 -0.017588    0.190385
# benchmark       0.349346 -0.019044    0.190026
# n10-lagged      0.344808 -0.017256    0.190322
# n10-olh         0.343153 -0.017597    0.190312
# n200-sma        0.340192 -0.017823    0.190393
# n10-olhcv       0.325955 -0.017362    0.190336
# defalt-sma      0.322438 -0.017859    0.190388
# n10-olh_sma     0.319267 -0.017722    0.190313
# n50-sma         0.306703 -0.017929    0.190390
# n50-lagged      0.294079 -0.017657    0.190227
# defalt-lagged   0.293021 -0.017621    0.190227
# n200-lagged     0.293021 -0.017621    0.190227

# %% [markdown]
# There is no improvement adding more boosted trees. With 50 or 100 seems to be ok.

# %% [markdown]
# **Partial conclusion:** For the moment, GBM was the model with highest CAGR when it was trained with only 1 month of history.
